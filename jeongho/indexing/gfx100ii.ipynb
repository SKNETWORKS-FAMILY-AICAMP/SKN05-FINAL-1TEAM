# %% [markdown]
# # pdf split

# %%
import os
from pikepdf import Pdf

camera_model = "gfx100ii"
pdf_path = f"../data/raw_data/{camera_model}/{camera_model}.pdf"

basename = os.path.basename(pdf_path)
splitname = os.path.splitext(basename)[0]

raw_dir = "../data/raw_data"
output_dir = os.path.join(raw_dir, splitname)
detail_output_dir = os.path.join(output_dir, f"{splitname}_split")

if not os.path.exists(detail_output_dir):
    os.makedirs(detail_output_dir)

pdf = Pdf.open(pdf_path)
for n, page in enumerate(pdf.pages):
    new_pdf = Pdf.new()
    new_pdf.pages.append(page)

    output_filename = os.path.join(detail_output_dir, splitname+f"_page{n+1}.pdf")

    new_pdf.save(output_filename)
    print(f"[+] File: {output_filename} saved.")
# Out:
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page1.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page2.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page3.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page4.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page5.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page6.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page7.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page8.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page9.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page10.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page11.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page12.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page13.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page14.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page15.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page16.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page17.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page18.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page19.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page20.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page21.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page22.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page23.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page24.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page25.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page26.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page27.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page28.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page29.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page30.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page31.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page32.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page33.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page34.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page35.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page36.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page37.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page38.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page39.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page40.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page41.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page42.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page43.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page44.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page45.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page46.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page47.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page48.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page49.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page50.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page51.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page52.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page53.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page54.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page55.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page56.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page57.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page58.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page59.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page60.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page61.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page62.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page63.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page64.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page65.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page66.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page67.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page68.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page69.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page70.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page71.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page72.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page73.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page74.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page75.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page76.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page77.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page78.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page79.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page80.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page81.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page82.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page83.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page84.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page85.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page86.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page87.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page88.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page89.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page90.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page91.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page92.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page93.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page94.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page95.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page96.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page97.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page98.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page99.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page100.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page101.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page102.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page103.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page104.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page105.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page106.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page107.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page108.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page109.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page110.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page111.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page112.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page113.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page114.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page115.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page116.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page117.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page118.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page119.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page120.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page121.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page122.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page123.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page124.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page125.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page126.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page127.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page128.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page129.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page130.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page131.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page132.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page133.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page134.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page135.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page136.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page137.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page138.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page139.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page140.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page141.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page142.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page143.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page144.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page145.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page146.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page147.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page148.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page149.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page150.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page151.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page152.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page153.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page154.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page155.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page156.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page157.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page158.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page159.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page160.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page161.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page162.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page163.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page164.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page165.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page166.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page167.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page168.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page169.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page170.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page171.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page172.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page173.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page174.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page175.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page176.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page177.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page178.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page179.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page180.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page181.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page182.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page183.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page184.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page185.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page186.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page187.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page188.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page189.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page190.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page191.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page192.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page193.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page194.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page195.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page196.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page197.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page198.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page199.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page200.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page201.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page202.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page203.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page204.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page205.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page206.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page207.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page208.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page209.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page210.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page211.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page212.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page213.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page214.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page215.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page216.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page217.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page218.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page219.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page220.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page221.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page222.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page223.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page224.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page225.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page226.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page227.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page228.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page229.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page230.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page231.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page232.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page233.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page234.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page235.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page236.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page237.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page238.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page239.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page240.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page241.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page242.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page243.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page244.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page245.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page246.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page247.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page248.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page249.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page250.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page251.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page252.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page253.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page254.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page255.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page256.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page257.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page258.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page259.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page260.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page261.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page262.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page263.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page264.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page265.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page266.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page267.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page268.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page269.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page270.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page271.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page272.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page273.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page274.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page275.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page276.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page277.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page278.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page279.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page280.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page281.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page282.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page283.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page284.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page285.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page286.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page287.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page288.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page289.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page290.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page291.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page292.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page293.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page294.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page295.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page296.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page297.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page298.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page299.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page300.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page301.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page302.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page303.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page304.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page305.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page306.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page307.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page308.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page309.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page310.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page311.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page312.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page313.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page314.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page315.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page316.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page317.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page318.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page319.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page320.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page321.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page322.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page323.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page324.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page325.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page326.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page327.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page328.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page329.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page330.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page331.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page332.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page333.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page334.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page335.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page336.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page337.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page338.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page339.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page340.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page341.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page342.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page343.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page344.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page345.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page346.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page347.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page348.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page349.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page350.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page351.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page352.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page353.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page354.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page355.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page356.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page357.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page358.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page359.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page360.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page361.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page362.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page363.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page364.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page365.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page366.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page367.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page368.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page369.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page370.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page371.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page372.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page373.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page374.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page375.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page376.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page377.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page378.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page379.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page380.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page381.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page382.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page383.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page384.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page385.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page386.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page387.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page388.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page389.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page390.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page391.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page392.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page393.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page394.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page395.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page396.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page397.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page398.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page399.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page400.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page401.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page402.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page403.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page404.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page405.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page406.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page407.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page408.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page409.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page410.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page411.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page412.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page413.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page414.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page415.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page416.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page417.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page418.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page419.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page420.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page421.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page422.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page423.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page424.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page425.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page426.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page427.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page428.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page429.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page430.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page431.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page432.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page433.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page434.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page435.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page436.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page437.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page438.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page439.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page440.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page441.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page442.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page443.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page444.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page445.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page446.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page447.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page448.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page449.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page450.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page451.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page452.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page453.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page454.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page455.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page456.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page457.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page458.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page459.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page460.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page461.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page462.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page463.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page464.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page465.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page466.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page467.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page468.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page469.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page470.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page471.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page472.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page473.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page474.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page475.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page476.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page477.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page478.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page479.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page480.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page481.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page482.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page483.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page484.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page485.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page486.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page487.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page488.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page489.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page490.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page491.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page492.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page493.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page494.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page495.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page496.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page497.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page498.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page499.pdf saved.
# [+] File: ../data/raw_data/gfx100ii/gfx100ii_split/gfx100ii_page500.pdf saved.

# %% [markdown]
# # Llama Parase Multimodal

# %%
import os
import json
from dotenv import load_dotenv
from llama_parse import LlamaParse
from glob import glob

# %%
load_dotenv(dotenv_path="../.env", override=True)
# Out:
# Python-dotenv could not parse statement starting at line 2
# True

# %%
parsing_instruction='''You are a highly proficient language model with advanced multimodal parsing capabilities. Your task is to process and extract content from a PDF document that serves as a camera manual.

**Specific Requirements:**

1. **Text Extraction:**  
   Extract all textual content from the document in a structured Markdown format. Preserve the hierarchy and formatting, including headings, subheadings, bullet points, numbered lists, and paragraphs.

2. **Image Identification and Inclusion:**  
   - Identify any images present in the document.  
   - For each image, insert a Markdown reference in the appropriate location using the syntax:  
     `![Image Description](ImagePlaceholder)`

3. **General Guidelines:**  
   - Maintain logical and clean formatting for Markdown output.
   - Avoid redundant or non-informative text (e.g., "Page number" or "Header/Footer").
   - Ensure extracted text and image references align with their original positions in the document.

**Example Output Structure:**  

# SHOOTING SETTING (Still Photography)
Adjust shooting options for still photography.

To display shooting settings, press **MENU/OK** in the photo shooting display and select the **SHOOTING SETTING** tab.

![Shooting Settings Menu](ImagePlaceholder)

> 💡 **Note:**
> - The options available vary with the shooting mode selected.

## SELF-TIMER
Choose a shutter release delay.

| Option   | Description                                                                                                         |
|----------|---------------------------------------------------------------------------------------------------------------------|
| 2 SEC | The shutter is released two seconds after the shutter button is pressed. Use to reduce blur caused by the camera moving when the shutter button is pressed. The self-timer lamp blinks as the timer counts down.  |
| 10 SEC| The shutter is released ten seconds after the shutter button is pressed. Use for photographs in which you wish to appear yourself. The self-timer lamp blinks immediately before the picture is taken. |
| OFF      | Self-timer off.                                                                                                    |

If an option other than **OFF** is selected, the timer will start when the shutter button is pressed all the way down. The display shows the number of seconds remaining until the shutter is released. To stop the timer before the picture is taken, press **DISP/BACK**.

![Timer Display](ImagePlaceholder)

> 💡 **Note:**
> - Stand behind the camera when using the shutter button. Standing in front of the lens can interfere with focus and exposure.
> - The self-timer turns off automatically when the camera is turned off.'''

parser = LlamaParse(
    api_key = os.getenv("LLAMA_CLOUD_API_KEY"),
    result_type="markdown",
    use_vendor_multimodal_model=True,
    vendor_multimodal_model_name="openai-gpt4o",
    vendor_multimodal_api_key=os.getenv("OPENAI_API_KEY"),
    parsing_instruction = parsing_instruction,
    invalidate_cache=True
)

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
camera_model = "gfx100ii"
splited_pdf_path = f"../data/raw_data/{camera_model}/{camera_model}_split/*.pdf"
pdf_list = glob(splited_pdf_path)

json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "init_result")
if not os.path.exists(detail_json_dir):
    os.makedirs(detail_json_dir)

for pdf in pdf_list:
    json_objs = parser.get_json_result(pdf)

    file_path, file_name = os.path.split(pdf)
    name = os.path.splitext(file_name)[0]
    json_path = os.path.join(detail_json_dir, name+".json")
    
    with open(json_path, "w", encoding="utf-8") as file:
        json.dump(json_objs[0], file, ensure_ascii=False, indent=4)
# Out:
# Started parsing the file under job_id c081f66e-c556-4510-b186-14f716386965
# Started parsing the file under job_id 29759d58-8afe-49ee-88bf-50ea532f4bf4
# Started parsing the file under job_id 7b0776ce-0eaa-4fc7-9cfc-c7d269de22ed
# Started parsing the file under job_id 33b311f3-9b6a-4417-b5f7-d54d9538ffe9
# Started parsing the file under job_id 473d2a47-71b5-4d77-aaed-656ce72674d8
# Started parsing the file under job_id 3dcc40d5-969c-4285-b39d-1348f0412e7d
# Started parsing the file under job_id 33bbfd93-40d7-4b48-96fd-539d58928a26
# Started parsing the file under job_id 65ad9424-ec84-466c-aa45-696640efa43a
# Started parsing the file under job_id d98053b3-d675-4f96-9b08-bf3ce9260fc9
# Started parsing the file under job_id c8378619-3c33-4b8c-881b-a0a6c179035a
# Started parsing the file under job_id 39a8c92f-43d3-447c-920b-cf08a93b5f4b
# Started parsing the file under job_id 8e6c4a26-9ae0-4057-a630-901b787eacb2
# Started parsing the file under job_id 3560bce7-f52e-41aa-94b7-d49a078a77eb
# Started parsing the file under job_id b3eea410-a3fa-4e35-a621-ca0b477f1570
# Started parsing the file under job_id 509d913f-05df-497f-a8d8-a6999f92313f
# Started parsing the file under job_id 9a8e73a1-d17b-413e-b8b9-f92adb8c8cc0
# Started parsing the file under job_id 50dccced-4f7a-47c6-b3eb-1789719eec7e
# Started parsing the file under job_id 8e583354-cc34-4206-94c4-65ec88e87466
# Started parsing the file under job_id a7c9ab57-bb85-4dbf-befe-3b56294a0cb9
# Started parsing the file under job_id cbbf1036-b77f-466d-a50d-61ee3be8f6ed
# Started parsing the file under job_id 169831b7-aa9e-45c2-8178-16d899ba5dbe
# Started parsing the file under job_id 4fa7a588-f2c6-4092-97c8-d21e7aed8f73
# Started parsing the file under job_id 710b987b-a212-41fd-9b6a-ba8d975714cf
# Started parsing the file under job_id 30deaf1a-6cf1-4ee8-a5a7-fba1e81597d7
# Started parsing the file under job_id 5d2b7729-3f77-4ba6-bb51-5b2fd79e4380
# Started parsing the file under job_id c3b4b97f-36a0-443b-b764-f4057656bec6
# Started parsing the file under job_id 4ef50363-e60b-4546-bca9-4240292ebf27
# Started parsing the file under job_id 73b45c96-e857-4155-b48e-bec92ed8b69a
# Started parsing the file under job_id 99e3ab6e-61e6-4e21-a9ae-5668e67a0d58
# Started parsing the file under job_id 52b7ce97-8935-4201-bca9-39f69c53c0e8
# Started parsing the file under job_id baf3dc0c-7663-4960-9386-a4be9aaab4d2
# Started parsing the file under job_id 0484030b-1025-477f-be42-abf346b2b9b9
# Started parsing the file under job_id b1c85aa3-4029-466e-8ed6-40ea7baf3a9c
# Started parsing the file under job_id c852a100-bc6e-4809-a6c2-4ef8b7b80b53
# Started parsing the file under job_id ede0c757-7e80-4b0b-8f21-e6245690d983
# Started parsing the file under job_id c3ae4219-408e-4707-8d29-39102726e86e
# Started parsing the file under job_id 5a064257-3b22-416a-aa8a-851618f7f5ef
# Started parsing the file under job_id 21cdebc1-37cd-47ef-99f4-2a6113f84fb7
# Started parsing the file under job_id 495a784c-c552-4f52-86cc-b81a585523e2
# Started parsing the file under job_id d51bb2ef-7d83-4335-9bfa-7b2002eb09b5
# Started parsing the file under job_id f3fb73f7-20ce-4950-961f-a672c72e8453
# Started parsing the file under job_id 480ea003-82a5-4e18-9066-fad9a97c5d22
# Started parsing the file under job_id e9eb6baf-aa33-4856-b466-b00dc6969804
# Started parsing the file under job_id 6ec58969-e7bd-4cb8-b33e-ccba637aa7a3
# Started parsing the file under job_id 9385c7d7-6b22-48d4-a76e-e067af35e6da
# Started parsing the file under job_id 97643eab-9000-4b5d-90de-0bc90f1dcdd9
# Started parsing the file under job_id 50fdb63b-0a01-4fe4-a5d2-5b033ba447bc
# Started parsing the file under job_id 797cb245-774a-4b8f-a031-db2c4277cb8e
# Started parsing the file under job_id 447f3ac2-db10-4c1d-95ea-c3db7c5d27a2
# Started parsing the file under job_id 7f95c570-da9e-4063-a5b8-58329f0ca1e9
# Started parsing the file under job_id 127fae69-f860-4c40-83aa-4c964f43872b
# Started parsing the file under job_id cc94a510-3a76-4cfa-bca6-d9f55154e9aa
# Started parsing the file under job_id d24999b1-e962-4106-97fb-5974141fd127
# Started parsing the file under job_id e5bcbc63-8e20-411e-a557-057c56c99b69
# Started parsing the file under job_id a0b1942c-95f7-47f7-ae2c-38dac27215fc
# Started parsing the file under job_id aee78dad-2081-451b-a58e-8b348094b8e7
# Started parsing the file under job_id c65ed775-8f17-4506-ad29-78cd619250e7
# Started parsing the file under job_id 1ca8e075-0ef7-457c-921c-5b798f9754b7
# Started parsing the file under job_id cc4549b7-cb43-4482-b625-9f05816859c1
# Started parsing the file under job_id 0eca3a8c-2cc7-4f98-99ff-69e91c5b8125
# Started parsing the file under job_id 37e6d460-ab5b-41de-9a48-421aadcccbc1
# Started parsing the file under job_id 66fb0051-35d9-45ac-a022-ce04d617c4df
# Started parsing the file under job_id 0030c6dc-9ded-455b-8891-128f7a085f00
# Started parsing the file under job_id 754fc5c8-75cb-42fc-a5da-b1b2d4e6f87f
# Started parsing the file under job_id c3170452-0999-4bb3-8ba8-234bf0557c1b
# Started parsing the file under job_id 1db1896a-f246-40ef-8982-d6f973ee30fb
# Started parsing the file under job_id b378a17e-8c30-4e16-93f2-08556a4ad569
# Started parsing the file under job_id 1389288d-ac6c-46f8-bae9-453ef10d05e8
# Started parsing the file under job_id 13f2dd4b-b842-4c2c-a32f-c17addaca7cd
# Started parsing the file under job_id 465b8169-5610-4098-bac1-2a3e8d63ee21
# Started parsing the file under job_id ef9853e3-d1c4-49ab-a3f2-ae15533f469f
# Started parsing the file under job_id b2910665-6d9f-40e3-b42d-0630d21b0b41
# Started parsing the file under job_id 1ada3bd2-6996-49e8-b8f1-a2c287e8ec7e
# Started parsing the file under job_id 7242f3a2-2b7f-4d3e-84aa-94d294735553
# Started parsing the file under job_id 1e3b23a9-e1b2-4033-8655-d5679f4125bf
# Started parsing the file under job_id 760077b9-bad3-4f38-ab2f-d9900b84493f
# Started parsing the file under job_id 79cbe9c4-fa58-4495-95ce-b641f5971eda
# Started parsing the file under job_id 3d67ad21-1005-41f2-99e7-c7a08b108fec
# Started parsing the file under job_id 22d2cd88-3059-446b-a45a-ef494c02fb8a
# Started parsing the file under job_id e0ebc663-4181-40e8-a6b8-d97b73024f9a
# Started parsing the file under job_id e0b5bc39-2310-4ff3-b048-8b3752baef60
# Started parsing the file under job_id 198cc642-3f7e-4a8e-a438-a6195842708d
# Started parsing the file under job_id 68b34385-2588-4493-800d-77fd9a2bf46c
# Started parsing the file under job_id b12ea482-e594-48db-9e65-d803cb2f05a2
# Started parsing the file under job_id 319e778d-cd19-4e3f-8301-4b0beae1f1e3
# Started parsing the file under job_id a3e888c2-81fc-4e47-912f-33c82f329b9b
# Started parsing the file under job_id a42d7587-0646-4e62-9cbd-10553c694c2b
# Started parsing the file under job_id a61ea9bf-f752-4b82-93c1-1ca517680cd4
# Started parsing the file under job_id 44983db5-3187-4984-8d2e-707536dc680d
# Started parsing the file under job_id 36204ae4-b775-4c56-8148-c4b527c43cf9
# Started parsing the file under job_id 3a2dc597-1738-4385-b9f7-4fef722e3829
# Started parsing the file under job_id 0ab3c2b0-a201-4425-ae56-98f17f3fa3d1
# Started parsing the file under job_id 5810158f-5043-4ebe-9526-11603959e1c1
# Started parsing the file under job_id 04877081-b2df-44ee-8d84-d392e8c3de43
# Started parsing the file under job_id 14a51985-2121-4847-a102-d49e69cc8cb0
# Started parsing the file under job_id 64ab4419-3ff2-4433-b654-cd7d517269e4
# Started parsing the file under job_id 186d4515-9c7e-4319-a3a9-82bfcadd6252
# Started parsing the file under job_id 3d85731a-c5f9-4e2a-a49b-23e9dcace22b
# Started parsing the file under job_id f21834cb-7629-49ea-9628-6826d262c43b
# Started parsing the file under job_id a2a351c3-cd6b-43e2-ad39-1b43455090cd
# Started parsing the file under job_id 67693b55-ce2f-4989-a54c-3d0cc8907a22
# Started parsing the file under job_id 3cb67cc4-da93-419f-9358-3ed129210bbd
# Started parsing the file under job_id 718a8503-6d15-4089-967d-2fc6d1396254
# Started parsing the file under job_id 6da3a685-c63a-4d13-b269-4b278acd4aec
# Started parsing the file under job_id 414bfb89-d387-49d3-823a-b020fa5c6bd9
# Started parsing the file under job_id dfaa30cd-8af2-44f7-b5c4-1792b62550e4
# Started parsing the file under job_id df2844be-ec7c-40ac-9433-19779e067127
# Started parsing the file under job_id 54f8fb91-5689-4aff-9bc6-5620dbdce699
# Started parsing the file under job_id ffeede99-6cb7-473d-b15f-933115af2e8c
# Started parsing the file under job_id dea196a6-0967-48d9-a190-316be8ff4ec5
# Started parsing the file under job_id e0b04c19-4a48-4ee3-89dc-a1e245c352d5
# Started parsing the file under job_id 444a479f-d15f-4cc4-a178-a7a8300f7e52
# Started parsing the file under job_id 91537c9a-0afd-44db-8358-a95d6fd92c0a
# Started parsing the file under job_id a13bb677-2b61-46d9-b1c3-6905d4730b9c
# Started parsing the file under job_id 1ddc064d-51a5-427e-a24a-6ba208223a28
# Started parsing the file under job_id 607f6e62-5a4a-49e0-bedf-9824c3363fc9
# Started parsing the file under job_id 5fd761e4-4886-4b2e-af51-eb0e70b65b6f
# Started parsing the file under job_id 56012422-cad9-4713-b12d-3dfd47caab62
# Started parsing the file under job_id 80537a71-d383-422e-b314-1a29984a94b1
# Started parsing the file under job_id a1d336d3-5c53-42cd-b3e1-532caecc8515
# Started parsing the file under job_id 0b7a7982-fd0a-4180-8108-b0e062177cf2
# Started parsing the file under job_id 176c09c2-833f-4f9e-8527-198b74420be9
# Started parsing the file under job_id cfefbb23-ffd1-4cc6-8b91-705f92d811ec
# Started parsing the file under job_id 5d165135-ec46-4479-aab2-84aeb233f662
# Started parsing the file under job_id 2a6b3a03-d022-40ac-8809-200378b520be
# Started parsing the file under job_id 65b61084-ced0-4406-bd19-6ba08cfb0e47
# Started parsing the file under job_id ae23ae5e-3376-4d71-a7dc-ad695ed2fdea
# Started parsing the file under job_id cd87e259-abdd-497b-8826-a6e0cfc78ee6
# Started parsing the file under job_id b83c7a0f-5e36-4855-ba94-e74a5db8f6df
# Started parsing the file under job_id 2d19fae5-3901-4938-9aff-eb2ef5c5f6af
# Started parsing the file under job_id 18225dfc-776a-45ae-a917-4027b2dde245
# Started parsing the file under job_id 0d77e78a-c82c-40d2-8c19-2d7c99d206fa
# Started parsing the file under job_id efe47c55-e0e4-4db6-a0e1-b700f2842e40
# Started parsing the file under job_id ad5db03d-978d-4fc7-9514-f78a0311f2ab
# Started parsing the file under job_id ce33f0a5-102e-47db-8a42-130010b1858b
# Started parsing the file under job_id 1ebbb399-1666-40fd-881d-f97d472f4f1d
# Started parsing the file under job_id 05d93ecf-5e17-43e2-935a-8914bb52cd3d
# Started parsing the file under job_id 8d974fc6-05e1-49ba-a578-1f9d6585a9b7
# Started parsing the file under job_id 0f79c87d-d135-46cb-a209-268862397a66
# Started parsing the file under job_id 6f992c9e-0c1e-4674-a451-c2cb0d8c4c5d
# Started parsing the file under job_id 51808e82-a09d-46c2-8072-8471c47f9ba1
# Started parsing the file under job_id 29e4e50a-c5aa-4409-8b5b-5a8e8affd56f
# Started parsing the file under job_id 25b3c750-2503-4d33-9988-206e44aa0b1f
# Started parsing the file under job_id 749eab86-8822-46bb-bb48-0b82378f2af7
# Started parsing the file under job_id 922c07fe-98d0-48ff-92c2-d0719a6c2e90
# Started parsing the file under job_id a29131a0-da36-4450-8bdd-2a99007191d3
# Started parsing the file under job_id 86cd142e-7cfd-48d3-a749-fec1fb964282
# Started parsing the file under job_id 8d87b752-13fe-4492-8639-fac5ab16ec15
# Started parsing the file under job_id fdf883ab-35ec-4d09-b425-97903dabbaf9
# Started parsing the file under job_id 4f981922-d885-435b-bd79-09af93ca3f76
# Started parsing the file under job_id d3686fc8-1c9e-478f-ae7c-969d5bf7c768
# Started parsing the file under job_id 13ff0df6-de12-4faa-aff1-79ad8505f585
# Started parsing the file under job_id a475ca6c-4270-40f2-9261-58c2508aef37
# Started parsing the file under job_id 560ec318-a1dd-4855-a6ae-654eb362b62d
# Started parsing the file under job_id dc273841-29fc-4d6e-9d03-ddb65ec7a467
# Started parsing the file under job_id 4bc69b74-06b5-4ec2-865c-ea41ff21d824
# Started parsing the file under job_id 371ba0ff-1a67-4591-87df-e1c3b749f198
# Started parsing the file under job_id c19eb2b3-dbb3-4433-9b79-06ce15bbc765
# Started parsing the file under job_id 5f327a32-c0a0-45ac-929c-13fe16ce9c0a
# Started parsing the file under job_id 8a295bae-d0de-4849-b23f-c96ddd64c208
# Started parsing the file under job_id 0b814d0e-445c-4fe7-8a22-9db0749f7b58
# Started parsing the file under job_id ef4ed608-cf14-4a86-909e-8e1ade0f3702
# Started parsing the file under job_id 9524bb6b-e4ab-4eb1-8546-14d3925b37d2
# Started parsing the file under job_id 4f7c54ca-9a26-4ec5-b3fc-e8e2ef33d38c
# Started parsing the file under job_id 85b0df11-dfb8-4dbe-9d20-a7241108a257
# Started parsing the file under job_id c2d9a1c6-abd3-41d0-b229-743e003386b6
# Started parsing the file under job_id 37d42c66-90ee-46b9-840b-bc10c8b11384
# Started parsing the file under job_id 7973f701-3eba-4f4f-8630-e9a49c6f8266
# Started parsing the file under job_id c2446205-dcfc-4ada-914e-17b231f1f113
# Started parsing the file under job_id 6731122b-aacb-4bb6-ae04-b513d4f6bf87
# Started parsing the file under job_id 8267adf0-488f-41af-afd1-48c690b11519
# Started parsing the file under job_id 75e57d9f-9b08-4f76-af60-e395bc3231a2
# Started parsing the file under job_id 9cbf346e-a0cc-42c0-a1c0-d1589fd83dd2
# Started parsing the file under job_id 6aa495d3-2f6f-4e05-8ad6-b3d37ce5711a
# Started parsing the file under job_id 388f70dd-1e1d-45c7-8ac9-e427d9452808
# Started parsing the file under job_id 831be60e-8a74-4f36-8b06-3df8e24bce84
# Started parsing the file under job_id 5d70ef94-146f-4666-bc2a-985f2d00cc87
# Started parsing the file under job_id 5e0e79a4-e169-47ea-a082-1b348f136813
# Started parsing the file under job_id 0261db9b-d7bf-4bd6-a0dd-aa9a41eac958
# Started parsing the file under job_id 4151fcbd-52c1-4c42-97ef-5f5cfe79262d
# Started parsing the file under job_id fca6f343-4496-4941-92f7-072fc2b7c93a
# Started parsing the file under job_id 31193192-28b2-4610-bc95-3e10f3fd9e51
# Started parsing the file under job_id 78032136-0d9b-425e-8b74-fccdbfed3f9f
# Started parsing the file under job_id 59c39c1b-0858-416b-8637-7599c4f26e23
# Started parsing the file under job_id 9cf5090c-1c4f-4a5a-a26a-7264e07a39bb
# Started parsing the file under job_id 7fa11e08-76cd-4d17-a6eb-0849d68d2255
# Started parsing the file under job_id ed5321de-e0ae-4be6-a792-01c188422949
# Started parsing the file under job_id 2bc8192b-3f9e-483c-b80f-2ddaea83ba80
# Started parsing the file under job_id 924fd819-f53b-4bdd-8bff-1030ef328eba
# Started parsing the file under job_id f47786de-789d-4151-bd06-5b949c28a3d5
# Started parsing the file under job_id 586a8779-381f-4efa-8a09-79bb4a7e1b03
# Started parsing the file under job_id 3d3a3fdf-cace-4343-a2ef-9080564ec994
# Started parsing the file under job_id b5ca8ebd-5c2f-444a-8466-36c82638a233
# Started parsing the file under job_id 961af332-4b89-406a-b4c3-72a26a0686ff
# Started parsing the file under job_id 312847a8-3213-4591-801f-825eddad5b93
# Started parsing the file under job_id 9ccb2208-d905-4e10-a4da-9f0c2f0405ef
# Started parsing the file under job_id 60719a98-20ba-4026-b679-47e7eb3ee958
# Started parsing the file under job_id 715a59e1-3606-46e0-a511-003a02d59b6a
# Started parsing the file under job_id 8128812b-1b08-4bd3-ae50-22ddc32b253a
# Started parsing the file under job_id f3e4b8c8-8cc5-49e8-8483-474802095803
# Started parsing the file under job_id a2742099-a3f1-4c25-b4dc-4ffeec5cb506
# Started parsing the file under job_id 82ca854b-4fab-42ff-8302-58bfd8dfb044
# Started parsing the file under job_id 76611c43-da90-4dcd-8e3c-22e760af6bc3
# Started parsing the file under job_id cc8f3165-2408-479e-b55a-3783eef3c9c1
# Started parsing the file under job_id b5373b41-30c1-4829-bbc9-74107070d621
# Started parsing the file under job_id 640094b5-bda9-475a-8078-be5f94787e60
# Started parsing the file under job_id ca960276-d712-4a60-aabd-9e4474110db4
# Started parsing the file under job_id b7c428fd-22e2-489e-8c7c-e13f745468fd
# Started parsing the file under job_id 4f4f79e8-20f7-4447-96ed-d68fbcb45faf
# Started parsing the file under job_id d5e529b4-4062-4c63-bc0b-d6c9c38fb7bd
# Started parsing the file under job_id 9663fdec-88f5-48af-ba70-176c48ea14fe
# Started parsing the file under job_id 6223d491-0769-4974-89df-8056fa92ee8b
# Started parsing the file under job_id 4f2a967b-b8ee-4a1f-b9ac-987c6f50fbec
# Started parsing the file under job_id 1a2a7de9-7e4f-490f-9d07-a9282a4675e8
# Started parsing the file under job_id 0bf9156a-1895-4af2-8417-8777d3f42bb6
# Started parsing the file under job_id 500cc28a-7945-473d-a6c0-1c8eca44f300
# Started parsing the file under job_id 36e521c3-15b5-42ff-98a0-684430164971
# Started parsing the file under job_id 885b0035-81eb-4f07-b89e-b67d49d93c9b
# Started parsing the file under job_id 40216860-b50e-4349-a7ef-feb70ade2cc6
# Started parsing the file under job_id 98da2a1f-f4b1-487f-b015-8455f5976fa4
# Started parsing the file under job_id c01fd2be-7b89-4350-95b0-6e2c7484ee3e
# Started parsing the file under job_id 81c64693-5891-4735-999a-ddfad50f5ebc
# Started parsing the file under job_id 663a1b08-5033-4fa1-89a7-c468000f3ec9
# Started parsing the file under job_id 85d169b7-fdf3-45b7-971a-0a238a733d5c
# Started parsing the file under job_id 8eeaf7db-5b07-4f67-9008-006c8dfb151e
# Started parsing the file under job_id 7dc2c4e7-3e1f-4f0b-b181-123978ed5399
# Started parsing the file under job_id 5092eeed-b7d2-4ed6-8c6e-afae85b86095
# Started parsing the file under job_id 3e67f60a-e97f-4c0f-ab22-148d0c472a02
# Started parsing the file under job_id f80f2726-1fe8-4d2e-87cd-8e139ef36fa4
# Started parsing the file under job_id df0a2f66-9195-4b01-b31a-1e0174d2292b
# Started parsing the file under job_id c8b59ad4-7c95-410e-90b4-55e4b456ba98
# Started parsing the file under job_id 01698ae6-bda2-4594-becb-3eb442c03942
# Started parsing the file under job_id b00c8798-d59d-432e-a390-af8eec5a43e5
# Started parsing the file under job_id 35978629-f17b-4d58-9432-b33a0a384f91
# Started parsing the file under job_id 32d75f1f-63d8-4a60-ac19-f11aeabd2c07
# Started parsing the file under job_id a393c2a8-c79a-4027-baed-9484634a72db
# Started parsing the file under job_id 296b1adb-452c-4db0-afd0-0a178ea5e3c0
# Started parsing the file under job_id 3044ec7d-267d-4c8f-8856-622abde8b221
# Started parsing the file under job_id 603c3879-4a61-472e-b9b7-6b26a615e2e7
# Started parsing the file under job_id dc268ead-e14b-4877-8ff1-f44c0e761942
# Started parsing the file under job_id f9861ed3-a3e3-433b-86c5-931463c2d853
# Started parsing the file under job_id fdffc972-6fd5-4dac-8c6c-8405df09cc9e
# Started parsing the file under job_id 242df1e7-50b9-457f-bfde-5063fb9ba255
# Started parsing the file under job_id 9055036e-a6e5-4ed8-b106-e4aea4502bff
# Started parsing the file under job_id dd7c905d-4840-492c-913f-d314ae25d0e7
# Started parsing the file under job_id 04dd6d1f-4e76-4b5a-912f-edbf35654602
# Started parsing the file under job_id 06f138cd-1da8-482e-92cd-1c34b477cc64
# Started parsing the file under job_id f3963284-c3bc-42f2-9ec6-6e0962517a52
# Started parsing the file under job_id 784f71fd-4bfb-41a5-b11b-0ecb23daef9f
# Started parsing the file under job_id 230e5e6d-0f2d-44d4-8dcb-dee3960f96c8
# Started parsing the file under job_id 6e6f4b5d-03c7-4f68-b335-407c6e17da6f
# Started parsing the file under job_id 450de0f8-b564-45d5-a41c-852abf650be6
# Started parsing the file under job_id dfca4bda-2a6d-46de-870a-07c644a27928
# Started parsing the file under job_id 2605b935-94c3-442d-8823-8fd61ae04f90
# Started parsing the file under job_id eb06738d-7297-4c7b-9a57-64ea9e3cbe62
# Started parsing the file under job_id e8d9e0d3-fbc7-4704-b2c8-6c577c8b29db
# Started parsing the file under job_id 27153241-a576-49f4-b0b5-32b44a03acc9
# Started parsing the file under job_id b190abf4-8be3-463b-9093-c0119ec5c9e4
# Started parsing the file under job_id 44134c4e-ccf5-4155-ac63-7cd8a916449f
# Started parsing the file under job_id 9dc3349c-7514-4711-9e80-d048706189cf
# Started parsing the file under job_id 0cfd0ab9-b538-4c59-80bc-acf0d1ded31b
# Started parsing the file under job_id 6368abc2-9b5a-4c4f-a566-9d1992f098b6
# Started parsing the file under job_id b8433b29-0ca0-414a-a17a-74f1310c62f1
# Started parsing the file under job_id b8235df1-51d6-4eef-bc1f-ee8bb44cb2c9
# Started parsing the file under job_id 15fa158b-d3c0-44a0-baae-6f5f89635155
# Started parsing the file under job_id bfc3e42c-ac83-4dfc-aaeb-549fe6b5f4ce
# Started parsing the file under job_id 6e4cba88-8217-4e74-8930-8fb732c277bd
# Started parsing the file under job_id b92f806e-2e4b-4d62-9140-73e0c99959ed
# Started parsing the file under job_id 5c60ee67-2f2e-46f9-a6d6-c13dcc815826
# Started parsing the file under job_id f3c19f21-755a-47f5-997c-ab236f64beb1
# Started parsing the file under job_id 516d160a-c9ae-4fa1-acb0-bf4655ee4d4f
# Started parsing the file under job_id dddf3d03-86c5-4150-947d-7bb84db1bdf9
# Started parsing the file under job_id eac6e1e8-cc26-4b4a-a99b-3b799e2c838f
# Started parsing the file under job_id fdf0e083-bd24-4775-bcc9-1f6f39575026
# Started parsing the file under job_id 1e473d8a-ae70-4533-9717-3dc647cfb0fe
# Started parsing the file under job_id cbfba2d6-87f6-47af-8a67-ed13277340c3
# Started parsing the file under job_id 7fdb89e3-d06a-4bfd-b33d-6107ef39b84d
# Started parsing the file under job_id 243aa145-fc0c-4c3a-a3aa-bef9b0993ee0
# Started parsing the file under job_id 41180eba-ce48-4f76-9bd9-79ec541f93f6
# Started parsing the file under job_id 9f5933ab-db7e-430a-b968-7deb2cf9b24c
# Started parsing the file under job_id 3d39f7b1-06ac-4e30-8cca-310de2eac34c
# Started parsing the file under job_id f968b939-f914-4a21-a40e-5ae0ef398850
# Started parsing the file under job_id 1a490d7c-1526-48cb-be19-1327d882dd5f
# Started parsing the file under job_id 0cd36a36-9288-48b6-a8d4-5739b9e26839
# Started parsing the file under job_id b3d2c66b-0460-43e5-9426-36dd0820b5de
# Started parsing the file under job_id 62bcd52e-46b3-4b92-b7ee-7826b33b57cc
# Started parsing the file under job_id be08796e-d45c-43ba-b378-5168cfda545e
# Started parsing the file under job_id e0697217-8187-4fa9-83cd-386b49b9f3cb
# Started parsing the file under job_id b8628cf4-426c-4da7-9b41-aa79d77ffa62
# Started parsing the file under job_id 8ebfff4b-7a58-4642-b3e7-cb05c7325f9b
# Started parsing the file under job_id 4f090917-8818-4745-af3b-8e2924a7095d
# Started parsing the file under job_id 3c4855e2-24bc-427c-b33d-69f50d810757
# Started parsing the file under job_id 06d6f360-b122-4bab-9749-77a75560677b
# Started parsing the file under job_id 91a234c6-4464-4e93-b9df-6bcdc8da6a36
# Started parsing the file under job_id 92e1c869-0c22-4a59-a11c-2a1b8340baed
# Started parsing the file under job_id c85d5d1b-059f-4526-9c97-7876a088cefd
# Started parsing the file under job_id 5dedaae2-530d-4978-8df7-f9745f63fef6
# Started parsing the file under job_id 919a1059-53a2-4301-af92-64a95e7a0ad6
# Started parsing the file under job_id 36daa443-255c-42a3-aa97-54ad0fde3814
# Started parsing the file under job_id 17aec834-cc9f-47b1-9ed6-b57153fae83c
# Started parsing the file under job_id d0d17ee3-2dce-429c-8a7c-3c20609e819c
# Started parsing the file under job_id 1fd0d3c0-251c-4b31-b7f7-74308f3bdbfa
# Started parsing the file under job_id ed4e59c6-162e-4b09-8791-31c62844a9de
# Started parsing the file under job_id 2d17ce72-2546-42c0-87f0-a489265c09ea
# Started parsing the file under job_id b3606575-c0d4-43c5-82ad-62527cf388ee
# Started parsing the file under job_id 70457ec9-c0d3-469c-92cc-c325f3558d97
# Started parsing the file under job_id 5d5f0fe1-3ec4-4a3a-bbf9-ed7c51b32c6f
# Started parsing the file under job_id 0dd55af5-2856-4a6d-8c4f-03839863042c
# Started parsing the file under job_id f5f127ef-0082-4770-8afb-ee6848ace034
# Started parsing the file under job_id 7abf1ee9-e341-4a2e-aea6-951420e46555
# Started parsing the file under job_id 1ff79e5c-3af5-4b8c-a231-9890ce30a160
# Started parsing the file under job_id b0ae702c-c2ab-478e-9572-d5f0947b7488
# Started parsing the file under job_id b226ae16-e5bb-495a-a0f0-8008f35a30d9
# Started parsing the file under job_id 3c0e6fd2-5ea7-4862-a4cb-5f629c731bda
# Started parsing the file under job_id 9a9bde76-852c-4f82-a98a-d3cfdea06d86
# Started parsing the file under job_id 143e2f62-b593-4c3f-a379-545532b20ecb
# Started parsing the file under job_id 3413e25a-5651-4068-b856-a7c5365f78d2
# Started parsing the file under job_id 6e5b40fd-de96-49b7-a428-396703d0fc5d
# Started parsing the file under job_id f7c2b551-387d-491c-bda3-5ab17025ee7e
# Started parsing the file under job_id dcc3a836-9483-451a-97de-ae6db957921c
# Started parsing the file under job_id 7149e1cf-1df1-4ffd-82b5-7eaaa081bdae
# Started parsing the file under job_id b0246008-e29a-428c-a48a-e7f0a804b5e2
# Started parsing the file under job_id 55cb567d-508e-4d16-9da8-65398af0fbb7
# Started parsing the file under job_id 568ed15c-bf64-47da-bc93-188752ceaa34
# Started parsing the file under job_id bfde1acf-11d1-4541-b8fa-2a8cf1cc51db
# Started parsing the file under job_id dd8a1899-2c28-4c66-a8e2-3b6aebf6a2c9
# Started parsing the file under job_id a760193d-178b-4d45-9cf6-989008651b6b
# Started parsing the file under job_id 9de65e36-fead-4571-a9df-889563b0af25
# Started parsing the file under job_id d0495f9d-8211-4e72-8e30-c1685e8da1b1
# Started parsing the file under job_id 5b57773a-6a6d-4f4d-a97f-2d2d4c53dd01
# Started parsing the file under job_id d1b48b72-91a7-421f-af80-ca1b4dc553d6
# Started parsing the file under job_id ad0e0d0d-fec4-40be-9040-cd633caf77ad
# Started parsing the file under job_id 387b5a78-703a-4650-9c6c-36c09ac8e9b7
# Started parsing the file under job_id 7a7af79c-7f36-42b1-8c4b-362d4a0b3ecc
# Started parsing the file under job_id 37cabfad-8a58-46e9-b4bd-1ef3a33f8531
# Started parsing the file under job_id ae69743d-c998-4a4f-b018-9c895d1d94a0
# Started parsing the file under job_id f3d23da8-d82a-4fc1-93ac-22e299f22f55
# Started parsing the file under job_id ec750c21-6179-4dcf-82fe-ba88332a8f3f
# Started parsing the file under job_id 1fd2c35d-b96e-4051-9ae0-bf3d692a960b
# Started parsing the file under job_id ce45148b-84ae-4c99-b95a-0397e6d19ccb
# Started parsing the file under job_id e782dbf9-db85-4299-b58e-e7787e9474e7
# Started parsing the file under job_id 77f32924-c4b6-44cc-86c7-43b36d5fc908
# Started parsing the file under job_id cbbabff2-1583-494a-9a60-881c04fecdbc
# Started parsing the file under job_id 095e1e97-2695-43d7-a3aa-9af946af0f33
# Started parsing the file under job_id 67162201-99a7-4f0c-b5fb-d1a5293ae8bd
# Started parsing the file under job_id 704e48d0-0ba0-4817-a3ee-4f2321eaf892
# Started parsing the file under job_id dfcb770f-c593-454c-96a0-3a512dd996c2
# Started parsing the file under job_id 32ce3c7b-4208-42a0-a329-66a531ad855c
# Started parsing the file under job_id ac5fa9c4-3e1c-4388-aa2d-a2fb493aebd7
# Started parsing the file under job_id 7170d5b7-6c3e-43d7-8c01-1a8957ba5d76
# Started parsing the file under job_id 15e571fa-d981-4c93-bca1-4a88fcab6509
# Started parsing the file under job_id 38546c05-a8ad-4077-ab75-d43a87246097
# Started parsing the file under job_id e6c3eafc-5656-4e51-bd66-622a87ff619b
# Started parsing the file under job_id acf74160-bac0-419d-8e59-7d1d682ca21b
# Started parsing the file under job_id a96121fa-c933-4bd3-81b7-cd26f098c3ee
# Started parsing the file under job_id e0eabb09-220b-47b9-b69f-544810b9fbac
# Started parsing the file under job_id 2520ae66-596b-4b75-9632-8c547f966290
# Started parsing the file under job_id 4d73becc-5586-41f0-b2de-52c2e6d3a3a2
# Started parsing the file under job_id 34bb3f8c-ecfb-4395-961e-afdd29c9821f
# Started parsing the file under job_id 3b03378d-ac5c-4f2a-98df-78d1d37e795f
# Started parsing the file under job_id fedab6af-6982-4a39-ba85-341c80fa2092
# Started parsing the file under job_id aac3f8c0-d687-4a94-991f-1c21c883189c
# Started parsing the file under job_id bc553097-47f3-4370-95fa-ca62857f2ab0
# Started parsing the file under job_id 82d59993-73d6-4445-aabc-3ead18d75667
# Started parsing the file under job_id 3d8da04d-92cb-4d30-8c85-332a8540538a
# Started parsing the file under job_id 95b61677-4e5b-423a-acb8-f7a15d721188
# Started parsing the file under job_id 756ca77f-3798-4e36-b3d1-68850ab55026
# Started parsing the file under job_id e9f2f658-ffa0-4505-8633-612565e81a04
# Started parsing the file under job_id 4767d17e-a488-49b3-9a1c-99b63967b4e7
# Started parsing the file under job_id 9dc41934-c8a6-4c80-abda-3741f97fe7e8
# Started parsing the file under job_id 7fbb28f8-81db-4359-bbd6-d70d85777c49
# Started parsing the file under job_id 3b1db433-630c-4173-b2c1-d659e7d04fb4
# Started parsing the file under job_id 818cd0c9-e03a-4f1b-bf62-3146a5e01e52
# Started parsing the file under job_id f50d0b4c-c2ea-4c17-b8a6-5c4c086c5006
# Started parsing the file under job_id 21156639-d4e0-4a90-bdb6-e5c2ad59dad6
# Started parsing the file under job_id 97f96861-6693-4338-b88d-96b22c1583ed
# Started parsing the file under job_id a3fa332d-41d7-4b07-b233-1e6d42b67ee3
# Started parsing the file under job_id b3dc67c9-9d9d-4ced-96ba-5990571f0603
# Started parsing the file under job_id f6c57ebe-a0c2-477a-8ba7-d0d98f90f72a
# Started parsing the file under job_id c35de5e4-dbaa-454a-8070-6e9002c4b719
# Started parsing the file under job_id 761f5f01-5971-4445-8836-e0e990bf795d
# Started parsing the file under job_id 393658e5-1994-4dc4-a3bc-92a858ef575e
# Started parsing the file under job_id 1af522ec-3abe-45a0-ad1c-e3d121bd05b6
# Started parsing the file under job_id d8304f68-8947-429b-9bf6-461a49da4dae
# Started parsing the file under job_id 494be2a7-8a4f-4320-a493-36f16769af28
# Started parsing the file under job_id ed616e0a-1b51-425b-8a56-a5c7c22acfd4
# Started parsing the file under job_id 53607110-5c32-4b14-997f-8f40bd3a4470
# Started parsing the file under job_id 16a04131-2e77-4ade-b1f0-db50039c2451
# Started parsing the file under job_id 4e156aad-2d06-4a92-bfff-2673c6fbd2fa
# Started parsing the file under job_id e8694069-7bdc-435a-ae8f-bcfe0c000477
# Started parsing the file under job_id 44d0c95b-2fdc-4022-a20f-5596d90016cd
# Started parsing the file under job_id a68076db-a20e-4494-8c7e-e4420a02922f
# Started parsing the file under job_id 0ea05574-a6a0-4eb7-bf53-dee7eef09f55
# Started parsing the file under job_id 900ef0bf-e20f-4f21-9afb-e0c17a53c80d
# Started parsing the file under job_id f54d0207-d64f-42d9-8e48-356fd369cb6a
# Started parsing the file under job_id fa842053-d6ea-4a3c-a0b7-eba2d1b99a5a
# Started parsing the file under job_id 7e1ce205-67d1-46b0-aa09-87b3eb2483be
# Started parsing the file under job_id e9ce38bd-b72f-4712-b42c-58a0cb6bff4f
# Started parsing the file under job_id 1a76cdb2-596f-4ba1-9721-945815845d38
# Started parsing the file under job_id 9f1db0df-dcd8-4b4a-b659-bd78fa15d47d
# Started parsing the file under job_id b475dac7-c328-470f-a266-d868e332eb86
# Started parsing the file under job_id 7d1140f2-f1ae-4ae5-8d23-ff8c731ad132
# Started parsing the file under job_id 81220986-eb7a-471a-acc5-899b3032aa49
# Started parsing the file under job_id 91f414d5-a3c6-4c47-a3d5-b054d44d4470
# Started parsing the file under job_id afec5f8f-7479-4970-9bbd-502192ce99a0
# Started parsing the file under job_id b93aabe5-211d-4719-8994-52df65aef7b9
# Started parsing the file under job_id 3460169e-56d6-4e78-8b2f-4084cca2db66
# Started parsing the file under job_id 958a6cf4-58cf-4a9a-b46b-d05ae3bddabb
# Started parsing the file under job_id a100ef07-26dd-4cab-938b-3c9521aa9931
# Started parsing the file under job_id 1e95b117-57c9-4699-bba0-e532e7a94879
# Started parsing the file under job_id f8ecdfc1-edc9-4c18-956b-2f2261b111ba
# Started parsing the file under job_id 479145e2-2b05-48a6-b4d5-c56eff8d5698
# Started parsing the file under job_id fa3e7a9a-2e9f-4aba-a742-3a21caae3bc9
# Started parsing the file under job_id ca9e6912-a55b-4329-bffc-595f06c4fd2f
# Started parsing the file under job_id c7a76c25-0d56-44ec-b070-9300f9df874c
# Started parsing the file under job_id 12c6cf22-cd4e-4989-a7a5-e7e331f8d334
# Started parsing the file under job_id ad4fc843-6658-46dc-bf76-129a639f71b5
# Started parsing the file under job_id d8bb0f4b-9bc5-4ed4-ab1f-25ad668cfc9d
# Started parsing the file under job_id 720e5e71-6682-457a-8550-eb620f07de09
# Started parsing the file under job_id 025b415c-3c73-4349-8aa8-9c739f71203e
# Started parsing the file under job_id 5f3ce2d6-4976-4d31-ba4a-d4d47a0037b1
# Started parsing the file under job_id 4e0460c5-61c8-4e44-a4e4-290c014b8f86
# Started parsing the file under job_id cf07e4df-6bbc-4e4d-a3f3-3078532b7b57
# Started parsing the file under job_id 154f2bf1-e844-4aa8-9c24-4ed351a8da49
# Started parsing the file under job_id ba32fb0f-9a65-4eb2-881d-08ccdd6951d4
# Started parsing the file under job_id 99df3d66-e7d5-4542-9437-aab3107f27b4
# Started parsing the file under job_id 0d0ad3cb-9253-4a0e-b338-fc6881927056
# Started parsing the file under job_id 7f068522-9878-47b1-9df3-c7cdd7ee2591
# Started parsing the file under job_id a3c6716b-748f-4573-8c41-9ac37fd60738
# Started parsing the file under job_id bb2dcdb1-bbf5-428b-91e6-869442b5ccc7
# Started parsing the file under job_id 03a487ff-01fd-4042-a5fe-5c3088ddc5fd
# Started parsing the file under job_id e5e33ac5-c98c-4866-af81-ada4600a7d50
# Started parsing the file under job_id 6882cef9-48d0-4efc-ae87-da84f6ed18f5
# Started parsing the file under job_id 21490928-4ed3-40d9-b654-1fff8844ea94
# Started parsing the file under job_id 2e599144-11ce-4293-bbc6-67d1f57ac5f4
# Started parsing the file under job_id b385b6f1-5c98-4b87-8208-4cf469336e5c
# Started parsing the file under job_id fc60b4f7-9912-4ea8-8f9a-7d6c86513c4c
# Started parsing the file under job_id 34d85238-4c10-4d89-8b55-a49dfa084b89
# Started parsing the file under job_id f7d9de7e-cfd8-4a5f-b037-56819933e898
# Started parsing the file under job_id c440e03e-0958-419b-80f6-43cdf71e9725
# Started parsing the file under job_id 148d02e3-01d8-4e1d-929d-ace61c09818f
# Started parsing the file under job_id 81340cef-70f7-44b3-97d1-77b6d5596720
# Started parsing the file under job_id 7d29ff6e-dc8b-44e0-9aeb-741f88f1dba9
# Started parsing the file under job_id 2f5e182f-8ac5-4477-9749-440dd120c542
# Started parsing the file under job_id c4d6ec22-dd3b-4dce-b3ae-1b5be885e4f4
# Started parsing the file under job_id fbd03f5f-b7cd-4ecf-a8b2-ec2eb2b15176
# Started parsing the file under job_id dda006f8-6b4c-4eab-ac6d-58e85fef2cbd
# Started parsing the file under job_id 5d976279-8a7d-46f8-a9f6-1e6c04b315cb
# Started parsing the file under job_id 5489118e-2a8b-4afb-a2ac-1dda8fdd6578
# Started parsing the file under job_id 9a526513-a378-44cc-a356-eab7b9f845aa
# Started parsing the file under job_id 8775c4e9-f64f-4342-b95e-6a17d44ad6ee
# Started parsing the file under job_id ab6894c5-5da8-4656-ae6d-e694103dd338
# Started parsing the file under job_id 73400fbf-1bd6-4322-ab11-9dada6cc479c
# Started parsing the file under job_id b905e7ab-f318-4b49-961b-a6f835c3121d
# Started parsing the file under job_id ba911c55-ce79-4111-ab2a-2972c699957f
# Started parsing the file under job_id c0a16d71-d0c1-43ed-a04c-a9f2d0456599
# Started parsing the file under job_id 94c2ba5a-c6d4-4459-bdd4-9e2f09611fd3
# Started parsing the file under job_id d4849f00-a913-49cf-878f-3c8e990a62b3
# Started parsing the file under job_id 6485ec26-619a-4896-9346-87ab08d46da2
# Started parsing the file under job_id 674102b9-3d5b-4ed0-8521-8662d4758687
# Started parsing the file under job_id cb87a9d0-91d6-44e8-bdd7-d98778438b6c
# Started parsing the file under job_id e6436335-8e20-405b-a593-4c50eb5bb1e8
# Started parsing the file under job_id 377a6e1b-8fef-4b06-8a90-f9d43ee8166b
# Started parsing the file under job_id a0ae77cb-afb8-43e7-a68f-041685c8f109
# Started parsing the file under job_id f3457a4d-996d-48ef-bcbf-6222eecb3a86
# Started parsing the file under job_id 5de4510c-8bbc-4cab-94d9-77ae7c788079
# Started parsing the file under job_id 875af455-a318-4276-8f1c-a8a352fcb459
# Started parsing the file under job_id f32b5225-eab6-4ed9-a120-428ce62e0379
# Started parsing the file under job_id e3805929-a9e3-4d8a-82ac-03df8181a13b
# Started parsing the file under job_id 74ffc192-1ef0-48f2-a14c-30fc5e626c73
# Started parsing the file under job_id 59b16ca0-6fe5-4b18-ae43-fdce154ee8bb
# Started parsing the file under job_id 307114a6-af8f-40f9-808e-bf40fdae8e4e
# Started parsing the file under job_id ea7510c4-b4c6-4f82-9c80-859de0888b9e
# Started parsing the file under job_id 0adb0bae-55ff-4147-8875-5e192230e596
# Started parsing the file under job_id c65c1466-86a8-4cf3-8d53-9848d1730dde
# Started parsing the file under job_id 27449ae3-945e-4045-9961-da8d40077575
# Started parsing the file under job_id dfebb82f-4252-47dc-9a54-939d92dfead2
# Started parsing the file under job_id 9268fa63-172b-49dd-b622-b74b66aa465c
# Started parsing the file under job_id 1c60e91f-a804-4a93-9987-4490bc521afa
# Started parsing the file under job_id 06382e36-359d-4a5d-8aef-550d697ef878
# Started parsing the file under job_id df3daf83-61f8-468e-bdc7-868f01e5fb51
# Started parsing the file under job_id 8201a85c-02f6-4356-bb3b-c9cfea29c97a
# Started parsing the file under job_id f0a75a24-ae73-465e-9bd1-61fdf5b228d4
# Started parsing the file under job_id cb893ebf-6585-4cf4-8ddc-bedd8af07d2f
# Started parsing the file under job_id 76f3d881-b37b-450f-9df7-0b6f3e741aea
# Started parsing the file under job_id 8feb621b-9df8-4562-a472-a8b2139b144d
# Started parsing the file under job_id 69465601-1b67-4ac4-a121-da3acfb7dd76
# Started parsing the file under job_id f6bf4b72-8b4a-4349-80f7-f161cb730651
# Started parsing the file under job_id 57ccc1da-d0ee-4d49-8adc-ee09a69c2392
# Started parsing the file under job_id 451fd5d0-f403-4597-a7e1-353da3f98659
# Started parsing the file under job_id 084e8540-27b4-4ab0-9e40-58cdf15b608d
# Started parsing the file under job_id fe3dfaee-63d5-4dcc-ad68-2e43db7fc51d
# Started parsing the file under job_id cb6a4779-d7ec-42f2-82f8-06369b27ea1c
# Started parsing the file under job_id cf854a2d-1b6f-4e10-84c8-c82fddbaada4
# Started parsing the file under job_id e7febc99-b42b-43a0-ba3f-4ca1632ac745
# Started parsing the file under job_id 75388e62-ad92-4392-a7b0-b56bb8a1fe37
# Started parsing the file under job_id 1d98538b-6080-4c5b-a04b-69939b5d5c3a
# Started parsing the file under job_id 1643543b-29ef-45c9-a4eb-a053e369fae5
# Started parsing the file under job_id 03b3c3e4-9521-4e41-a909-e10fefc998e3
# Started parsing the file under job_id 952c1f4f-c458-4845-85f7-c7dbec3d0661

# %% [markdown]
# # Modify Json
# - parsing_result
# - metadata: {
#     "model":,
#     "page":
#     }

# %%
import os
import re
import json
from glob import glob

import sys
sys.path.append('../') 
from CameraDocument import CameraDocument

# %%
def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

# %%
camera_model = "gfx100ii"
json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "init_result")
init_json_path = os.path.join(detail_json_dir, "*.json")

json_list = glob(init_json_path)
json_list = sorted(json_list, key=extract_number)

# %%
output_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for json_path in json_list:
    doc = CameraDocument()

    page_num = extract_number(json_path)
    if page_num >= 29:
        real_page_num = page_num - 28
        doc.metadata['page'] = real_page_num
        basename = camera_model + f"_page{real_page_num}.json"
        output_path = os.path.join(output_dir, basename)
    else:
        doc.metadata['page'] = page_num
        basename = camera_model + f"_front_page{page_num}.json"
        front_output_dir = os.path.join(output_dir, "front_page")
        output_path = os.path.join(front_output_dir, basename)
        if not os.path.exists(front_output_dir):
            os.makedirs(front_output_dir)

    doc.metadata['model'] = camera_model

    with open(json_path, "r", encoding="utf-8") as file:
        json_data = json.load(file)
        doc.parsing_result = json_data["pages"][0]["md"]
        doc.save_json(output_path)
# Out:
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page1.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page2.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page3.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page4.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page5.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page6.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page7.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page8.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page9.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page10.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page11.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page12.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page13.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page14.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page15.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page16.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page17.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page18.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page19.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page20.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page21.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page22.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page23.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page24.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page25.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page26.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page27.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/front_page/gfx100ii_front_page28.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page1.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page2.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page3.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page4.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page5.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page6.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page7.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page8.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page9.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page10.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page11.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page12.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page13.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page14.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page15.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page16.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page17.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page18.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page19.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page20.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page21.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page22.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page23.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page24.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page25.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page26.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page27.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page28.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page29.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page30.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page31.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page32.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page33.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page34.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page35.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page36.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page37.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page38.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page39.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page40.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page41.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page42.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page43.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page44.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page45.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page46.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page47.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page48.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page49.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page50.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page51.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page52.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page53.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page54.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page55.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page56.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page57.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page58.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page59.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page60.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page61.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page62.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page63.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page64.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page65.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page66.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page67.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page68.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page69.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page70.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page71.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page72.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page73.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page74.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page75.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page76.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page77.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page78.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page79.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page80.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page81.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page82.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page83.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page84.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page85.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page86.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page87.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page88.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page89.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page90.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page91.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page92.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page93.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page94.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page95.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page96.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page97.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page98.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page99.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page100.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page101.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page102.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page103.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page104.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page105.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page106.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page107.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page108.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page109.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page110.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page111.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page112.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page113.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page114.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page115.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page116.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page117.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page118.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page119.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page120.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page121.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page122.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page123.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page124.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page125.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page126.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page127.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page128.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page129.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page130.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page131.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page132.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page133.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page134.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page135.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page136.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page137.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page138.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page139.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page140.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page141.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page142.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page143.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page144.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page145.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page146.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page147.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page148.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page149.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page150.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page151.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page152.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page153.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page154.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page155.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page156.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page157.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page158.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page159.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page160.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page161.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page162.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page163.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page164.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page165.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page166.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page167.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page168.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page169.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page170.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page171.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page172.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page173.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page174.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page175.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page176.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page177.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page178.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page179.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page180.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page181.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page182.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page183.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page184.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page185.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page186.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page187.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page188.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page189.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page190.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page191.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page192.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page193.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page194.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page195.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page196.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page197.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page198.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page199.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page200.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page201.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page202.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page203.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page204.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page205.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page206.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page207.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page208.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page209.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page210.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page211.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page212.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page213.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page214.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page215.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page216.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page217.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page218.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page219.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page220.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page221.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page222.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page223.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page224.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page225.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page226.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page227.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page228.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page229.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page230.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page231.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page232.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page233.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page234.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page235.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page236.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page237.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page238.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page239.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page240.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page241.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page242.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page243.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page244.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page245.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page246.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page247.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page248.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page249.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page250.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page251.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page252.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page253.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page254.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page255.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page256.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page257.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page258.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page259.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page260.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page261.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page262.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page263.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page264.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page265.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page266.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page267.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page268.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page269.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page270.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page271.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page272.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page273.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page274.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page275.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page276.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page277.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page278.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page279.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page280.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page281.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page282.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page283.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page284.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page285.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page286.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page287.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page288.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page289.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page290.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page291.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page292.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page293.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page294.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page295.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page296.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page297.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page298.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page299.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page300.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page301.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page302.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page303.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page304.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page305.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page306.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page307.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page308.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page309.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page310.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page311.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page312.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page313.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page314.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page315.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page316.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page317.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page318.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page319.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page320.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page321.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page322.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page323.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page324.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page325.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page326.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page327.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page328.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page329.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page330.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page331.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page332.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page333.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page334.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page335.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page336.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page337.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page338.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page339.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page340.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page341.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page342.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page343.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page344.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page345.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page346.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page347.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page348.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page349.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page350.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page351.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page352.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page353.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page354.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page355.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page356.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page357.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page358.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page359.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page360.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page361.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page362.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page363.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page364.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page365.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page366.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page367.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page368.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page369.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page370.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page371.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page372.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page373.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page374.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page375.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page376.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page377.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page378.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page379.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page380.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page381.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page382.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page383.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page384.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page385.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page386.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page387.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page388.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page389.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page390.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page391.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page392.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page393.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page394.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page395.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page396.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page397.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page398.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page399.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page400.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page401.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page402.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page403.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page404.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page405.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page406.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page407.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page408.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page409.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page410.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page411.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page412.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page413.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page414.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page415.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page416.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page417.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page418.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page419.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page420.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page421.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page422.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page423.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page424.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page425.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page426.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page427.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page428.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page429.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page430.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page431.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page432.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page433.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page434.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page435.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page436.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page437.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page438.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page439.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page440.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page441.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page442.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page443.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page444.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page445.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page446.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page447.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page448.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page449.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page450.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page451.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page452.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page453.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page454.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page455.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page456.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page457.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page458.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page459.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page460.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page461.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page462.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page463.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page464.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page465.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page466.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page467.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page468.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page469.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page470.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page471.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/add_metadata/gfx100ii_page472.json complete

# %% [markdown]
# # Index page to .png

# %%
import os
import fitz

# %%
def extract_pages_as_images(pdf_path, output_folder, start_page, end_page, dpi=600):
    pdf_document = fitz.open(pdf_path)

    # Loop through the specified page range
    for page_number in range(start_page - 1, end_page):
        # Check if the page number is within bounds
        if page_number < 0 or page_number >= len(pdf_document):
            print(f"Page {page_number + 1} is out of range. Skipping.")
            continue

        # Load the page
        page = pdf_document[page_number]

        # Render the page to a pixmap with specified DPI
        pix = page.get_pixmap(dpi=dpi)

        # Define the output image path
        output_path = f"{output_folder}/{camera_model}_page{page_number + 1}.png"

        # Save the image
        pix.save(output_path)
        print(f"Saved page {page_number + 1} as {output_path}")

    # Close the PDF document
    pdf_document.close()

# %%
camera_model = 'gfx100ii'
image_dir = '../data/image'
output_dir = os.path.join(image_dir, camera_model, "index_images")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
pdf_path = f"../data/raw_data/{camera_model}/{camera_model}.pdf"

# %%
extract_pages_as_images(pdf_path, output_dir, 13, 26, 600)
# Out:
# Saved page 13 as ../data/image/gfx100ii/index_images/gfx100ii_page13.png
# Saved page 14 as ../data/image/gfx100ii/index_images/gfx100ii_page14.png
# Saved page 15 as ../data/image/gfx100ii/index_images/gfx100ii_page15.png
# Saved page 16 as ../data/image/gfx100ii/index_images/gfx100ii_page16.png
# Saved page 17 as ../data/image/gfx100ii/index_images/gfx100ii_page17.png
# Saved page 18 as ../data/image/gfx100ii/index_images/gfx100ii_page18.png
# Saved page 19 as ../data/image/gfx100ii/index_images/gfx100ii_page19.png
# Saved page 20 as ../data/image/gfx100ii/index_images/gfx100ii_page20.png
# Saved page 21 as ../data/image/gfx100ii/index_images/gfx100ii_page21.png
# Saved page 22 as ../data/image/gfx100ii/index_images/gfx100ii_page22.png
# Saved page 23 as ../data/image/gfx100ii/index_images/gfx100ii_page23.png
# Saved page 24 as ../data/image/gfx100ii/index_images/gfx100ii_page24.png
# Saved page 25 as ../data/image/gfx100ii/index_images/gfx100ii_page25.png
# Saved page 26 as ../data/image/gfx100ii/index_images/gfx100ii_page26.png

# %% [markdown]
# # Delete
# - chapter cover page
# - memo page

# %%
import sys
sys.path.append('../') 
from CameraDocument import CameraDocument

camera_model = 'gfx100ii'
json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata", "front_page")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)
json_list[:5]

documents = []
for i, path in enumerate(json_list):
    if "front" in path:
        document = CameraDocument()
        document.load_json(path)
        documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 1, 'model': 'gfx100ii'}, parsing_result="I'm unable to provide the content of the manual directly from the image. However, if you have any specific questions about the Fujifilm GFX 100 II camera or need information on a particular feature, feel free to ask!", embedding_result=[]),
#  CameraDocument(metadata={'page': 2, 'model': 'gfx100ii'}, parsing_result='# Introduction\n\nThank you for your purchase of this product. Be sure that you have read this manual and understood its contents before using the camera. Keep the manual where it will be read by all who use the product.\n\n## For the Latest Information\n\nThe latest versions of the manuals are available from:\n\nhttps://fujifilm-dsc.com/en/manual/\n\nThe website can be accessed not only from your computer but also from smartphones and tablets. It also contains information on the software license.\n\nFor information on firmware updates, visit:  \nhttps://fujifilm-x.com/support/download/firmware/cameras/\n\n!QR Code and Devices', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'gfx100ii'}, parsing_result='# Chapter Index\n\n- **Menu List** iv\n\n1. **Before You Begin** 1\n2. **First Steps** 39\n3. **Basic Photography and Playback** 59\n4. **Movie Recording and Playback** 67\n5. **Taking Photographs** 75\n6. **The Shooting Menus** 125\n7. **Playback and the Playback Menu** 213\n8. **Network/USB Setting Menus** 241\n9. **The Setup Menus** 331\n10. **Shortcuts** 375\n11. **Peripherals and Optional Accessories** 393\n12. **Technical Notes** 419', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'gfx100ii'}, parsing_result='# Menu List\n\nCamera menu options are listed below.\n\n## Shooting Menus\n\nAdjust settings when shooting photos or movies.\n\n> See page 125 for details.\n\n## Photo Menus\n\nItems marked with both !Camera Icon and !Movie Icon icons are available in both the still photography and movie shooting menus. Changes to these items in either menu also apply to the item in the remaining menu.\n\n| Image Quality Setting       | Page | Image Quality Setting       | Page |\n|-----------------------------|------|-----------------------------|------|\n| IMAGE SIZE                  | 126  | HIGH ISO NR                 | 140  |\n| IMAGE QUALITY               | 127  | CLARITY                     | 141  |\n| RAW RECORDING               | 128  | LONG EXPOSURE NR            | 141  |\n| SELECT JPEG/HEIF            | 129  | LENS MODULATION OPTIMIZER   | 141  |\n| FILM SIMULATION             | 130  | COLOR SPACE                 | 141  |\n| MONOCHROMATIC COLOR         | 132  | !Pixel Mapping Icon PIXEL MAPPING | 142  |\n| GRAIN EFFECT                | 132  | !Edit/Save Icon EDIT/SAVE CUSTOM SETTING | 142  |\n| COLOR CHROME EFFECT         | 133  | AUTO UPDATE CUSTOM SETTING  | 142  |\n| COLOR CHROME FX BLUE        | 133  | !Mount Adaptor Icon MOUNT ADAPTOR SETTING | 143  |\n| SMOOTH SKIN EFFECT          | 133  |                             |      |\n| DYNAMIC RANGE               | 134  |                             |      |\n| D RANGE PRIORITY            | 135  |                             |      |\n| WHITE BALANCE               | 136  |                             |      |\n| TONE CURVE                  | 140  |                             |      |\n| COLOR                       | 140  |                             |      |\n| SHARPNESS                   | 140  |                             |      |', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'gfx100ii'}, parsing_result='# Menu List\n\n## AF/MF Setting\n- **Focus Area** - 146\n- **AF Mode** - 146\n- **Zone Custom Setting** - 146\n- **AF Mode All Setting** - 146\n- **AF-C Custom Settings** - 147\n- **Store AF Mode by Orientation** - 150\n- **AF Point Display** - 151\n- **Wrap Focus Point** - 151\n- **Number of Focus Points** - 151\n- **Pre-AF** - 152\n- **AF Illuminator** - 152\n- **Face/Eye Detection Setting** - 153\n- **Subject Detection Setting** - 155\n- **AF+MF** - 157\n- **MF Assist** - 158\n- **Interlock MF Assist & Focus Ring** - 158\n- **Focus Check** - 159\n- **Interlock Spot AE & Focus Area** - 159\n- **Instant AF Setting** - 159\n- **Depth-of-Field Scale** - 160\n- **Release/Focus Priority** - 160\n- **AF Range Limiter** - 161\n- **Touch Screen Mode** - 162\n\n## Shooting Setting\n- **Self-Timer** - 164\n- **Save Self-Timer Setting** - 165\n- **Self-Timer Lamp** - 165\n- **Interval Timer Shooting** - 166\n- **Interval Timer Shooting Exposure Smoothing** - 168\n- **Interval Priority Mode** - 168\n- **AE BKT Setting** - 169\n- **Film Simulation BKT** - 169\n- **Focus BKT Setting** - 169\n- **Photometry** - 169\n- **Shutter Type** - 170\n- **Flicker Reduction** - 171\n- **Flickerless S.S. Setting** - 171\n- **ISO** - 171\n- **IS Mode** - 172\n- **35mm Format Mode** - 172\n- **Cooling Fan Setting** - 173\n- **Wireless Communication** - 173\n\n## Flash Setting\n- **Flash Function Setting** - 174\n- **Red Eye Removal** - 174\n- **TTL-Lock Mode** - 175\n- **LED Light Setting** - 175\n- **Commander Setting** - 176\n- **CH Setting** - 176', embedding_result=[])]

# %%
for document in documents:
    if document.metadata['page'] == 26:
        print(document.parsing_result)
# Out:
# # Technical Notes
#
# ## Accessories from Fujifilm
# - Page 420
#
# ## Software and Services for Use with Your Camera
# - Page 423
#   - Smartphone Apps
#   - RAW FILE CONVERTER EX powered by SILKYPIX
#   - Capture One Express for Fujifilm
#   - Capture One for Fujifilm
#   - FUJIFILM Tether Shooting Plug-in (Exclusively for Lightroom)
#   - FUJIFILM X Acquire
#   - FUJIFILM X RAW STUDIO
#   - FUJIFILM Pixel Shift Combiner
#   - Frame.io Camera to Cloud
#
# ## For Your Safety
# - Page 426
#
# ## Product Care
# - Page 437
#
# ## Cleaning the Image Sensor
# - Page 438
#
# ## Firmware Updates
# - Page 439
#   - Checking the Firmware Version
#
# ## Troubleshooting
# - Page 440
#
# ## Warning Messages and Displays
# - Page 452
#
# ## Errors
# - Page 457
#
# ## Memory Card Capacity
# - Page 460
#
# ## Specifications
# - Page 461

# %%
import os
import re
import sys
sys.path.append('../') 
from CameraDocument import CameraDocument
from glob import glob

camera_model = 'gfx100ii'
json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)
json_list[:5]

documents = []
for i, path in enumerate(json_list):
    document = CameraDocument()
    document.load_json(path)
    documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 1, 'model': 'gfx100ii'}, parsing_result='!Before You Begin', embedding_result=[]),
#  CameraDocument(metadata={'page': 2, 'model': 'gfx100ii'}, parsing_result='# Parts of the Camera\n\n!Parts of the Camera\n\n1. **Secondary monitor backlight button**  \n2. **Fn4 button**  \n3. **Secondary LCD monitor**  \n4. **Microphone**  \n5. **Hot shoe**  \n6. **Dial lock release**  \n7. **Mode dial**  \n8. **STILL/MOVIE mode switch**  \n9. **Strap eyelet**  \n10. **LAN connector cover**  \n11. **Connector cover**  \n12. **AF-assist illuminator**  \n13. **Self-timer lamp**  \n14. **Tally light**  \n15. **Sync terminal**  \n16. **Lens signal contacts**  \n17. **Lens release button**  \n18. **Fn6 button**  \n19. **Fn5 button**  \n20. **Front command dial**  \n21. **ON/OFF switch**  \n22. **Shutter button**  \n23. **Fn1 button**  \n24. **Fn2 button**  \n25. **Fn3 button**  \n26. **Hot shoe cover**  \n27. **Body cap**  \n28. **LAN connector**  \n29. **Microphone/remote release connector (ø3.5mm)**  \n30. **HDMI connector (Type A)**  \n31. **USB connector (Type-C)**  \n32. **Hole to screw USB cable**  \n33. **Hole to screw cable protector**  \n\n> 💡 **Note:**  \n> Use of an optional RR-100 remote release requires a third-party adapter to convert the three-pin, ø2.5 mm connector to a three-pin, ø3.5 mm connector.', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'gfx100ii'}, parsing_result='# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n1. **32 DRIVE button**  \n   - Page 8\n\n2. **33 (delete) button**  \n   - Page 66\n\n3. **34 Focus mode selector**  \n   - Page 93\n\n4. **35 AFON button**  \n   - Pages 111, 385\n\n5. **36 Rear command dial**  \n   - Pages 9, 218, 358\n\n6. **37 Q (quick menu) button**  \n   - Page 379\n\n7. **38 Indicator lamp**  \n   - Pages 10, 192\n\n8. **39 Headphone jack cover**\n\n9. **40 Memory card slot cover latch**  \n   - Page 45\n\n10. **41 Memory card slot cover (detachable)**  \n    - Pages 6, 45\n\n11. **42 Battery-chamber cover latch**  \n    - Page 43\n\n12. **43 Hole to hook Vertical Battery Grip**\n\n13. **44 Battery-chamber cover**  \n    - Page 43\n\n14. **45 DISP (display)/BACK button**  \n    - Pages 22, 216\n\n15. **46 (playback) button**  \n    - Page 63\n\n16. **47 Speaker**  \n    - Pages 73, 341\n\n17. **48 MENU/OK button**  \n    - Page 32\n\n18. **49 AEL (exposure lock) button**  \n    - Pages 111, 385\n\n19. **50 Focus stick (focus lever)**  \n    - Pages 6, 98, 357\n\n20. **51 Tripod mount**\n\n21. **52 Vertical battery grip connector cover**  \n    - Page 411\n\n22. **53 Tilt lock release**  \n    - Page 11\n\n23. **54 LCD monitor**  \n    - Pages 11, 18, 20  \n    - Touch screen: Pages 34, 162, 203\n\n24. **55 Headphone jack (ø3.5mm)**  \n    - Page 207\n\n25. **56 Memory card slot 1**  \n    - For Type B CFexpress cards: Page 45\n\n26. **57 Memory card slot 2**  \n    - For SD memory cards: Page 45', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'gfx100ii'}, parsing_result='# Before You Begin\n\n!Camera Diagram\n\n### Diagram Key\n\n- **58** Battery latch ..............................................44\n- **59** Battery chamber ......................................43\n- **60** Cooling fan connector cover .................416\n- **61** Cooling fan connector ...........................416\n- **62** Hole to screw cooling fan ......................416\n- **63** Serial number plate ..................................6\n- **64** Vertical battery grip connector ............411', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'gfx100ii'}, parsing_result='# The Cable Protector\n\nAttach the protector as shown to prevent accidental disconnection.\n\n1. Slide the protector over the USB connector cover so that the cover passes through the slot in the protector.\n2. Tighten the lock screw.\n3. Connect the cable and pass it through the protector as shown.\n\n!Cable Protector Instructions', embedding_result=[])]

# %%
chapter_dict = {
  "chapter": {
    "Before You Begin": [1, 39],
    "First Steps": [39, 59],
    "Basic Photography and Playback": [59, 67],
    "Movie Recording and Playback": [67, 75],
    "Taking Photographs": [75, 125],
    "The Shooting Menus": [125, 213],
    "Playback and the Playback Menu": [213, 241],
    "Network/USB Setting Menus": [241, 331],
    "The Setup Menus": [331, 375],
    "Shortcuts": [375, 393],
    "Peripherals and Optional Accessories": [393, 419],
    "Technical Notes": [419, 470]
  }
}

# %%
cover_page_list = []
for chapter in chapter_dict["chapter"]:
    cover_page_list.append(chapter_dict["chapter"][chapter][0])

cover_erase_documents = []
for document in documents:
    if document.metadata['page'] not in cover_page_list:
        cover_erase_documents.append(document)

# %%
for doc in cover_erase_documents:
    if "MEMO" in doc.parsing_result:
        print(doc.metadata['page'])
# Out:
# 124
# 230
# 234
# 251
# 276
# 289
# 327
# 330
# 374
# 453
# 470
# 471

# %%
memo_page_list = [124, 330, 374, 470, 471, 472]

memo_erase_documents = []
for document in cover_erase_documents:
    if document.metadata['page'] not in memo_page_list:
        memo_erase_documents.append(document)

# %% [markdown]
# # add metadata
# - metadata: {
#     "chapter":,
#     "section":,
#     "subsection":
# }

# %%
from pprint import pprint

pprint(chapter_dict)
# Out:
# {'chapter': {'Basic Photography and Playback': [59, 67],
#              'Before You Begin': [1, 39],
#              'First Steps': [39, 59],
#              'Movie Recording and Playback': [67, 75],
#              'Network/USB Setting Menus': [241, 331],
#              'Peripherals and Optional Accessories': [393, 419],
#              'Playback and the Playback Menu': [213, 241],
#              'Shortcuts': [375, 393],
#              'Taking Photographs': [75, 125],
#              'Technical Notes': [419, 470],
#              'The Setup Menus': [331, 375],
#              'The Shooting Menus': [125, 213]}}

# %%
memo_erase_documents[:5]
# Out:
# [CameraDocument(metadata={'page': 2, 'model': 'gfx100ii'}, parsing_result='# Parts of the Camera\n\n!Parts of the Camera\n\n1. **Secondary monitor backlight button**  \n2. **Fn4 button**  \n3. **Secondary LCD monitor**  \n4. **Microphone**  \n5. **Hot shoe**  \n6. **Dial lock release**  \n7. **Mode dial**  \n8. **STILL/MOVIE mode switch**  \n9. **Strap eyelet**  \n10. **LAN connector cover**  \n11. **Connector cover**  \n12. **AF-assist illuminator**  \n13. **Self-timer lamp**  \n14. **Tally light**  \n15. **Sync terminal**  \n16. **Lens signal contacts**  \n17. **Lens release button**  \n18. **Fn6 button**  \n19. **Fn5 button**  \n20. **Front command dial**  \n21. **ON/OFF switch**  \n22. **Shutter button**  \n23. **Fn1 button**  \n24. **Fn2 button**  \n25. **Fn3 button**  \n26. **Hot shoe cover**  \n27. **Body cap**  \n28. **LAN connector**  \n29. **Microphone/remote release connector (ø3.5mm)**  \n30. **HDMI connector (Type A)**  \n31. **USB connector (Type-C)**  \n32. **Hole to screw USB cable**  \n33. **Hole to screw cable protector**  \n\n> 💡 **Note:**  \n> Use of an optional RR-100 remote release requires a third-party adapter to convert the three-pin, ø2.5 mm connector to a three-pin, ø3.5 mm connector.', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'gfx100ii'}, parsing_result='# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n1. **32 DRIVE button**  \n   - Page 8\n\n2. **33 (delete) button**  \n   - Page 66\n\n3. **34 Focus mode selector**  \n   - Page 93\n\n4. **35 AFON button**  \n   - Pages 111, 385\n\n5. **36 Rear command dial**  \n   - Pages 9, 218, 358\n\n6. **37 Q (quick menu) button**  \n   - Page 379\n\n7. **38 Indicator lamp**  \n   - Pages 10, 192\n\n8. **39 Headphone jack cover**\n\n9. **40 Memory card slot cover latch**  \n   - Page 45\n\n10. **41 Memory card slot cover (detachable)**  \n    - Pages 6, 45\n\n11. **42 Battery-chamber cover latch**  \n    - Page 43\n\n12. **43 Hole to hook Vertical Battery Grip**\n\n13. **44 Battery-chamber cover**  \n    - Page 43\n\n14. **45 DISP (display)/BACK button**  \n    - Pages 22, 216\n\n15. **46 (playback) button**  \n    - Page 63\n\n16. **47 Speaker**  \n    - Pages 73, 341\n\n17. **48 MENU/OK button**  \n    - Page 32\n\n18. **49 AEL (exposure lock) button**  \n    - Pages 111, 385\n\n19. **50 Focus stick (focus lever)**  \n    - Pages 6, 98, 357\n\n20. **51 Tripod mount**\n\n21. **52 Vertical battery grip connector cover**  \n    - Page 411\n\n22. **53 Tilt lock release**  \n    - Page 11\n\n23. **54 LCD monitor**  \n    - Pages 11, 18, 20  \n    - Touch screen: Pages 34, 162, 203\n\n24. **55 Headphone jack (ø3.5mm)**  \n    - Page 207\n\n25. **56 Memory card slot 1**  \n    - For Type B CFexpress cards: Page 45\n\n26. **57 Memory card slot 2**  \n    - For SD memory cards: Page 45', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'gfx100ii'}, parsing_result='# Before You Begin\n\n!Camera Diagram\n\n### Diagram Key\n\n- **58** Battery latch ..............................................44\n- **59** Battery chamber ......................................43\n- **60** Cooling fan connector cover .................416\n- **61** Cooling fan connector ...........................416\n- **62** Hole to screw cooling fan ......................416\n- **63** Serial number plate ..................................6\n- **64** Vertical battery grip connector ............411', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'gfx100ii'}, parsing_result='# The Cable Protector\n\nAttach the protector as shown to prevent accidental disconnection.\n\n1. Slide the protector over the USB connector cover so that the cover passes through the slot in the protector.\n2. Tighten the lock screw.\n3. Connect the cable and pass it through the protector as shown.\n\n!Cable Protector Instructions', embedding_result=[]),
#  CameraDocument(metadata={'page': 6, 'model': 'gfx100ii'}, parsing_result='# Before You Begin\n\n## The Serial Number Plate\n\nDo not remove the serial number plate, which provides the CMIIT ID, serial number, and other important information.\n\n!Serial number plate\n\n## The Memory Card Slot Cover (Detachable)\n\nThe memory card slot cover can be removed by lowering the interior latch. Remove the cover for ease of access when a camera rig is attached or in other situations that make it difficult to open or close the cover.\n\n!Memory card slot cover removal\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus stick operation\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING**.', embedding_result=[])]

# %%
for chapter in chapter_dict['chapter']:
    for document in memo_erase_documents:
        if chapter_dict['chapter'][chapter][0] <= document.metadata['page'] < chapter_dict['chapter'][chapter][1]:
            document.metadata['chapter'] = chapter

# %%
# chapter가 들어가지 않은 page확인
for document in memo_erase_documents:
    if 'chapter' not in document.metadata:
        print(document.metadata['page'])

# %%
section_dict = {
  "section": {
    "Before You Begin": {
      "Parts of the Camera": [2, 12],
      "The Viewfinder": [12, 16],
      "Camera Displays": [16, 32],
      "Using the Menus": [32, 34],
      "Touch Screen Mode": [34, 39]
    },
    "First Steps": {
      "Attaching the Strap": [40, 41],
      "Attaching a Lens": [41, 43],
      "Inserting the Battery": [43, 45],
      "Inserting Memory Cards": [45, 50],
      "Charging the Battery": [50, 54],
      "Turning the Camera On and Off": [54, 55],
      "Checking the Battery Level": [55, 56],
      "Basic Setup": [56, 59]
    },
    "Basic Photography and Playback": {
      "Taking Photographs (Mode P)": [60, 63],
      "Viewing Pictures": [63, 66],
      "Deleting Pictures": [66, 67]
    },
    "Movie Recording and Playback": {
      "Recording Movies": [68, 73],
      "Viewing Movies": [73, 75]
    },
    "Taking Photographs": {
      "P, S, A, and M Modes": [76, 92],
      "Autofocus": [92, 101],
      "Manual Focus": [101, 106],
      "Sensitivity": [106, 108],
      "Metering": [108, 109],
      "Exposure Compensation": [109, 110],
      "Focus/Exposure Lock": [110, 112],
      "Bracketing": [112, 117],
      "Continuous Shooting (Burst Mode)": [117, 119],
      "Multiple Exposures": [119, 121],
      "Pixel-Shift Multi-Shot": [121, 125]
    },
    "The Shooting Menus": {
      "IMAGE QUALITY SETTING (Still Photography)": [126, 146],
      "AF/MF SETTING (Still Photography)": [146, 164],
      "SHOOTING SETTING (Still Photography)": [164, 174],
      "FLASH SETTING (Still Photography)": [174, 177],
      "MOVIE SETTING (Movie Recording)": [177, 194],
      "IMAGE QUALITY SETTING (Movie Recording)": [194, 198],
      "AF/MF SETTING (Movie Recording)": [198, 205],
      "AUDIO SETTING (Movie Recording)": [205, 209],
      "TIME CODE SETTING (Movie Recording)": [209, 213]
    },
    "Playback and the Playback Menu": {
      "The Playback Display": [214, 218],
      "Viewing Pictures": [218, 220],
      "The Playback Menu": [220, 241]
    },
    "Network/USB Setting Menus": {
      "Overview": [242, 247],
      "Connecting to Smartphones (Bluetooth)": [247, 252],
      "Connecting to Smartphones (USB)": [252, 257],
      "Using the Camera as a Webcam": [257, 258],
      "instax SHARE Printers": [258, 260],
      "Tethered Photography": [260, 270],
      "Uploading Files to Frame.io": [270, 278],
      "Uploading Files via FTP": [278, 291],
      "RAW Processing": [291, 292],
      "Saving and Loading Settings": [292, 293],
      "Remote Movie Recording Using a Web Browser": [293, 313],
      "Network/USB Setting Menus Summary": [313, 331]
    },
    "The Setup Menus": {
      "USER SETTING": [332, 338],
      "SOUND SETTING": [338, 342],
      "SCREEN SETTING": [342, 357],
      "BUTTON/DIAL SETTING": [357, 366],
      "POWER MANAGEMENT": [366, 369],
      "SAVE DATA SETTING": [369, 375]
    },
    "Shortcuts": {
      "Shortcut Options": [376, 377],
      "MY MENU": [377, 379],
      "The Quick Menu": [379, 385],
      "Function Controls": [385, 393]
    },
    "Peripherals and Optional Accessories": {
      "Lenses": [394, 397],
      "Viewfinder Tilt Adapters": [397, 400],
      "External Flash Units": [400, 410],
      "Vertical Battery Grips": [410, 416],
      "Cooling Fans": [416, 419]
    },
    "Technical Notes": {
      "Accessories from Fujifilm": [420, 423],
      "Software and Services for Use with Your Camera": [423, 426],
      "For Your Safety": [426, 437],
      "Product Care": [437, 438],
      "Cleaning the Image Sensor": [438, 439],
      "Firmware Updates": [439, 440],
      "Troubleshooting": [440, 452],
      "Warning Messages and Displays": [452, 457],
      "Errors": [457, 460],
      "Memory Card Capacity": [460, 461],
      "Specifications": [461, 470]
    }
  }
}

# %%
for chapter in section_dict["section"]:
    for section in section_dict["section"][chapter]:
        for document in memo_erase_documents:
            if section_dict["section"][chapter][section][0] <= document.metadata['page'] < section_dict["section"][chapter][section][1]:
                document.metadata["section"] = section

# %%
# section 들어가지 않은 page확인
for document in memo_erase_documents:
    if 'section' not in document.metadata:
        print(document.metadata['page'])

# %%
subsection_front_page13 = {
    "The Serial Number Plate": 6,
    "The Memory Card Slot Cover (Detachable)": 6,
    "The Focus Stick (Focus Lever)": 6,
    "The Mode Dial": 7,
    "The STILL/MOVIE Mode Switch": 8,
    "The DRIVE Button": 8,
    "The Command Dials": 9,
    "The Indicator Lamp": 10,
    "The LCD Monitor": 11,

    "Attaching the Viewfinder": 13,
    "The Eye Cup": 14,
    "Focusing the Viewfinder": 15,

    "The Electronic Viewfinder": 16,
    "The LCD Monitor": 18,
    "Choosing a Display Mode": 20,
    "Adjusting Display Brightness": 22,
    "Display Rotation": 22,
    "The DISP/BACK Button": 22
}

# %%
subsection_front_page14 = {
    "The Dual Display": 24,
    "Customizing the Standard Display": 25,
    "Virtual Horizon": 27,
    "The Secondary LCD Monitor": 28,

    "The Menus": 32,
    "Selecting a Menu Tab": 33,

    "Shooting Touch Controls": 34,
    "Playback Touch Controls": 38,

    "Using Two Cards": 47,
    "Compatible Memory Cards": 48,
    "Using an External SSD in Place of a Memory Card": 49,

    "Choosing a Different Language": 58,
    "Changing the Time and Date": 58,

    "HDMI Output": 64,

    "Adjusting Movie Settings": 72,
}

# %%
subsection_front_page15 = {
    "Mode P: Program AE": 76,
    "Mode S: Shutter-Priority AE": 78,
    "Mode A: Aperture-Priority AE": 80,
    "Mode M: Manual Exposure": 82,
    "Custom Modes": 86,

    "Focus Mode": 93,
    "Autofocus Options (AF Mode)": 95,
    "Focus-Point Selection": 97,

    "Checking Focus": 103,

    "AUTO": 107,

    "Other Controls": 111,

    "ISO BKT": 113,
    "WHITE BALANCE BKT": 113,
    "BKT Bracketing": 114,

    "IMAGE SIZE": 126,
    "IMAGE QUALITY": 127,
    "RAW RECORDING": 128,
    "SELECT JPEG/HEIF": 129,
    "FILM SIMULATION": 130,
    "MONOCHROMATIC COLOR": 132,
    "GRAIN EFFECT": 132
}

# %%
subsection_front_page16 = {
    "COLOR CHROME EFFECT": 133,
    "COLOR CHROME FX BLUE": 133,
    "SMOOTH SKIN EFFECT": 133,
    "DYNAMIC RANGE": 134,
    "D RANGE PRIORITY": 135,
    "WHITE BALANCE": 136,
    "TONE CURVE": 140,
    "COLOR": 140,
    "SHARPNESS": 140,
    "HIGH ISO NR": 140,
    "CLARITY": 141,
    "LONG EXPOSURE NR": 141,
    "LENS MODULATION OPTIMIZER": 141,
    "COLOR SPACE": 141,
    "(photography)(movie)PIXEL MAPPING": 142,
    "(photography)EDIT/SAVE CUSTOM SETTING": 142,
    "AUTO UPDATE CUSTOM SETTING": 142,
    "(photography)(movie)MOUNT ADAPTOR SETTING": 143,
    
    "FOCUS AREA": 146,
    "AF MODE": 146,
    "ZONE CUSTOM SETTING": 146,
    "AF MODE ALL SETTING": 146,
    "AF-C CUSTOM SETTINGS": 147,
    "STORE AF MODE BY ORIENTATION": 150,
    "AF POINT DISPLAY": 151,
    "(photography)(movie)WRAP FOCUS POINT": 151,
    "NUMBER OF FOCUS POINTS": 151,
    "PRE-AF": 152,
    "(photography)(movie)AF ILLUMINATOR": 152,
    "FACE/EYE DETECTION SETTING": 153,
    "SUBJECT DETECTION SETTING": 155,
    "AF+MF": 157,
    "MF ASSIST": 158,
    "INTERLOCK MF ASSIST & FOCUS RING": 158,
    "FOCUS CHECK": 159
}

# %%
subsection_front_page17 = {
    "INTERLOCK SPOT AE & FOCUS AREA": 159,
    "(photography)(movie)INSTANT AF SETTING": 159,
    "(photography)(movie)DEPTH-OF-FIELD SCALE": 160,
    "RELEASE/FOCUS PRIORITY": 160,
    "(photography)(movie)AF RANGE LIMITER": 161,
    "TOUCH SCREEN MODE": 162,

    "SELF-TIMER": 164,
    "SAVE SELF-TIMER SETTING": 165,
    "SELF-TIMER LAMP": 165,
    "INTERVAL TIMER SHOOTING": 166,
    "INTERVAL TIMER SHOOTING EXPOSURE SMOOTHING": 168,
    "INTERVAL PRIORITY MODE": 168,
    "AE BKT SETTING": 169,
    "FILM SIMULATION BKT": 169,
    "FOCUS BKT SETTING": 169,
    "PHOTOMETRY": 169,
    "SHUTTER TYPE": 170,
    "FLICKER REDUCTION": 171,
    "FLICKERLESS S.S. SETTING": 171,
    "ISO": 171,
    "IS MODE": 172,
    "35mm FORMAT MODE": 172,
    "(photography)(movie)COOLING FAN SETTING": 173,
    "(photography)(movie)WIRELESS COMMUNICATION": 173,

    "FLASH FUNCTION SETTING": 174,
    "RED EYE REMOVAL": 174,
    "TTL-LOCK MODE": 175,
    "LED LIGHT SETTING": 175,
    "COMMANDER SETTING": 176,
    "CH SETTING": 176,

    "MOVIE SETTING LIST": 177,
    "IMAGE FORMAT": 177,
    "MOVIE MODE": 178
}

# %%
subsection_front_page18 = {
    "HIGH SPEED REC": 179,
    "(movie)SELF-TIMER": 180,
    "MEDIA REC SETTING": 181,
    "HDMI OUTPUT SETTING": 184,
    "FIX MOVIE CROP MAGNIFICATION": 185,
    "F-Log/HLG RECORDING": 186,
    "DATA LEVEL SETTING": 187,
    "(movie)PHOTOMETRY": 187,
    "(movie)FLICKERLESS S.S. SETTING": 187,
    "(movie)IS MODE": 188,
    "(movie)IS MODE BOOST": 188,
    "ISO": 189,
    "ZEBRA SETTING": 189,
    "ZEBRA LEVEL": 189,
    "WAVEFORM/VECTORSCOPE": 190,
    "MOVIE OPTIMIZED CONTROL": 191,
    "(movie)REC FRAME INDICATOR": 191,
    "TALLY LIGHT": 192,
    "(photography)(movie)COOLING FAN SETTING": 193,
    "(movie)EDIT/SAVE CUSTOM SETTING": 193,
    "(movie)AUTO UPDATE CUSTOM SETTING": 193,
    "(photography)(movie)WIRELESS COMMUNICATION": 193,

    "(movie)FILM SIMULATION": 194,
    "(movie)MONOCHROMATIC COLOR": 194,
    "(movie)DYNAMIC RANGE": 195,
    "(movie)WHITE BALANCE": 195,
    "(movie)TONE CURVE": 195,
    "(movie)COLOR": 195,
    "(movie)SHARPNESS": 196,
    "(movie)HIGH ISO NR": 196,
    "INTERFRAME NR": 196,
    "(photography)(movie)PIXEL MAPPING": 196,
    "F-Log2 D RANGE PRIORITY": 197,
    "(movie)PERIPHERAL LIGHT CORRECTION": 197,
    "(photography)(movie)MOUNT ADAPTOR SETTING": 197
}

# %%
subsection_front_page19 ={
    "(movie)FOCUS AREA": 198,
    "(movie)AF MODE": 198,
    "(movie)AF-C CUSTOM SETTING": 199,
    "(photography)(movie)WRAP FOCUS POINT": 199,
    "(photography)(movie)AF ILLUMINATOR": 200,
    "(movie)FACE/EYE DETECTION SETTING": 200,
    "(movie)SUBJECT DETECTION SETTING": 200,
    "(movie)AF+MF": 201,
    "(movie)MF ASSIST": 201,
    "(movie)INTERLOCK MF ASSIST & FOCUS RING": 201,
    "(movie)FOCUS CHECK": 202,
    "(photography)(movie)INSTANT AF SETTING": 202,
    "(photography)(movie)DEPTH-OF-FIELD SCALE": 202,
    "(photography)(movie)AF RANGE LIMITER": 202,
    "(movie)TOUCH SCREEN MODE": 203,
    "FOCUS CHECK LOCK": 204,

    "INTERNAL MIC LEVEL ADJUSTMENT": 205,
    "EXTERNAL MIC LEVEL ADJUSTMENT": 205,
    "MIC JACK SETTING": 206,
    "MIC LEVEL LIMITER": 206,
    "WIND FILTER": 206,
    "LOW CUT FILTER": 206,
    "HEADPHONES VOLUME": 207,
    "MIC/REMOTE RELEASE": 207,
    "XLR MIC ADAPTER SETTING": 208,

    "TIME CODE DISPLAY": 209,
    "START TIME SETTING": 209,
    "COUNT UP SETTING": 210,
    "DROP FRAME": 210,
    "HDMI TIME CODE OUTPUT": 211,
    "TIME CODE SYNC. SETTING": 211
}

# %%
subsection_front_page20 = {
    "The DISP/BACK Button": 216,

    "Playback Zoom": 219,
    "Multi-Frame Playback": 219,

    "SWITCH SLOT": 220,
    "RAW CONVERSION": 221,
    "HEIF TO JPEG/TIFF CONVERSION": 223,
    "ERASE": 224,
    "SIMULTANEOUS DELETE": 226,
    "CROP": 226,
    "RESIZE": 227,
    "PROTECT": 228,
    "IMAGE ROTATE": 229,
    "VOICE MEMO SETTING": 230,
    "RATING": 231,
    "COPY": 232,
    "TRANSFER IMAGE TO SMARTPHONE": 233,
    "(photography)(movie)WIRELESS COMMUNICATION": 235,
    "DESQUEEZE DISP. IN PLAYBACK": 235,
    "PHOTOBOOK ASSIST": 236,
    "PRINT ORDER (DPOF)": 238,
    "INSTAX PRINTER PRINT": 239,
    "DISP ASPECT": 240,

    "Supported Features": 242,
    "Connection Setting Profiles": 246
}

# %%
subsection_front_page21 = {
    "Installing Smartphone Apps": 247,
    "Connecting to a Smartphone": 247,
    "Using the Smartphone App": 249,

    "Copying Pictures to a Smartphone": 252,
    "Connecting the Camera and Computer": 255,

    "Establishing a Connection": 258,
    "Printing Pictures": 259,

    "Tethered Photography via USB": 260,
    "Tethered Photography via Wireless LAN": 262,
    "Tethered Photography via Wired LAN (Ethernet)": 267,

    "Connecting via Wireless LAN": 270,
    "Connecting via Wired LAN (Ethernet)": 272,
    "Uploading Items to Frame.io": 275,

    "Connecting to FTP Servers": 278,
    "Adjusting Settings for Connection to FTP Servers": 285,
    "Uploading Pictures to FTP Servers": 288,


    "Connecting to the Camera from a Web Browser": 293,
    "Connecting to the Camera from a Computer or Tablet": 303,
    "The Remote Recording Display": 306,
    "Recording Movies Remotely": 310,
    "Viewing Movies": 310,
    "Saving and Loading Camera Settings": 311
}

# %%
subsection_front_page22 = {
    "CREATE/EDIT CONNECTION SETTING": 313,
    "SELECT CONNECTION SETTING": 318,
    "AIRPLANE MODE": 319,
    "Bluetooth/SMARTPHONE SETTING": 320,
    "instax PRINTER CONNECTION SETTING": 323,
    "Frame.io Camera to Cloud": 323,
    "FTP OPTIONAL SETTING": 326,
    "USB POWER SUPPLY/COMM SETTING": 328,
    "INFORMATION": 329,
    "RESET NETWORK/USB SETTING": 329,

    "FORMAT": 332,
    "AREA SETTING": 333,
    "DATE/TIME": 333,
    "TIME DIFFERENCE": 334,
    "LANGUAGE": 335,
    "(photography)(movie)MY MENU SETTING": 335,
    "SENSOR CLEANING": 336,
    "BATTERY AGE": 336,
    "RESET": 337,
    "REGULATORY": 337,

    "AF BEEP VOL.": 338,
    "SELF-TIMER BEEP VOL.": 338,
    "OPERATION VOL.": 339,
    "REC START/STOP VOLUME": 339,
    "ELECTRONIC SHUTTER VOLUME": 340,
    "ELECTRONIC SHUTTER SOUND": 340,
    "PLAYBACK VOLUME": 341,
    "4ch AUDIO PLAYBACK": 341
}

# %%
subsection_front_page23 = {
    "VIEW MODE SETTING": 342,
    "EVF BRIGHTNESS": 342,
    "EVF COLOR": 342,
    "EVF COLOR ADJUSTMENT": 343,
    "LCD BRIGHTNESS": 344,
    "LCD COLOR": 344,
    "LCD COLOR ADJUSTMENT": 344,
    "IMAGE DISP": 345,
    "AUTOROTATE DISPLAYS": 345,
    "PREVIEW EXP/WB IN MANUAL MODE": 346,
    "NATURAL LIVE VIEW": 346,
    "F-Log VIEW ASSIST": 347,
    "ELECTRONIC LEVEL SETTING": 347,
    "FRAMING GUIDELINE": 347,
    "AUTOROTATE PB": 348,
    "PLAYBACK MAGNIFICATION": 348,
    "FOCUS SCALE UNITS": 348,
    "DUAL DISPLAY SETTING": 349,
    "EVF FULL SCREEN MAGNIFICATION": 349,
    "DISP. CUSTOM SETTING": 349,
    "LARGE INDICATORS MODE(EVF)": 350,
    "LARGE INDICATORS MODE(LCD)": 351,
    "LARGE INDICATORS DISP. SETTING": 352,
    "INFORMATION CONTRAST ADJ": 352,
    "LOCATION INFO": 353,
    "SUB MONITOR SETTING": 353,
    "SUB MONITOR BACKGROUND COLOR": 356,
    "(photography)(movie)Q MENU BACKGROUND": 356,

    "FOCUS LEVER SETTING": 357,
    "(photography)(movie)EDIT/SAVE QUICK MENU": 357,
    "FUNCTION (Fn) SETTING": 358,
    "COMMAND DIAL SETTING": 358
}

# %%
subsection_front_page24 = {
    "S.S. OPERATION": 359,
    "COMMAND DIAL DIRECTION": 359,
    "SHUTTER AF": 359,
    "SHUTTER AE": 360,
    "SHOOT WITHOUT LENS": 360,
    "SHOOT WITHOUT CARD": 360,
    "FOCUS RING": 361,
    "FOCUS RING OPERATION": 361,
    "AE/AF-LOCK MODE": 361,
    "AWB-LOCK MODE": 362,
    "EXPO. COMP. BUTTON SETTING": 362,
    "Fn BUTTON SETTING": 363,
    "TOUCH SCREEN SETTING": 364,
    "LOCK": 365,

    "AUTO POWER OFF": 366,
    "PERFORMANCE": 367,
    "SHOOTING STAND BY MODE": 368,
    "AUTO POWER SAVE": 368,
    "AUTO POWER OFF TEMP.": 368,

    "FRAME NO.": 369,
    "EDIT FILE NAME": 370,
    "(photography)CARD SLOT SETTING": 370,
    "SELECT SLOT ((photography)SEQUENTIAL)": 370,
    "SELECT FOLDER": 371,
    "COPYRIGHT INFO": 371,
    "DEFAULT CAPTION": 372,
    "IPTC": 372,
    "GEOTAGGING": 373
}

# %%
subsection_front_page25 = {
    "MY MENU SETTING": 377,
    "The Quick Menu Display": 379,
    "Viewing and Changing Settings": 381,
    "Editing the Quick Menu": 382,
    "The Function Buttons": 385,
    "Touch-Function Gestures": 390,

    "Lens Parts": 394,
    "Lens Care": 395,
    "Removing Lens Caps": 395,
    "Attaching Lens Hoods": 395,
    "Aperture Rings": 396,
    "T/S Lenses": 396,

    "Attaching the EVF-TL1": 398,
    "Using the EVF-TL1": 399,

    "Flash Settings": 401,
    "SYNC TERMINAL": 402,
    "SHOE MOUNT FLASH": 403,
    "COMMANDER (OPTICAL)": 406,

    "Attaching the Vertical Battery Grip": 411,
    "Inserting and Removing Batteries": 413,
    "Charging the Batteries": 415,

    "Attaching a Cooling Fan": 416,
    "Using the Fan": 418
}

# %%
subsection_front_page26 = {
    "Smartphone Apps": 423,
    "RAW FILE CONVERTER EX powered by SILKYPIX": 423,
    "Capture One Express for Fujifilm": 424,
    "Capture One for Fujifilm": 424,
    "FUJIFILM Tether Shooting Plug-in (Exclusively for Lightroom)": 424,
    "FUJIFILM X Acquire": 424,
    "FUJIFILM X RAW STUDIO": 425,
    "FUJIFILM Pixel Shift Combiner": 425,
    "Frame.io Camera to Cloud": 425,

    "Checking the Firmware Version": 439,
}

# %%
subsection_dict = {}
subsection_dict |= subsection_front_page13
subsection_dict |= subsection_front_page14
subsection_dict |= subsection_front_page15
subsection_dict |= subsection_front_page16
subsection_dict |= subsection_front_page17
subsection_dict |= subsection_front_page18
subsection_dict |= subsection_front_page19
subsection_dict |= subsection_front_page20
subsection_dict |= subsection_front_page21
subsection_dict |= subsection_front_page22
subsection_dict |= subsection_front_page23
subsection_dict |= subsection_front_page24
subsection_dict |= subsection_front_page25
subsection_dict |= subsection_front_page26

# %%
jh_temp_dict = {}
for section in subsection_dict:
    if subsection_dict[section] not in jh_temp_dict:
        jh_temp_dict[subsection_dict[section]] = [section]
    elif subsection_dict[section] in jh_temp_dict:
        jh_temp_dict[subsection_dict[section]].append(section)

# %%
for chapter in section_dict['section']:
    for section in section_dict['section'][chapter]:
        for subsection_page_num in jh_temp_dict:
            if section_dict['section'][chapter][section][0] <= subsection_page_num < section_dict['section'][chapter][section][1]:
                for document in memo_erase_documents:
                    if subsection_page_num <= document.metadata['page'] < section_dict['section'][chapter][section][1]:
                        document.metadata['subsection'] = jh_temp_dict[subsection_page_num]

# %%
# section 들어가지 않은 page확인
for document in memo_erase_documents:
    if 'subsection' not in document.metadata:
        print(document.metadata['page'])
# Out:
# 2
# 3
# 4
# 5
# 12
# 40
# 41
# 42
# 43
# 44
# 45
# 46
# 50
# 51
# 52
# 53
# 54
# 55
# 56
# 57
# 60
# 61
# 62
# 63
# 66
# 68
# 69
# 70
# 71
# 73
# 74
# 92
# 101
# 102
# 106
# 108
# 109
# 110
# 112
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 214
# 215
# 218
# 257
# 291
# 292
# 376
# 397
# 400
# 410
# 420
# 421
# 422
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469

# %%
# section 들어가지 않은 page는 section으로 대체
for document in memo_erase_documents:
    if 'subsection' not in document.metadata:
        document.metadata["subsection"] = [document.metadata["section"]]

# %%
# section 들어가지 않은 page확인
for document in memo_erase_documents:
    if 'subsection' not in document.metadata:
        print(document.metadata['page'])

# %%
camera_model = "gfx100ii"
json_dir = "../data/json"

output_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "processed_data")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for doc in memo_erase_documents:
    output_path = os.path.join(output_dir, f"{camera_model}_page{doc.metadata['page']}.json")
    doc.save_json(output_path)
# Out:
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page2.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page3.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page4.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page5.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page6.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page7.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page8.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page9.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page10.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page11.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page12.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page13.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page14.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page15.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page16.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page17.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page18.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page19.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page20.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page21.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page22.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page23.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page24.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page25.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page26.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page27.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page28.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page29.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page30.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page31.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page32.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page33.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page34.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page35.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page36.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page37.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page38.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page40.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page41.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page42.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page43.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page44.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page45.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page46.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page47.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page48.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page49.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page50.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page51.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page52.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page53.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page54.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page55.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page56.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page57.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page58.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page60.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page61.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page62.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page63.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page64.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page65.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page66.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page68.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page69.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page70.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page71.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page72.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page73.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page74.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page76.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page77.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page78.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page79.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page80.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page81.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page82.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page83.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page84.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page85.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page86.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page87.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page88.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page89.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page90.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page91.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page92.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page93.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page94.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page95.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page96.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page97.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page98.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page99.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page100.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page101.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page102.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page103.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page104.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page105.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page106.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page107.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page108.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page109.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page110.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page111.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page112.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page113.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page114.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page115.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page116.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page117.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page118.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page119.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page120.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page121.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page122.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page123.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page126.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page127.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page128.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page129.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page130.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page131.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page132.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page133.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page134.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page135.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page136.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page137.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page138.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page139.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page140.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page141.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page142.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page143.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page144.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page145.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page146.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page147.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page148.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page149.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page150.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page151.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page152.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page153.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page154.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page155.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page156.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page157.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page158.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page159.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page160.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page161.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page162.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page163.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page164.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page165.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page166.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page167.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page168.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page169.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page170.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page171.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page172.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page173.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page174.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page175.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page176.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page177.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page178.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page179.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page180.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page181.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page182.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page183.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page184.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page185.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page186.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page187.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page188.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page189.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page190.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page191.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page192.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page193.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page194.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page195.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page196.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page197.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page198.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page199.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page200.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page201.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page202.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page203.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page204.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page205.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page206.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page207.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page208.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page209.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page210.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page211.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page212.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page214.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page215.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page216.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page217.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page218.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page219.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page220.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page221.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page222.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page223.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page224.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page225.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page226.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page227.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page228.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page229.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page230.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page231.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page232.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page233.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page234.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page235.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page236.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page237.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page238.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page239.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page240.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page242.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page243.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page244.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page245.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page246.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page247.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page248.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page249.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page250.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page251.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page252.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page253.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page254.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page255.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page256.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page257.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page258.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page259.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page260.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page261.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page262.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page263.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page264.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page265.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page266.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page267.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page268.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page269.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page270.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page271.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page272.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page273.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page274.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page275.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page276.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page277.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page278.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page279.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page280.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page281.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page282.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page283.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page284.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page285.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page286.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page287.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page288.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page289.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page290.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page291.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page292.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page293.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page294.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page295.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page296.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page297.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page298.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page299.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page300.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page301.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page302.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page303.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page304.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page305.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page306.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page307.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page308.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page309.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page310.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page311.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page312.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page313.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page314.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page315.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page316.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page317.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page318.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page319.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page320.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page321.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page322.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page323.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page324.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page325.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page326.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page327.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page328.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page329.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page332.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page333.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page334.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page335.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page336.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page337.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page338.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page339.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page340.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page341.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page342.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page343.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page344.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page345.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page346.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page347.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page348.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page349.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page350.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page351.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page352.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page353.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page354.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page355.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page356.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page357.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page358.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page359.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page360.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page361.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page362.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page363.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page364.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page365.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page366.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page367.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page368.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page369.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page370.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page371.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page372.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page373.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page376.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page377.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page378.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page379.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page380.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page381.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page382.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page383.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page384.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page385.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page386.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page387.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page388.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page389.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page390.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page391.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page392.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page394.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page395.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page396.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page397.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page398.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page399.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page400.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page401.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page402.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page403.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page404.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page405.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page406.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page407.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page408.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page409.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page410.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page411.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page412.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page413.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page414.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page415.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page416.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page417.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page418.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page420.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page421.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page422.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page423.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page424.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page425.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page426.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page427.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page428.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page429.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page430.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page431.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page432.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page433.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page434.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page435.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page436.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page437.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page438.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page439.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page440.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page441.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page442.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page443.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page444.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page445.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page446.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page447.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page448.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page449.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page450.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page451.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page452.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page453.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page454.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page455.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page456.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page457.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page458.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page459.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page460.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page461.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page462.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page463.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page464.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page465.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page466.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page467.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page468.json complete
# ../data/json/gfx100ii/LlamaParseMultimodal/processed_data/gfx100ii_page469.json complete

# %% [markdown]
# # Image Extract

# %%
from glob import glob
import re
import os

import sys
sys.path.append('../') 
from CameraDocument import CameraDocument

camera_model = 'gfx100ii'
json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "processed_data")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)

documents = []
for i, path in enumerate(json_list):
    document = CameraDocument()
    document.load_json(path)
    documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 2, 'model': 'gfx100ii', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': ['Parts of the Camera']}, parsing_result='# Parts of the Camera\n\n!Parts of the Camera\n\n1. **Secondary monitor backlight button**  \n2. **Fn4 button**  \n3. **Secondary LCD monitor**  \n4. **Microphone**  \n5. **Hot shoe**  \n6. **Dial lock release**  \n7. **Mode dial**  \n8. **STILL/MOVIE mode switch**  \n9. **Strap eyelet**  \n10. **LAN connector cover**  \n11. **Connector cover**  \n12. **AF-assist illuminator**  \n13. **Self-timer lamp**  \n14. **Tally light**  \n15. **Sync terminal**  \n16. **Lens signal contacts**  \n17. **Lens release button**  \n18. **Fn6 button**  \n19. **Fn5 button**  \n20. **Front command dial**  \n21. **ON/OFF switch**  \n22. **Shutter button**  \n23. **Fn1 button**  \n24. **Fn2 button**  \n25. **Fn3 button**  \n26. **Hot shoe cover**  \n27. **Body cap**  \n28. **LAN connector**  \n29. **Microphone/remote release connector (ø3.5mm)**  \n30. **HDMI connector (Type A)**  \n31. **USB connector (Type-C)**  \n32. **Hole to screw USB cable**  \n33. **Hole to screw cable protector**  \n\n> 💡 **Note:**  \n> Use of an optional RR-100 remote release requires a third-party adapter to convert the three-pin, ø2.5 mm connector to a three-pin, ø3.5 mm connector.', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'gfx100ii', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': ['Parts of the Camera']}, parsing_result='# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n1. **32 DRIVE button**  \n   - Page 8\n\n2. **33 (delete) button**  \n   - Page 66\n\n3. **34 Focus mode selector**  \n   - Page 93\n\n4. **35 AFON button**  \n   - Pages 111, 385\n\n5. **36 Rear command dial**  \n   - Pages 9, 218, 358\n\n6. **37 Q (quick menu) button**  \n   - Page 379\n\n7. **38 Indicator lamp**  \n   - Pages 10, 192\n\n8. **39 Headphone jack cover**\n\n9. **40 Memory card slot cover latch**  \n   - Page 45\n\n10. **41 Memory card slot cover (detachable)**  \n    - Pages 6, 45\n\n11. **42 Battery-chamber cover latch**  \n    - Page 43\n\n12. **43 Hole to hook Vertical Battery Grip**\n\n13. **44 Battery-chamber cover**  \n    - Page 43\n\n14. **45 DISP (display)/BACK button**  \n    - Pages 22, 216\n\n15. **46 (playback) button**  \n    - Page 63\n\n16. **47 Speaker**  \n    - Pages 73, 341\n\n17. **48 MENU/OK button**  \n    - Page 32\n\n18. **49 AEL (exposure lock) button**  \n    - Pages 111, 385\n\n19. **50 Focus stick (focus lever)**  \n    - Pages 6, 98, 357\n\n20. **51 Tripod mount**\n\n21. **52 Vertical battery grip connector cover**  \n    - Page 411\n\n22. **53 Tilt lock release**  \n    - Page 11\n\n23. **54 LCD monitor**  \n    - Pages 11, 18, 20  \n    - Touch screen: Pages 34, 162, 203\n\n24. **55 Headphone jack (ø3.5mm)**  \n    - Page 207\n\n25. **56 Memory card slot 1**  \n    - For Type B CFexpress cards: Page 45\n\n26. **57 Memory card slot 2**  \n    - For SD memory cards: Page 45', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'gfx100ii', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': ['Parts of the Camera']}, parsing_result='# Before You Begin\n\n!Camera Diagram\n\n### Diagram Key\n\n- **58** Battery latch ..............................................44\n- **59** Battery chamber ......................................43\n- **60** Cooling fan connector cover .................416\n- **61** Cooling fan connector ...........................416\n- **62** Hole to screw cooling fan ......................416\n- **63** Serial number plate ..................................6\n- **64** Vertical battery grip connector ............411', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'gfx100ii', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': ['Parts of the Camera']}, parsing_result='# The Cable Protector\n\nAttach the protector as shown to prevent accidental disconnection.\n\n1. Slide the protector over the USB connector cover so that the cover passes through the slot in the protector.\n2. Tighten the lock screw.\n3. Connect the cable and pass it through the protector as shown.\n\n!Cable Protector Instructions', embedding_result=[]),
#  CameraDocument(metadata={'page': 6, 'model': 'gfx100ii', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': ['The Serial Number Plate', 'The Memory Card Slot Cover (Detachable)', 'The Focus Stick (Focus Lever)']}, parsing_result='# Before You Begin\n\n## The Serial Number Plate\n\nDo not remove the serial number plate, which provides the CMIIT ID, serial number, and other important information.\n\n!Serial number plate\n\n## The Memory Card Slot Cover (Detachable)\n\nThe memory card slot cover can be removed by lowering the interior latch. Remove the cover for ease of access when a camera rig is attached or in other situations that make it difficult to open or close the cover.\n\n!Memory card slot cover removal\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus stick operation\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING**.', embedding_result=[])]

# %%
import fitz

raw_data_dir = "../data/raw_data"
image_dir = "../data/image"
output_dir = os.path.join(image_dir, camera_model, "pdf_to_image")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

dpi = 600  # 원하는 DPI 값 (300, 600 등)
for document in documents:
    page_num = document.metadata['page']
    pdf_path = os.path.join(raw_data_dir, camera_model, f"{camera_model}_split", f"{camera_model}_page{page_num+28}.pdf")

    pdf_document = fitz.open(pdf_path)
    page = pdf_document.load_page(0)
    pix = page.get_pixmap(dpi=dpi)

    output_file = os.path.join(output_dir, f"{camera_model}_page{page_num}.png")
    pix.save(output_file)
    print(f"Saved: {output_file}")

    pdf_document.close()
# Out:
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page2.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page3.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page4.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page5.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page6.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page7.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page8.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page9.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page10.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page11.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page12.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page13.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page14.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page15.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page16.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page17.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page18.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page19.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page20.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page21.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page22.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page23.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page24.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page25.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page26.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page27.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page28.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page29.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page30.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page31.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page32.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page33.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page34.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page35.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page36.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page37.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page38.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page40.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page41.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page42.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page43.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page44.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page45.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page46.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page47.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page48.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page49.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page50.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page51.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page52.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page53.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page54.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page55.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page56.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page57.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page58.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page60.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page61.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page62.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page63.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page64.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page65.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page66.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page68.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page69.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page70.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page71.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page72.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page73.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page74.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page76.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page77.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page78.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page79.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page80.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page81.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page82.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page83.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page84.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page85.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page86.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page87.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page88.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page89.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page90.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page91.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page92.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page93.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page94.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page95.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page96.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page97.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page98.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page99.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page100.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page101.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page102.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page103.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page104.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page105.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page106.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page107.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page108.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page109.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page110.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page111.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page112.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page113.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page114.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page115.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page116.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page117.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page118.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page119.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page120.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page121.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page122.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page123.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page126.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page127.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page128.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page129.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page130.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page131.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page132.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page133.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page134.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page135.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page136.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page137.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page138.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page139.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page140.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page141.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page142.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page143.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page144.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page145.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page146.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page147.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page148.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page149.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page150.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page151.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page152.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page153.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page154.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page155.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page156.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page157.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page158.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page159.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page160.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page161.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page162.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page163.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page164.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page165.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page166.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page167.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page168.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page169.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page170.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page171.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page172.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page173.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page174.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page175.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page176.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page177.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page178.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page179.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page180.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page181.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page182.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page183.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page184.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page185.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page186.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page187.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page188.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page189.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page190.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page191.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page192.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page193.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page194.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page195.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page196.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page197.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page198.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page199.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page200.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page201.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page202.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page203.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page204.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page205.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page206.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page207.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page208.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page209.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page210.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page211.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page212.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page214.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page215.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page216.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page217.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page218.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page219.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page220.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page221.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page222.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page223.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page224.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page225.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page226.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page227.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page228.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page229.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page230.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page231.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page232.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page233.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page234.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page235.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page236.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page237.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page238.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page239.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page240.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page242.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page243.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page244.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page245.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page246.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page247.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page248.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page249.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page250.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page251.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page252.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page253.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page254.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page255.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page256.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page257.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page258.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page259.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page260.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page261.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page262.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page263.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page264.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page265.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page266.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page267.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page268.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page269.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page270.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page271.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page272.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page273.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page274.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page275.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page276.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page277.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page278.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page279.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page280.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page281.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page282.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page283.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page284.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page285.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page286.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page287.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page288.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page289.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page290.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page291.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page292.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page293.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page294.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page295.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page296.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page297.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page298.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page299.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page300.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page301.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page302.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page303.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page304.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page305.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page306.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page307.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page308.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page309.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page310.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page311.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page312.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page313.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page314.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page315.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page316.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page317.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page318.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page319.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page320.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page321.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page322.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page323.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page324.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page325.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page326.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page327.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page328.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page329.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page332.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page333.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page334.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page335.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page336.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page337.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page338.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page339.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page340.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page341.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page342.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page343.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page344.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page345.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page346.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page347.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page348.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page349.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page350.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page351.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page352.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page353.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page354.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page355.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page356.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page357.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page358.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page359.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page360.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page361.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page362.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page363.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page364.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page365.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page366.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page367.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page368.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page369.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page370.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page371.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page372.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page373.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page376.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page377.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page378.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page379.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page380.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page381.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page382.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page383.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page384.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page385.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page386.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page387.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page388.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page389.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page390.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page391.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page392.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page394.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page395.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page396.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page397.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page398.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page399.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page400.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page401.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page402.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page403.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page404.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page405.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page406.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page407.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page408.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page409.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page410.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page411.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page412.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page413.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page414.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page415.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page416.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page417.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page418.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page420.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page421.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page422.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page423.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page424.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page425.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page426.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page427.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page428.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page429.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page430.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page431.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page432.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page433.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page434.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page435.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page436.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page437.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page438.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page439.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page440.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page441.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page442.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page443.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page444.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page445.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page446.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page447.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page448.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page449.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page450.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page451.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page452.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page453.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page454.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page455.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page456.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page457.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page458.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page459.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page460.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page461.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page462.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page463.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page464.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page465.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page466.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page467.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page468.png
# Saved: ../data/image/gfx100ii/pdf_to_image/gfx100ii_page469.png

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path="../.env", override=True)
# Out:
# Python-dotenv could not parse statement starting at line 2
# True

# %%
from glob import glob
import re

def extract_number(file_path):
    match = re.search(r'(\d+)\.png$', file_path)
    return int(match.group(1)) if match else None

camera_model = "gfx100ii"
image_dir = "../data/image"
image_path = os.path.join(image_dir, camera_model, "pdf_to_image", "*.png")

images = glob(image_path)
images = sorted(images, key=extract_number)

# %%
import requests
import json

json_dir = f"../data/json/{camera_model}/upstage"
if not os.path.exists(json_dir):
    os.makedirs(json_dir)

api_key = os.getenv("UPSTAGE_API_KEY")
url = "https://api.upstage.ai/v1/document-ai/document-parse"
headers = {"Authorization": f"Bearer {api_key}"}

for image_path in images:
    filename = image_path
    files = {"document": open(filename, "rb")}
    data = {"output_formats":"['html','markdown']"}
    response_test = requests.post(url, headers=headers, files=files, data=data)

    json_path = os.path.join(json_dir, os.path.splitext(os.path.basename(image_path))[0] +".json")
    with open(json_path, "w", encoding="utf-8") as file:
        json.dump(response_test.json(), file, ensure_ascii=False, indent=4)

# %%
from glob import glob
import re
import os

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

camera_model = "gfx100ii"
json_dir = "../data/json"
json_path = os.path.join(json_dir, camera_model, "upstage", "*.json")

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)

# %%
import json
from PIL import Image

image_dir = "../data/image"
pdf_image_dir = os.path.join(image_dir, camera_model, "pdf_to_image")
output_dir = os.path.join(image_dir, camera_model, "extracted_images")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for json_path in json_list:
    with open(json_path, "r", encoding="utf-8") as file:
        json_data = json.load(file)

    filtered_elements = []
    for element in json_data['elements']:
        if element.get('category') == 'figure':
            filtered_elements.append(element.get('coordinates'))
            image_path = os.path.join(pdf_image_dir, os.path.splitext(os.path.basename(json_path))[0]+'.png')

            # 이미지 열기
            for idx, coordinate in enumerate(filtered_elements):
                try:
                    with Image.open(image_path) as img:
                        width, height = img.size

                        # 바운딩 박스 좌표 계산
                        x_min = int(min(coord['x'] * width for coord in coordinate))
                        y_min = int(min(coord['y'] * height for coord in coordinate))
                        x_max = int(max(coord['x'] * width for coord in coordinate))
                        y_max = int(max(coord['y'] * height for coord in coordinate))

                        # 바운딩 박스 크롭
                        cropped_image = img.crop((x_min, y_min, x_max, y_max))

                        # 결과 이미지 저장
                        output_path = os.path.join(output_dir, os.path.splitext(os.path.basename(json_path))[0]+f"_image{idx+1}.png")
                        cropped_image.save(output_path)
                        print(f"Cropped image saved to: {output_path}")

                except FileNotFoundError:
                    print(f"File not found: {image_path}")
# Out:
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page2_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page3_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page4_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page5_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page6_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page7_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page8_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page8_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page8_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page10_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page11_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page11_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page11_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page12_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page12_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page12_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page13_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page13_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page13_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page14_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page15_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page16_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page18_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page20_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page21_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page22_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page23_image5.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page24_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page26_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page27_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page28_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page28_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page28_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page29_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page29_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page29_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page30_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page31_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page32_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page33_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page33_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page33_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page34_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page36_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page37_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page37_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page37_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page38_image5.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page40_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page41_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page41_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page41_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page43_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page43_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page43_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page44_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page44_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page44_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page45_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page45_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page45_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page46_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page50_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page50_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page50_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page53_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page54_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page56_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page57_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page60_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page61_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page62_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page63_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page63_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page63_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page64_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page66_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page68_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page69_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page71_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page73_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page74_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page76_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page77_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page78_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page80_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page81_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page82_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page83_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page83_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page83_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page85_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page86_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page87_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page88_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page89_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page92_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page92_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page92_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page93_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page98_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page100_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page101_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page103_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page104_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page105_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page110_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page111_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page111_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page111_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page112_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page115_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page116_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page117_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page119_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page119_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page119_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page120_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page121_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page132_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page137_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page138_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page139_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page139_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page139_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page140_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page143_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page144_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page145_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page147_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page148_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page148_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page148_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page149_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page150_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page153_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page163_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page163_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page163_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page166_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page172_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page174_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page178_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page180_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page190_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page190_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page190_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page191_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page192_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page204_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page204_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page204_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page210_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page212_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page214_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page216_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page216_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page216_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page217_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page218_image5.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page219_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page221_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page233_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page238_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page239_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page240_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page244_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page246_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page247_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page248_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page250_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page252_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page253_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page254_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page255_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page258_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page259_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page262_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page262_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page262_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page264_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page265_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page266_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page269_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page272_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page273_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page274_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page274_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page274_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page275_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page281_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page281_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page281_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page283_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page284_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page284_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page284_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page286_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page288_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page288_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page288_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page293_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page294_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page296_image5.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page297_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page297_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page297_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page300_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page300_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page300_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page301_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page303_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page303_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page303_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page304_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page304_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page304_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page305_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page305_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page305_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page306_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page308_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page314_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page315_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page316_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page323_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page332_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page336_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page343_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page350_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page350_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page350_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page351_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page351_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page351_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page352_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page353_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page354_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page354_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page354_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page378_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page379_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page380_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page381_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page382_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page385_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page386_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page390_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page394_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page395_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page395_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page395_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page396_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page397_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page398_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page398_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page398_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page399_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page401_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page401_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page401_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page402_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page402_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page402_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page403_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page406_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page406_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page406_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page410_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page411_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page411_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page411_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page412_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image3.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page413_image4.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page415_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page416_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page416_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page416_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page417_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page417_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page417_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page426_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page426_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page426_image2.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page432_image1.png
# Cropped image saved to: ../data/image/gfx100ii/extracted_images/gfx100ii_page438_image1.png
