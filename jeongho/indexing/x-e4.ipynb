# %% [markdown]
# # pdf split

# %%
import os
from pikepdf import Pdf

cameramodel = "x-e4"
pdf_path = f"../data/raw_data/{cameramodel}/{cameramodel}.pdf"

basename = os.path.basename(pdf_path)
splitname = os.path.splitext(basename)[0]

raw_dir = "../data/raw_data"
output_dir = os.path.join(raw_dir, splitname)
detail_output_dir = os.path.join(output_dir, f"{splitname}_split")

if not os.path.exists(detail_output_dir):
    os.makedirs(detail_output_dir)

pdf = Pdf.open(pdf_path)
for n, page in enumerate(pdf.pages):
    new_pdf = Pdf.new()
    new_pdf.pages.append(page)

    output_filename = os.path.join(detail_output_dir, splitname+f"_page{n+1}.pdf")

    new_pdf.save(output_filename)
    print(f"[+] File: {output_filename} saved.")
# Out:
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page1.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page2.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page3.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page4.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page5.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page6.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page7.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page8.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page9.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page10.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page11.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page12.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page13.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page14.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page15.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page16.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page17.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page18.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page19.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page20.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page21.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page22.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page23.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page24.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page25.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page26.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page27.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page28.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page29.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page30.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page31.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page32.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page33.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page34.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page35.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page36.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page37.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page38.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page39.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page40.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page41.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page42.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page43.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page44.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page45.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page46.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page47.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page48.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page49.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page50.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page51.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page52.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page53.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page54.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page55.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page56.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page57.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page58.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page59.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page60.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page61.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page62.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page63.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page64.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page65.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page66.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page67.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page68.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page69.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page70.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page71.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page72.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page73.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page74.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page75.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page76.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page77.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page78.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page79.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page80.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page81.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page82.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page83.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page84.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page85.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page86.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page87.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page88.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page89.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page90.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page91.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page92.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page93.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page94.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page95.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page96.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page97.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page98.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page99.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page100.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page101.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page102.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page103.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page104.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page105.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page106.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page107.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page108.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page109.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page110.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page111.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page112.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page113.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page114.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page115.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page116.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page117.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page118.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page119.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page120.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page121.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page122.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page123.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page124.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page125.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page126.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page127.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page128.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page129.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page130.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page131.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page132.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page133.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page134.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page135.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page136.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page137.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page138.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page139.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page140.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page141.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page142.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page143.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page144.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page145.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page146.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page147.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page148.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page149.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page150.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page151.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page152.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page153.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page154.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page155.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page156.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page157.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page158.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page159.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page160.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page161.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page162.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page163.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page164.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page165.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page166.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page167.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page168.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page169.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page170.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page171.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page172.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page173.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page174.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page175.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page176.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page177.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page178.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page179.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page180.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page181.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page182.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page183.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page184.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page185.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page186.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page187.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page188.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page189.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page190.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page191.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page192.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page193.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page194.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page195.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page196.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page197.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page198.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page199.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page200.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page201.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page202.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page203.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page204.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page205.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page206.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page207.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page208.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page209.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page210.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page211.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page212.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page213.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page214.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page215.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page216.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page217.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page218.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page219.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page220.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page221.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page222.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page223.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page224.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page225.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page226.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page227.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page228.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page229.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page230.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page231.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page232.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page233.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page234.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page235.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page236.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page237.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page238.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page239.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page240.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page241.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page242.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page243.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page244.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page245.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page246.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page247.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page248.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page249.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page250.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page251.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page252.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page253.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page254.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page255.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page256.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page257.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page258.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page259.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page260.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page261.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page262.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page263.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page264.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page265.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page266.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page267.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page268.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page269.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page270.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page271.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page272.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page273.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page274.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page275.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page276.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page277.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page278.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page279.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page280.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page281.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page282.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page283.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page284.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page285.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page286.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page287.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page288.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page289.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page290.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page291.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page292.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page293.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page294.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page295.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page296.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page297.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page298.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page299.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page300.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page301.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page302.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page303.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page304.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page305.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page306.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page307.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page308.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page309.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page310.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page311.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page312.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page313.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page314.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page315.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page316.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page317.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page318.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page319.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page320.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page321.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page322.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page323.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page324.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page325.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page326.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page327.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page328.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page329.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page330.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page331.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page332.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page333.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page334.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page335.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page336.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page337.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page338.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page339.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page340.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page341.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page342.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page343.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page344.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page345.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page346.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page347.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page348.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page349.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page350.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page351.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page352.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page353.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page354.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page355.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page356.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page357.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page358.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page359.pdf saved.
# [+] File: ../data/raw_data/x-e4/x-e4_split/x-e4_page360.pdf saved.

# %% [markdown]
# # Llama Parase Multimodal

# %%
import os
import json
from dotenv import load_dotenv
from llama_parse import LlamaParse
from glob import glob

# %%
load_dotenv(dotenv_path="../.env", override=True)
# Out:
# Python-dotenv could not parse statement starting at line 2
# True

# %%
parsing_instruction='''You are a highly proficient language model with advanced multimodal parsing capabilities. Your task is to process and extract content from a PDF document that serves as a camera manual.

**Specific Requirements:**

1. **Text Extraction:**  
   Extract all textual content from the document in a structured Markdown format. Preserve the hierarchy and formatting, including headings, subheadings, bullet points, numbered lists, and paragraphs.

2. **Image Identification and Inclusion:**  
   - Identify any images present in the document.  
   - For each image, insert a Markdown reference in the appropriate location using the syntax:  
     `![Image Description](ImagePlaceholder)`

3. **General Guidelines:**  
   - Maintain logical and clean formatting for Markdown output.
   - Avoid redundant or non-informative text (e.g., "Page number" or "Header/Footer").
   - Ensure extracted text and image references align with their original positions in the document.

**Example Output Structure:**  

# SHOOTING SETTING (Still Photography)
Adjust shooting options for still photography.

To display shooting settings, press **MENU/OK** in the photo shooting display and select the **SHOOTING SETTING** tab.

![Shooting Settings Menu](ImagePlaceholder)

> 💡 **Note:**
> - The options available vary with the shooting mode selected.

## SELF-TIMER
Choose a shutter release delay.

| Option   | Description                                                                                                         |
|----------|---------------------------------------------------------------------------------------------------------------------|
| 2 SEC | The shutter is released two seconds after the shutter button is pressed. Use to reduce blur caused by the camera moving when the shutter button is pressed. The self-timer lamp blinks as the timer counts down.  |
| 10 SEC| The shutter is released ten seconds after the shutter button is pressed. Use for photographs in which you wish to appear yourself. The self-timer lamp blinks immediately before the picture is taken. |
| OFF      | Self-timer off.                                                                                                    |

If an option other than **OFF** is selected, the timer will start when the shutter button is pressed all the way down. The display shows the number of seconds remaining until the shutter is released. To stop the timer before the picture is taken, press **DISP/BACK**.

![Timer Display](ImagePlaceholder)

> 💡 **Note:**
> - Stand behind the camera when using the shutter button. Standing in front of the lens can interfere with focus and exposure.
> - The self-timer turns off automatically when the camera is turned off.'''

parser = LlamaParse(
    api_key = os.getenv("LLAMA_CLOUD_API_KEY"),
    result_type="markdown",
    use_vendor_multimodal_model=True,
    vendor_multimodal_model_name="openai-gpt4o",
    vendor_multimodal_api_key=os.getenv("OPENAI_API_KEY"),
    parsing_instruction = parsing_instruction,
    invalidate_cache=True
)

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
camera_model = "x-e4"
splited_pdf_path = f"../data/raw_data/{camera_model}/{camera_model}_split/*.pdf"
pdf_list = glob(splited_pdf_path)

json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "init_result")
if not os.path.exists(detail_json_dir):
    os.makedirs(detail_json_dir)

for pdf in pdf_list:
    json_objs = parser.get_json_result(pdf)

    file_path, file_name = os.path.split(pdf)
    name = os.path.splitext(file_name)[0]
    json_path = os.path.join(detail_json_dir, name+".json")
    
    with open(json_path, "w", encoding="utf-8") as file:
        json.dump(json_objs[0], file, ensure_ascii=False, indent=4)
# Out:
# Started parsing the file under job_id 6391c917-5431-49f6-a9cb-9aa6e7ed847a
# Started parsing the file under job_id f1dd721e-3a06-4a5b-accc-f53affafd330
# Started parsing the file under job_id 8d03821d-6c3b-4972-995a-98fb5d99e870
# Started parsing the file under job_id 92ceae71-827a-4c62-a47e-728cac518b3e
# Started parsing the file under job_id 88230244-4998-45c6-85ae-d49bcf16777f
# Started parsing the file under job_id b63a6ce6-69da-4e12-96a4-fb77c2258be5
# Started parsing the file under job_id 3acc3896-fdbb-4a75-88ac-901d80b492f9
# Started parsing the file under job_id 4fffc6c4-346f-4072-8ace-cf3ccb9ffd70
# Started parsing the file under job_id ffb59caf-7dc3-44fa-935f-545a2e15e1ea
# Started parsing the file under job_id dd4eb025-a13e-4a61-8489-47fcba9f56f5
# Started parsing the file under job_id 23dafe9d-56bc-441a-b922-7ac4d42ef9d4
# Started parsing the file under job_id a1d28ae9-623d-4aaf-a97e-572a2979cb7a
# Started parsing the file under job_id 8a0f6a40-b771-4067-bfb2-d20c96fe86ca
# Started parsing the file under job_id a46e1725-901b-4f7b-b5b4-c1d81037777a
# Started parsing the file under job_id ccb5f9de-2585-40e8-96cf-3004ea488d1b
# Started parsing the file under job_id 5816bc1a-e43f-47c5-bc2f-45f1a7b6bb14
# Started parsing the file under job_id 0ba6dec1-b876-4007-94d5-e7f6caf3d950
# Started parsing the file under job_id 91147d6f-1973-4a69-9212-4f82e7b5935a
# Started parsing the file under job_id e53272a8-4e09-4265-9dc2-084d958bfcd5
# Started parsing the file under job_id 7ec55e4c-d70b-4755-b4cc-6f94a5599b71
# Started parsing the file under job_id 4b621792-c53f-4e05-a00a-7fd2a0de65fb
# Started parsing the file under job_id 56d7bfc0-af2e-4cf3-81d6-81acce02bf1d
# Started parsing the file under job_id 105bb8b1-0e3e-44c5-83b2-6c48b04da21f
# Started parsing the file under job_id 3146fb1c-532e-4434-9589-49c08d776b03
# Started parsing the file under job_id 73ceceb0-6c00-4a3b-b91c-b7b8937662ca
# Started parsing the file under job_id 64d81499-0f58-414d-b0e7-a15a4c09d130
# Started parsing the file under job_id 0be25787-5e2c-4e1c-874c-7184ee2b28be
# Started parsing the file under job_id 9d4087ca-6065-46c0-b366-7428ce78def7
# Started parsing the file under job_id a142e686-3630-4c53-a177-d18fd9c25c5c
# Started parsing the file under job_id 3435d1b0-0a3b-41dc-a0d5-5e972726088e
# Started parsing the file under job_id 64792672-dbb4-48cd-9024-8ff6a66fb3fc
# Started parsing the file under job_id 641d4133-f42a-4e72-b6bd-80d72157bfbf
# Started parsing the file under job_id d881b98b-782f-41c6-820c-db4534186f74
# Started parsing the file under job_id a4331be9-96fe-41b5-b185-a1e0696719e7
# Started parsing the file under job_id da21ec66-14a1-4940-b932-7bc64c68bc16
# Started parsing the file under job_id 24315c74-75c6-48ac-b3a5-523fb6e8f3db
# Started parsing the file under job_id ea426bde-0b72-4e34-8f68-05cd8ca6b68a
# Started parsing the file under job_id 01517e6b-06af-4203-8e22-654627963a0b
# Started parsing the file under job_id b8f1dd69-a09c-480e-bbaa-308c279bf76c
# Started parsing the file under job_id 3417358f-d03b-4666-9a71-3ff8b4b47c10
# Started parsing the file under job_id c520ac76-a3cb-4584-b5e2-0e8a3516a2d1
# Started parsing the file under job_id 10d3b6ae-37cd-406b-a840-6e2a9a153d1b
# Started parsing the file under job_id ff6de7cc-9a93-4b1f-a04a-8c77a58c770b
# Started parsing the file under job_id 2ead4808-cedc-451b-ab88-5d90c47415f4
# Started parsing the file under job_id e950a4d1-c702-4330-9743-eced43015086
# Started parsing the file under job_id 2c36d247-d2ab-426e-8f8b-a9077413a135
# Started parsing the file under job_id 3f45390f-5d4b-4c6b-9132-d0d28bfba920
# Started parsing the file under job_id 959996aa-f261-452d-8baf-e693204a7ff3
# Started parsing the file under job_id c34da6b3-0867-4dc9-8f41-927f43e37417
# Started parsing the file under job_id 281e425d-42c4-4c0a-90a4-816c4262cd4d
# Started parsing the file under job_id 839a73d4-c54d-451a-8295-cb73dd69f6bf
# Started parsing the file under job_id 99cd7581-3fb3-4096-b242-75aecf3821b6
# Started parsing the file under job_id 855263c6-58c8-4774-81dd-1ffc11478c8b
# Started parsing the file under job_id f51009e5-c98e-4825-b836-d95bf994c564
# Started parsing the file under job_id fb289368-b461-460f-8f6b-bfb9baf7c8ba
# Started parsing the file under job_id 53d139e1-9168-4bf1-b40a-8c94b0e48a36
# Started parsing the file under job_id 25ab71b2-4e05-455c-a398-680bc8763dd8
# Started parsing the file under job_id 23c1202d-5602-4a3a-baa9-eb4faa5dc542
# Started parsing the file under job_id a983f4c4-af04-4504-87a5-23ac7e7157ee
# Started parsing the file under job_id e2c42382-48ea-4660-ab18-7fd904adc042
# Started parsing the file under job_id 143e111a-42e9-4112-ae09-27fbea8fc127
# Started parsing the file under job_id 67eae090-7b4a-4908-8def-f9c7340caf88
# Started parsing the file under job_id dc6eaebe-65e6-4105-898c-a20251c815ef
# Started parsing the file under job_id 6b3c9507-87c5-40e8-a0c1-b1cab9601837
# Started parsing the file under job_id 5275181a-b9ac-4904-ac42-d3be18a1698b
# Started parsing the file under job_id 43fb72ca-79fe-432f-b662-cf11bd34778e
# Started parsing the file under job_id 6d5cb8be-a4ea-409e-9280-3e21deb986cc
# Started parsing the file under job_id 1a7a008f-7fa4-4418-a431-972ca48b91c5
# Started parsing the file under job_id 30262a9d-4539-4a1b-a372-a6ea91e44a98
# Started parsing the file under job_id 85f75934-4db8-44a6-a13e-7a272916d525
# Started parsing the file under job_id 2911430c-6e0a-4576-911d-bc0bf80dbd69
# Started parsing the file under job_id 0a7fbc0f-f212-4a31-9604-19262820326c
# Started parsing the file under job_id 25266e64-a450-47c6-b855-f4bd57cea4ef
# Started parsing the file under job_id 346e77dc-fedf-4977-b6bb-8c6f0b6b3e4e
# Started parsing the file under job_id 2ba50496-d29d-4931-94bc-34fad3587e25
# Started parsing the file under job_id c797e1c7-918d-476b-b8dc-d34c4d985c72
# Started parsing the file under job_id 5eed4a4e-125c-4cf4-a038-2e3cdf238593
# Started parsing the file under job_id f651f86a-19c2-46cd-941f-131a5d7e11dd
# Started parsing the file under job_id 030d1ec6-ebac-446c-9770-3c85f82e26bb
# Started parsing the file under job_id 16202c38-9f75-45e7-a2da-c6ea39e3d4e0
# Started parsing the file under job_id bc13ffe2-12b3-4fb9-8bad-a2ff1dc67382
# Started parsing the file under job_id 452c3763-93d5-4755-8371-486748bd6ef9
# Started parsing the file under job_id de90ff0f-e93f-4ca5-bb65-1473492ca68e
# Started parsing the file under job_id 771871be-c210-4bb5-8578-119e08d34e22
# Started parsing the file under job_id 41ab539f-e83a-4959-9ec8-651639b5602f
# Started parsing the file under job_id 83de4912-874b-4a67-b5d6-ed0400aeda8f
# Started parsing the file under job_id d5fa9dc5-9197-497e-8d94-93494cf774c1
# Started parsing the file under job_id 1b51a0aa-d188-434e-9784-b7662c5eeb11
# Started parsing the file under job_id bea9c1d1-0e75-49a8-8ff7-00e10b34721c
# Started parsing the file under job_id c92e798a-4383-4726-917f-a357572f7bb5
# Started parsing the file under job_id 49bac48b-be4e-4f3b-a937-32d5e91fcdf4
# Started parsing the file under job_id 0b02ea05-4390-45b5-ac75-62bf13f53c5d
# Started parsing the file under job_id 575a90d1-f80a-4f4c-8cd4-86bc3a03c5bd
# Started parsing the file under job_id f7e42f3b-25c5-4f0e-a42e-d40f44731fc6
# Started parsing the file under job_id 420abf77-da0a-41ff-ab09-c43a9ad8c7e7
# Started parsing the file under job_id 860b0576-7e23-4208-9392-b6e72732935f
# Started parsing the file under job_id 044c54a4-b965-4748-9d9b-c36ae27a4fd6
# Started parsing the file under job_id 810ca399-c218-4adf-9b5c-bd785d800e6b
# Started parsing the file under job_id 9b2c2a36-f429-4049-9bd3-a41784ff40c7
# Started parsing the file under job_id a424a44b-6b25-46ff-8eba-8629e5352fc4
# Started parsing the file under job_id e56225f9-5740-41f7-a16e-5b1b005ae6b7
# Started parsing the file under job_id ffc4148d-e4b4-4d59-a369-9a786acb0bc6
# Started parsing the file under job_id be855a68-e1ad-41db-8b14-36ad2cd3e26e
# Started parsing the file under job_id a7c7bb3d-d420-475f-8f07-3380586317a2
# Started parsing the file under job_id 9cc121f5-db03-4297-9a38-0a336877714f
# Started parsing the file under job_id ea726539-d28b-4d32-9822-2d83fb3e91ba
# Started parsing the file under job_id 7188b14d-e388-4633-91c5-5765ceef1ddb
# Started parsing the file under job_id d9ba2b80-d6d1-47d2-b550-be8d47d929ab
# Started parsing the file under job_id 5e5e7d9f-a2ef-4bf5-8646-418ed1664fa3
# Started parsing the file under job_id 0d0fab90-1039-4548-80b7-c096f44e0c7b
# Started parsing the file under job_id f03b6147-2438-4c40-8df3-a07c8349e7d9
# Started parsing the file under job_id ad675a93-7e23-45ec-8871-e2f8df5f2332
# Started parsing the file under job_id c93d1d7f-5439-424b-b5d6-8a42e1ebe79b
# Started parsing the file under job_id 3a251d27-28eb-4016-8721-b2a894541a32
# Started parsing the file under job_id 84dc52e2-1728-477a-a3c4-abc926547839
# Started parsing the file under job_id 69b55714-b8d5-4ab4-b0aa-389a111869d1
# Started parsing the file under job_id 495948c3-618c-44ee-ae60-f7799d327fa1
# Started parsing the file under job_id eb89ac30-0b5b-427f-8fde-a08811429e18
# Started parsing the file under job_id 0c7d9cfc-a826-44d5-ae4d-3f12a9c72f4b
# Started parsing the file under job_id 7aa4bf8f-6321-4c3b-99a9-3eb3cf65e984
# Started parsing the file under job_id 14ead468-298b-48a9-897a-28d6fd01e869
# Started parsing the file under job_id af7c4088-2a80-4ce0-b90e-ebaebcc32a77
# Started parsing the file under job_id 7a620f1c-cffd-4761-8781-4844d4f38942
# Started parsing the file under job_id 7040b66c-a317-4572-8184-24de55386cfc
# Started parsing the file under job_id 78fb5606-a9df-4e7f-885d-7524a0382055
# Started parsing the file under job_id d46d2c73-0684-4b00-b22f-23e4cbfda195
# Started parsing the file under job_id ab8eb0f7-a600-4a49-89da-8b78e65ece03
# Started parsing the file under job_id dfc7a9d7-ec65-4698-af1a-4f425f3761e9
# Started parsing the file under job_id 70f72c8d-bb87-4f69-9a26-0aa068693087
# Started parsing the file under job_id 6a27ef4d-73d9-4f22-a5bf-8a306ad676d1
# Started parsing the file under job_id eda09146-b8ac-42bb-a8ef-10d16afc6aac
# Started parsing the file under job_id 8695ff4c-7aba-4449-9f0f-50de8aa54a88
# Started parsing the file under job_id 80f7888e-43a0-4268-a2d4-37ae70a69214
# Started parsing the file under job_id 746e09a5-d545-4aa4-88f7-5a8c72ddfd2f
# Started parsing the file under job_id a9eab064-b424-49d3-82f0-5cfa9d5feffa
# Started parsing the file under job_id bbf71670-c29a-4c61-bb45-3fd9a87a4c2d
# Started parsing the file under job_id 53a97b17-887c-49ef-b43b-d8d28d2afb22
# Started parsing the file under job_id 5dec173d-9542-4fb8-9549-c54c6df53b9b
# Started parsing the file under job_id fd92b01a-8d81-4c1e-9cb7-42b2daee2117
# Started parsing the file under job_id f1cefd06-e949-491f-996a-e51f425757d3
# Started parsing the file under job_id 24425fb6-b70f-4006-88b3-d36b59394aa6
# Started parsing the file under job_id 33e473cd-8e2d-4819-a51e-8a490bb01e84
# Started parsing the file under job_id 1fca0672-3b51-42b0-994e-7df440ee64b9
# Started parsing the file under job_id 59d6acd9-7824-438c-ae60-4194222b8392
# Started parsing the file under job_id f3d8b219-2256-4a2d-a59a-185f9480ab0b
# Started parsing the file under job_id ec5a05be-16d8-476b-a3ab-13c0df6e610f
# Started parsing the file under job_id 502feda4-99dd-421c-8283-fac1c27ce560
# Started parsing the file under job_id 4892ed50-b689-4779-b156-70a661053a4c
# Started parsing the file under job_id e21a5657-abdb-45a8-b5a7-a2d12d14e65d
# Started parsing the file under job_id de539999-b154-48ee-887c-900f69eef1cc
# Started parsing the file under job_id 866b49ef-d4e9-4484-b09a-9d803d04eabb
# Started parsing the file under job_id fdd0b07b-1fd3-4e22-86c9-80c7b6995ab2
# Started parsing the file under job_id 54fc36ac-d8f8-4af5-aa2b-76fa4a2dd10f
# Started parsing the file under job_id bd18ac86-d9d6-4ee5-8682-cecec5e33633
# Started parsing the file under job_id 7b43a507-b613-4f6c-ad12-864cffa399b7
# Started parsing the file under job_id e85e0fc9-b1d1-4012-86fb-00df18118590
# Started parsing the file under job_id 8d1fdff9-48e1-4edd-882d-16e89da383a7
# Started parsing the file under job_id 05660c93-ed56-4706-bf62-76c8cf6469a6
# Started parsing the file under job_id 6f3138bd-e689-4a73-82f2-5562edb1c121
# Started parsing the file under job_id c64eb118-4c95-4d09-9eab-f9a41a3fb131
# Started parsing the file under job_id 0c042562-805d-409a-8d4a-8170f9513f99
# Started parsing the file under job_id 95096a38-6c1c-4674-9624-9bc2e47194bd
# Started parsing the file under job_id 182b4466-7bd3-41a0-83d0-4096b919df3b
# Started parsing the file under job_id b3038797-6d77-494d-bbd4-4b02a714895b
# Started parsing the file under job_id 8e7e4483-0a30-4adf-b178-0110ba333e26
# Started parsing the file under job_id b3adb0ce-ace6-481e-b202-2e205e027b6d
# Started parsing the file under job_id a9d60e9f-b988-41d2-97ed-fa676e58b3cc
# Started parsing the file under job_id c52a73de-18e6-44e9-ad38-50515959436b
# Started parsing the file under job_id 8ab3b654-93db-4429-908c-898fd3e76a6c
# Started parsing the file under job_id d229a715-8014-4204-99a4-5a36a8a9a368
# Started parsing the file under job_id b17ff0a6-5bf0-47c6-8f72-4fcdb49f1277
# Started parsing the file under job_id 63d18002-adeb-4c2f-946c-e94d8ab21b2c
# Started parsing the file under job_id b1de7b42-39bc-4732-8750-70763b017c11
# Started parsing the file under job_id 64e33342-10a8-4477-a727-98b1fe52e2a3
# Started parsing the file under job_id a68375e0-b45b-4e3c-956d-747c65fe6dd5
# Started parsing the file under job_id 7be4882b-5035-45e6-8cea-42855c5653e5
# Started parsing the file under job_id a326767a-f39d-41a7-bd88-9e8eed94b1eb
# Started parsing the file under job_id f8729574-17e1-4a56-ac7d-fd06db450207
# Started parsing the file under job_id 317c5ec3-8447-4b33-adde-41fe0ffac6df
# Started parsing the file under job_id fcafa127-a370-419f-be4d-e425f6d4d2ae
# Started parsing the file under job_id 93e8264f-050b-4617-a4bc-50849e6443f9
# Started parsing the file under job_id 265e26af-99a2-43b5-b811-481584a35c4b
# Started parsing the file under job_id f16defd3-1be5-46ac-8c4c-e57b6f643d1c
# Started parsing the file under job_id d93a3b70-06d3-40d2-b505-71c13794e75f
# Started parsing the file under job_id 27fb929e-67b5-4a39-acaa-5126b8978039
# Started parsing the file under job_id 999a074a-a116-408d-a226-858ca24f027b
# Started parsing the file under job_id 8a570804-1ad5-4d62-bd8c-799532bc5297
# Started parsing the file under job_id 243b4e68-83d0-4570-83c8-987e7ccc645a
# Started parsing the file under job_id 7b6389b3-75c0-4528-8716-682faa8bfaaf
# Started parsing the file under job_id 574ae903-bee6-48d7-89b3-c781f884c687
# Started parsing the file under job_id c021a3b0-4beb-494a-bc8a-ac97d37741cb
# Started parsing the file under job_id 824b99c3-6bfc-4da2-a1fc-36e08629838a
# Started parsing the file under job_id 0b3c8395-1c50-4548-8274-8f50b6091f32
# Started parsing the file under job_id 288e1e2b-4e34-481f-a6c7-0bb15536d042
# Started parsing the file under job_id 193c7229-c7b1-4061-96f9-90e709e35939
# Started parsing the file under job_id 82ed1204-75cb-419b-8f3b-a454f91ced6c
# Started parsing the file under job_id 7b70b209-a903-40a5-9ab7-ecc66fc6c126
# Started parsing the file under job_id 7226fb87-700a-4efa-bf37-fac05a89e7e8
# Started parsing the file under job_id 373d2b5e-4f14-4baa-93fc-c3fce0cdfc11
# Started parsing the file under job_id 25f584d3-67fd-4d4f-98a8-c644cb2734e5
# Started parsing the file under job_id fd7ec365-32a7-4ffb-9358-becf803db174
# Started parsing the file under job_id be012c08-0fe3-479c-bba4-f2c535f0dbb1
# Started parsing the file under job_id f973b031-d655-4e80-a998-0d86a1950e4e
# Started parsing the file under job_id 413e6dfa-3f5d-439b-a1ef-857d6f611e10
# Started parsing the file under job_id d1e9114d-07e6-4e28-b4bd-36b59617599c
# Started parsing the file under job_id 4662cf78-a6e6-4522-8a42-5593ef0674b6
# Started parsing the file under job_id 2da29389-b2a0-4244-95ba-615637a6c628
# Started parsing the file under job_id 53bb08ac-4329-4461-859a-067d0d98958f
# Started parsing the file under job_id d9515f16-b634-463f-8d28-ac94d793ea34
# Started parsing the file under job_id 6bfa328a-0594-4e9f-8659-a8abd9d5982d
# Started parsing the file under job_id 5d63fd74-539d-4822-8314-5f6811a8315f
# Started parsing the file under job_id 8f86380e-c302-435f-a336-9e426a1ec033
# Started parsing the file under job_id 3356d251-68e1-4c9e-9b24-b38c83f00c58
# Started parsing the file under job_id 2577ec8e-e8d2-4e33-962c-7c92fa3a3ee7
# Started parsing the file under job_id f9688cae-c809-4bb5-a346-6bd4e14e5de6
# Started parsing the file under job_id c9834060-22c2-45c0-a617-c1bec515f24d
# Started parsing the file under job_id b31f0590-5da6-451f-85d2-d94c6bb58a04
# Started parsing the file under job_id 7a95a8a1-acec-4d25-884c-ca72fbf7731b
# Started parsing the file under job_id e45824eb-c46f-4562-84ef-1ae792a3ec2b
# Started parsing the file under job_id 06bb1af8-e64c-47f7-8a96-2dce647c41c9
# Started parsing the file under job_id 4b034c86-b536-4524-a8b3-8b521b4db52e
# Started parsing the file under job_id 2f81433c-ddb8-4d7c-9e74-6ad24d9f0124
# Started parsing the file under job_id 8db324ba-efe3-4273-9ce1-3d270a180d4e
# Started parsing the file under job_id e2df29f7-3d10-42f5-921f-bd1fda96aefb
# Started parsing the file under job_id c74e8dbe-0eb5-4a82-b3ec-f42d000e4e91
# Started parsing the file under job_id 6a1e8f4c-ccf7-47bb-b0a7-bad8cb8b0c88
# Started parsing the file under job_id 36a7b641-06bc-4109-851a-58f2780a5894
# Started parsing the file under job_id 319eedb1-f7e3-4e19-b19f-b8b9c1c8487f
# Started parsing the file under job_id ab6344d0-eccf-4e80-92b1-0ffd20ae6b48
# Started parsing the file under job_id e77c1510-1427-49f9-a236-73af497c17bf
# Started parsing the file under job_id 100e61e8-0931-4b66-8b37-32dab2bdb325
# Started parsing the file under job_id 13f17b02-87f5-46bd-ae12-deedeadc48fb
# Started parsing the file under job_id 6460b6ee-959e-4279-96ee-9a435364579e
# Started parsing the file under job_id 3a52e6ca-3ab3-4260-ad10-5d677144c897
# Started parsing the file under job_id 94113509-34af-42e4-847a-a2acfb75bf40
# Started parsing the file under job_id c8293944-5ba8-42b5-8389-c7e2b9fdfad5
# Started parsing the file under job_id 74b83118-b89d-49d8-ab63-d230703e1d37
# Started parsing the file under job_id 30de07df-e364-4f9b-b92f-143f7e3f37f1
# Started parsing the file under job_id 1bb21c89-548b-4b5a-9b93-834fc02b64ea
# Started parsing the file under job_id 73bf8639-fb4e-44ce-9124-9029da9e3cc1
# Started parsing the file under job_id 6ddbcbfd-bda4-4476-9fd6-ef513d1ced59
# Started parsing the file under job_id a4d4a1b4-c492-4310-b350-42badc57a31a
# Started parsing the file under job_id d534e261-530f-4aee-b2ff-dbf77ce6ab84
# Started parsing the file under job_id 8305f969-8e5d-4932-9bff-2df91dfb3182
# Started parsing the file under job_id 588d7db5-70a4-43a3-9d5c-a7ef5a334bd1
# Started parsing the file under job_id d2812695-bbe5-403f-97bc-e2fc2095e20b
# Started parsing the file under job_id 0edae5c3-6c27-41f2-9663-e16b049175d7
# Started parsing the file under job_id 4e5dab2f-77dc-48c2-9e4d-1f5c884fd096
# Started parsing the file under job_id a6bee2f0-0616-49b9-85d8-4c4f6d40e496
# Started parsing the file under job_id 4e812bdd-7a0f-43a6-8eb6-ebda5f77dea2
# Started parsing the file under job_id 319504ce-dd39-45af-9d29-c0d7ee49016c
# Started parsing the file under job_id 313b2a3a-d9e0-4ee3-a698-5790ad609468
# Started parsing the file under job_id 16e9609a-2c31-48de-8c9f-d5c8ecf0daaf
# Started parsing the file under job_id bac8c389-c04f-4f24-b114-4e07b2b320aa
# Started parsing the file under job_id 51c40e0b-2ff8-48d3-a05c-ed89236e70b1
# Started parsing the file under job_id f5be2244-0db7-4490-ba8f-b9254e1bbf9b
# Started parsing the file under job_id 05ae2a59-a265-434e-87ce-ffc5dfb34399
# Started parsing the file under job_id 5873cab6-fe27-4754-b29c-dd8ff7faf53d
# Started parsing the file under job_id 85d87328-4b72-4e84-a485-9d874743984c
# Started parsing the file under job_id 43b80be7-2dd8-42bf-9b1b-b0f32db53fd8
# Started parsing the file under job_id bc1a1076-5bd1-4a03-a61a-c18c2ccd8fe7
# Started parsing the file under job_id c0b3d6ff-c34b-4a73-aa3c-949c9abe619c
# Started parsing the file under job_id ce3812c1-4cb2-4a39-9840-57b1c0ed8ae7
# Started parsing the file under job_id d1474482-788e-4fcb-b850-4831d42dd452
# Started parsing the file under job_id c51b77b0-912a-476b-8bbb-afb68b78282b
# Started parsing the file under job_id 4182d673-120f-4f00-9437-68896c8c1b24
# Started parsing the file under job_id 11f322b1-d853-44dc-a23d-3af5509137a6
# Started parsing the file under job_id 0bd118a3-75c7-4128-bfdc-c1de95ac8901
# Started parsing the file under job_id 9b732361-4b91-4137-8469-4b1c91fd1845
# Started parsing the file under job_id 4891ba29-f585-45cd-ae3b-deef8693801c
# Started parsing the file under job_id 718cfb26-403f-4eeb-8f98-a831d99dbf61
# Started parsing the file under job_id 9ad0d310-42b1-4c1c-a818-5c7f80c6ea7a
# Started parsing the file under job_id 5a286412-e866-43d5-ab15-ea3b7931bdef
# Started parsing the file under job_id 0f82b0b3-8713-48f6-9ee8-ee1228e8d9f6
# Started parsing the file under job_id 31df473f-11b3-4f66-9dee-8385ca24a851
# Started parsing the file under job_id c5199559-d197-4ce2-8f14-193e2a88522a
# Started parsing the file under job_id f6010393-ab73-4b3b-9ad8-3f4cb463fabb
# Started parsing the file under job_id 834eb45f-4f20-4f9b-bcca-f1c5b16cac4b
# Started parsing the file under job_id 0bde325d-f1ac-432c-8423-b9a0c86497ba
# Started parsing the file under job_id cded6cbf-1a71-4725-88d2-7662cf039dfd
# Started parsing the file under job_id 53497759-2aab-4bb6-b012-e20f04c2617e
# Started parsing the file under job_id cd937c92-830a-44a9-8096-a2d040bd7e52
# Started parsing the file under job_id baaa2544-3aec-4c20-b070-c7b34029fa02
# Started parsing the file under job_id 85527d27-1c84-4254-be99-b5e67b2d5242
# Started parsing the file under job_id f58759c0-f3a6-41e3-b37c-5a3db8e49792
# Started parsing the file under job_id 81435393-01d4-4a88-b7ec-accf5cbad037
# Started parsing the file under job_id e72b13e9-07da-45d9-b616-dc8a939a49e4
# Started parsing the file under job_id 2d760801-cb73-4155-bd94-73e13f11995d
# Started parsing the file under job_id 6dbd31f2-bb42-4d55-9b6d-e1a6849e7bd4
# Started parsing the file under job_id 67d96286-7576-4339-8e5e-f7cc939b0c27
# Started parsing the file under job_id c68a0f0a-92c8-41ae-8992-350f51b5a211
# Started parsing the file under job_id 220dee8a-0bc4-4bff-bae6-9d76d80285c7
# Started parsing the file under job_id ee05abfd-ef99-4f34-ba56-f2a8206dbd9d
# Started parsing the file under job_id ea5a9178-abb7-42a7-9cca-05fb7849c1db
# Started parsing the file under job_id 2379f1e0-04ae-45ef-bb96-1803130ee54e
# Started parsing the file under job_id 542cd4c5-79e4-4385-84d7-91ec21ff9b3a
# Started parsing the file under job_id 437e0742-0032-4e4a-be85-b54cf411d388
# Started parsing the file under job_id b9423660-f9a5-48cb-8878-3953d112da3c
# Started parsing the file under job_id 447e49a6-4a82-4670-b6ad-ffaa0f867d7f
# Started parsing the file under job_id c87963c2-34ba-49b9-8bea-51f1fb80824e
# Started parsing the file under job_id ec8d9d2f-8087-483c-9fcd-df5d2a6ec479
# Started parsing the file under job_id d828d712-6217-403f-ac27-6f847837c2cf
# Started parsing the file under job_id a6bbff57-ebdc-4fb2-8597-39b66a77f79c
# Started parsing the file under job_id 82af7365-58f2-4c31-a713-9b82eecade9d
# Started parsing the file under job_id b35d4fe9-7bc0-4281-9575-c49d5ae88fbe
# Started parsing the file under job_id 40d75854-0141-4cea-9d16-92c9751716e6
# Started parsing the file under job_id 4c5f2b55-3cd9-4a4a-b80f-679ad3f959a7
# Started parsing the file under job_id 9e604ecc-c449-4072-94c9-036d544d353f
# Started parsing the file under job_id 779b0080-6479-4c00-8d70-2f9d403b8597
# Started parsing the file under job_id 35868c7d-c640-4518-8e3c-38ffce4f83bf
# Started parsing the file under job_id 40af0f4c-6610-4e33-90e7-a83bd8d2f6bf
# Started parsing the file under job_id 1babeb2c-c351-4e57-9e78-0b7bd4b48a99
# Started parsing the file under job_id 3881b593-e693-4c60-82a0-bbded18bfd19
# Error while parsing the file '../data/raw_data/x-e4/x-e4_split/x-e4_page261.pdf': Server disconnected without sending a response.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 18
#      15 json_path = os.path.join(detail_json_dir, name+".json")
#      17 with open(json_path, "w", encoding="utf-8") as file:
# ---> 18     json.dump(json_objs[0], file, ensure_ascii=False, indent=4)
#
# IndexError: list index out of range

# %%
# error 
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 18
#      15 json_path = os.path.join(detail_json_dir, name+".json")
#      17 with open(json_path, "w", encoding="utf-8") as file:
# ---> 18     json.dump(json_objs[0], file, ensure_ascii=False, indent=4)

# IndexError: list index out of range
from glob import glob

splited_pdf_files = glob("../data/raw_data/x-e4/x-e4_split/*.pdf")
json_files = glob("../data/json/x-e4/LlamaParseMultimodal/init_result/*.json")

splited_pdf_len = len(splited_pdf_files)
json_len = len(json_files)
print(splited_pdf_len, json_len)

json_name = []
for i in json_files:
    json_name.append(os.path.splitext(os.path.basename(i))[0])

pdf_name = []
for i in splited_pdf_files:
    pdf_name.append(os.path.splitext(os.path.basename(i))[0])

missing_page = [item for item in pdf_name if item not in json_name]
print(missing_page)
print(len(missing_page))
# Out:
# 360 312
# ['x-e4_page261', 'x-e4_page119', 'x-e4_page282', 'x-e4_page313', 'x-e4_page325', 'x-e4_page266', 'x-e4_page106', 'x-e4_page49', 'x-e4_page105', 'x-e4_page75', 'x-e4_page143', 'x-e4_page352', 'x-e4_page249', 'x-e4_page256', 'x-e4_page124', 'x-e4_page304', 'x-e4_page329', 'x-e4_page232', 'x-e4_page72', 'x-e4_page109', 'x-e4_page198', 'x-e4_page246', 'x-e4_page162', 'x-e4_page26', 'x-e4_page317', 'x-e4_page142', 'x-e4_page251', 'x-e4_page214', 'x-e4_page206', 'x-e4_page185', 'x-e4_page324', 'x-e4_page330', 'x-e4_page71', 'x-e4_page320', 'x-e4_page45', 'x-e4_page181', 'x-e4_page167', 'x-e4_page70', 'x-e4_page318', 'x-e4_page74', 'x-e4_page220', 'x-e4_page104', 'x-e4_page306', 'x-e4_page243', 'x-e4_page153', 'x-e4_page111', 'x-e4_page148', 'x-e4_page27']
# 48

# %%
camera_model = "x-e4"
splited_pdf_path = f"../data/raw_data/{camera_model}/{camera_model}_split/*.pdf"
pdf_list = glob(splited_pdf_path)

json_dir = "../data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "init_result")
if not os.path.exists(detail_json_dir):
    os.makedirs(detail_json_dir)

missing_pdf_list = []
for file_name in missing_page:
    missing_pdf_list.append(os.path.join("../data/raw_data/x-e4/x-e4_split", f"{file_name}.pdf"))

for pdf in missing_pdf_list:
    json_objs = parser.get_json_result(pdf)

    file_path, file_name = os.path.split(pdf)
    name = os.path.splitext(file_name)[0]
    json_path = os.path.join(detail_json_dir, name+".json")
    
    with open(json_path, "w", encoding="utf-8") as file:
        json.dump(json_objs[0], file, ensure_ascii=False, indent=4)
# Out:
# Started parsing the file under job_id 30aa337e-7376-490d-a766-34659494e8cb
# Started parsing the file under job_id a63fb4b5-b54f-442f-bc3e-618f18435494
# Started parsing the file under job_id c32e9083-772f-471f-9896-e74300035aec
# Started parsing the file under job_id ebc7f7a6-284f-414f-a400-de04f2a4676c
# Started parsing the file under job_id 2761b174-8c91-407c-aae5-f92fb2aaed05
# Started parsing the file under job_id def3119c-70cb-44bd-b94b-7d955ebb858b
# Started parsing the file under job_id d7b4e4d0-f90c-4452-ae0f-89a3107aeb7e
# Started parsing the file under job_id 995663a5-2f09-4c12-bb17-a16d2f0ebd0a
# Started parsing the file under job_id 27c71c9e-7b29-49b7-a4bc-7ca5d38784f0
# Started parsing the file under job_id 856f4cb2-af26-4ee6-a248-bb63586ed983
# Started parsing the file under job_id bdadb47b-3392-4233-b236-542b8c54c32a
# Started parsing the file under job_id 1ffa3f15-6409-45f2-b14c-2e4efb0f20b3
# Started parsing the file under job_id ff4c2909-c380-4125-9a14-63ccc0179f0e
# Started parsing the file under job_id 0e4d15b0-1ae5-43a1-abf9-9751e30d0ff6
# Started parsing the file under job_id fb88392b-5d9e-4e2d-8836-b551ee318aa0
# Started parsing the file under job_id 6c1dd1da-e6e9-4c40-8a2d-501320a89e60
# Started parsing the file under job_id f83d4381-cdc3-4fc2-a8ca-db55cd2364c1
# Started parsing the file under job_id d467b987-46bd-46c2-974e-142b97d2302d
# Started parsing the file under job_id b66d23fa-4e9b-4b68-9f99-bde8a135f931
# Started parsing the file under job_id 886de5cf-2ef0-4849-bddc-ab078c468a3d
# Started parsing the file under job_id edf537e9-21ec-42be-ae90-a8f01ca28924
# Started parsing the file under job_id 0b978707-f420-415b-ba2a-7657df398923
# Started parsing the file under job_id dafb8fe7-2473-4ff0-b5dd-7323a362a720
# Started parsing the file under job_id c965ff62-3def-4e14-a57a-d5a67e1a9527
# Started parsing the file under job_id 80203992-60ac-4aa2-906b-10e0f5886ea2
# Started parsing the file under job_id a4ab47c1-70cf-4af4-9957-2b8c06dde7d4
# Started parsing the file under job_id 58a4481d-713d-4015-a3b7-c2223b09298c
# Started parsing the file under job_id dab0ebdb-245e-4bed-ba4d-e4de6969bb61
# Started parsing the file under job_id 08793520-a623-4095-a49a-55054c918495
# Started parsing the file under job_id 26761e75-0666-417b-996b-14fa7f6e5c72
# Started parsing the file under job_id 39ea1df2-554d-48e9-971b-0e16d723013c
# Started parsing the file under job_id 739494e6-c97c-4fee-91c2-3d7c11343619
# Started parsing the file under job_id e3c07bd4-b8af-440d-9d3e-dc31856880ed
# Started parsing the file under job_id 93801b03-fb84-477e-9819-72c06e328935
# Started parsing the file under job_id 9f06bbb4-6e2c-489c-8c7d-f6cbb86b60d9
# Started parsing the file under job_id e71d64e6-5a8e-4250-a82d-847a30c88219
# Started parsing the file under job_id 5a48b438-096e-435b-a9ca-92766bd3e23f
# Started parsing the file under job_id fa12d71c-4212-4364-b761-ccfbc82e04dc
# Started parsing the file under job_id 64bcb179-17ac-4cab-888e-53b813a062c4
# Started parsing the file under job_id ce14e7fb-2140-4650-9f13-fa7a160c3681
# Started parsing the file under job_id 37ab3527-b1c7-46b5-a293-f50d7ebf359d
# Started parsing the file under job_id 24df5ca4-7b1a-4255-9187-e3cf5644d736
# Started parsing the file under job_id bac26d96-a9f2-460d-93e3-f95ef1e0b594
# Started parsing the file under job_id 6e82eb23-92f8-4aa9-9157-4d5284153d8a
# Started parsing the file under job_id fdc0446d-5e22-44a0-b865-c594214039c5
# Started parsing the file under job_id ba218999-0346-43ec-b3d3-86127e6e3302
# Started parsing the file under job_id 608d80de-83be-4941-bba3-96010905ced6
# Started parsing the file under job_id f3ecef73-ebdf-4704-b8a1-29e26423d714

# %%
from glob import glob

splited_pdf_files = glob("../data/raw_data/x-e4/x-e4_split/*.pdf")
json_files = glob("../data/json/x-e4/LlamaParseMultimodal/init_result/*.json")

splited_pdf_len = len(splited_pdf_files)
json_len = len(json_files)
print(splited_pdf_len, json_len)

json_name = []
for i in json_files:
    json_name.append(os.path.splitext(os.path.basename(i))[0])

pdf_name = []
for i in splited_pdf_files:
    pdf_name.append(os.path.splitext(os.path.basename(i))[0])

missing_page = [item for item in pdf_name if item not in json_name]
print(missing_page)
print(len(missing_page))
# Out:
# 360 360
# []
# 0

# %% [markdown]
# # Modify Json
# - parsing_result
# - metadata: {
#     "model":,
#     "page":
#     }

# %%
import os
import re
import json
from glob import glob

from CameraDocument import CameraDocument

# %%
def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

# %%
camera_model = "x-e4"
json_dir = "./data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "init_result")
init_json_path = os.path.join(detail_json_dir, "*.json")

json_list = glob(init_json_path)
json_list = sorted(json_list, key=extract_number)

# %%
output_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for json_path in json_list:
    doc = CameraDocument()

    page_num = extract_number(json_path)
    if page_num >= 25:
        real_page_num = page_num - 24
        doc.metadata['page'] = real_page_num
        basename = camera_model + f"_page{real_page_num}.json"
        output_path = os.path.join(output_dir, basename)
    else:
        doc.metadata['page'] = page_num
        basename = camera_model + f"_front_page{page_num}.json"
        front_output_dir = os.path.join(output_dir, "front_page")
        output_path = os.path.join(front_output_dir, basename)
        if not os.path.exists(front_output_dir):
            os.makedirs(front_output_dir)

    doc.metadata['model'] = camera_model

    with open(json_path, "r", encoding="utf-8") as file:
        json_data = json.load(file)
        doc.parsing_result = json_data["pages"][0]["md"]
        doc.save_json(output_path)
# Out:
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page1.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page2.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page3.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page4.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page5.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page6.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page7.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page8.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page9.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page10.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page11.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page12.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page13.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page14.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page15.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page16.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page17.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page18.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page19.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page20.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page21.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page22.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page23.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/front_page/x-e4_front_page24.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page1.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page2.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page3.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page4.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page5.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page6.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page7.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page8.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page9.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page10.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page11.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page12.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page13.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page14.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page15.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page16.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page17.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page18.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page19.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page20.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page21.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page22.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page23.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page24.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page25.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page26.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page27.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page28.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page29.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page30.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page31.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page32.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page33.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page34.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page35.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page36.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page37.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page38.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page39.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page40.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page41.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page42.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page43.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page44.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page45.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page46.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page47.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page48.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page49.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page50.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page51.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page52.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page53.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page54.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page55.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page56.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page57.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page58.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page59.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page60.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page61.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page62.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page63.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page64.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page65.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page66.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page67.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page68.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page69.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page70.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page71.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page72.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page73.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page74.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page75.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page76.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page77.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page78.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page79.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page80.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page81.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page82.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page83.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page84.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page85.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page86.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page87.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page88.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page89.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page90.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page91.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page92.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page93.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page94.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page95.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page96.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page97.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page98.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page99.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page100.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page101.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page102.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page103.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page104.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page105.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page106.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page107.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page108.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page109.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page110.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page111.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page112.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page113.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page114.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page115.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page116.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page117.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page118.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page119.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page120.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page121.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page122.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page123.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page124.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page125.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page126.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page127.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page128.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page129.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page130.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page131.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page132.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page133.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page134.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page135.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page136.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page137.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page138.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page139.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page140.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page141.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page142.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page143.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page144.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page145.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page146.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page147.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page148.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page149.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page150.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page151.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page152.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page153.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page154.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page155.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page156.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page157.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page158.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page159.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page160.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page161.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page162.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page163.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page164.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page165.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page166.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page167.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page168.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page169.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page170.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page171.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page172.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page173.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page174.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page175.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page176.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page177.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page178.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page179.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page180.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page181.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page182.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page183.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page184.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page185.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page186.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page187.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page188.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page189.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page190.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page191.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page192.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page193.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page194.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page195.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page196.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page197.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page198.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page199.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page200.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page201.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page202.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page203.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page204.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page205.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page206.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page207.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page208.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page209.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page210.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page211.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page212.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page213.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page214.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page215.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page216.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page217.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page218.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page219.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page220.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page221.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page222.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page223.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page224.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page225.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page226.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page227.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page228.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page229.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page230.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page231.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page232.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page233.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page234.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page235.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page236.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page237.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page238.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page239.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page240.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page241.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page242.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page243.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page244.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page245.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page246.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page247.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page248.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page249.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page250.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page251.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page252.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page253.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page254.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page255.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page256.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page257.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page258.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page259.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page260.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page261.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page262.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page263.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page264.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page265.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page266.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page267.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page268.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page269.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page270.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page271.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page272.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page273.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page274.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page275.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page276.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page277.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page278.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page279.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page280.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page281.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page282.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page283.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page284.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page285.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page286.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page287.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page288.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page289.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page290.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page291.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page292.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page293.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page294.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page295.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page296.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page297.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page298.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page299.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page300.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page301.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page302.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page303.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page304.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page305.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page306.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page307.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page308.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page309.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page310.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page311.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page312.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page313.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page314.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page315.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page316.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page317.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page318.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page319.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page320.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page321.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page322.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page323.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page324.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page325.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page326.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page327.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page328.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page329.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page330.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page331.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page332.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page333.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page334.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page335.json complete
# ./data/json/x-e4/LlamaParseMultimodal/add_metadata/x-e4_page336.json complete

# %% [markdown]
# # Index page to .png

# %%
import os
import fitz

# %%
def extract_pages_as_images(pdf_path, output_folder, start_page, end_page, dpi=600):
    pdf_document = fitz.open(pdf_path)

    # Loop through the specified page range
    for page_number in range(start_page - 1, end_page):
        # Check if the page number is within bounds
        if page_number < 0 or page_number >= len(pdf_document):
            print(f"Page {page_number + 1} is out of range. Skipping.")
            continue

        # Load the page
        page = pdf_document[page_number]

        # Render the page to a pixmap with specified DPI
        pix = page.get_pixmap(dpi=dpi)

        # Define the output image path
        output_path = f"{output_folder}/{camera_model}_page{page_number + 1}.png"

        # Save the image
        pix.save(output_path)
        print(f"Saved page {page_number + 1} as {output_path}")

    # Close the PDF document
    pdf_document.close()

# %%
camera_model = 'x-e4'
image_dir = './data/image'
output_dir = os.path.join(image_dir, camera_model, "index_images")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
pdf_path = f"./data/raw_data/{camera_model}/{camera_model}.pdf"

# %%
extract_pages_as_images(pdf_path, output_dir, 11, 22, 600)
# Out:
# Saved page 11 as ./data/image/x-e4/index_images/x-e4_page11.png
# Saved page 12 as ./data/image/x-e4/index_images/x-e4_page12.png
# Saved page 13 as ./data/image/x-e4/index_images/x-e4_page13.png
# Saved page 14 as ./data/image/x-e4/index_images/x-e4_page14.png
# Saved page 15 as ./data/image/x-e4/index_images/x-e4_page15.png
# Saved page 16 as ./data/image/x-e4/index_images/x-e4_page16.png
# Saved page 17 as ./data/image/x-e4/index_images/x-e4_page17.png
# Saved page 18 as ./data/image/x-e4/index_images/x-e4_page18.png
# Saved page 19 as ./data/image/x-e4/index_images/x-e4_page19.png
# Saved page 20 as ./data/image/x-e4/index_images/x-e4_page20.png
# Saved page 21 as ./data/image/x-e4/index_images/x-e4_page21.png
# Saved page 22 as ./data/image/x-e4/index_images/x-e4_page22.png

# %% [markdown]
# # Delete
# - chapter cover page
# - memo page

# %%
from CameraDocument import CameraDocument

camera_model = 'x-e4'
json_dir = "./data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata", "front_page")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)
json_list[:5]

documents = []
for i, path in enumerate(json_list):
    if "front" in path:
        document = CameraDocument()
        document.load_json(path)
        documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 1, 'model': 'x-e4'}, parsing_result="!Fujifilm X-E4 Owner's Manual Cover\n\n# FUJIFILM\n\n## DIGITAL CAMERA X-E4\n\nFF200002  \nOwner’s Manual\n\nBL00005102-202 EN", embedding_result=[]),
#  CameraDocument(metadata={'page': 2, 'model': 'x-e4'}, parsing_result='# Introduction\n\nThank you for your purchase of this product. Be sure that you have read this manual and understood its contents before using the camera. Keep the manual where it will be read by all who use the product.\n\n## For the Latest Information\n\nThe latest versions of the manuals are available from:\n\nhttp://fujifilm-dsc.com/en/manual/\n\n!QR Code for Manual\n\nThe site can be accessed not only from your computer but also from smartphones and tablets. It also contains information on the software license.\n\nFor information on firmware updates, visit:  \nhttps://fujifilm-x.com/support/download/firmware/cameras/\n\n!Devices', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'x-e4'}, parsing_result='# Chapter Index\n\n- **Menu List** - iv\n\n1. **Before You Begin** - 1\n2. **First Steps** - 27\n3. **Basic Photography and Playback** - 41\n4. **Movie Recording and Playback** - 47\n5. **Taking Photographs** - 55\n6. **The Shooting Menus** - 103\n7. **Playback and the Playback Menu** - 181\n8. **The Setup Menus** - 207\n9. **Shortcuts** - 243\n10. **Peripherals and Optional Accessories** - 259\n11. **Connections** - 281\n12. **Technical Notes** - 297', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'x-e4'}, parsing_result='# Menu List\n\nCamera menu options are listed below.\n\n## Shooting Menus\n\nAdjust settings when shooting photos or movies.\n\n> 📄 See page 103 for details.\n\n### Photo Menus\n\n> Items marked with both !Photo Icon and !Movie Icon icons are available in both the still photography and movie shooting menus. Changes to these items in either menu also apply to the item in the remaining menu.\n\n| **IMAGE QUALITY SETTING** | Page | **AF/MF SETTING** | Page |\n|---------------------------|------|-------------------|------|\n| IMAGE SIZE                | 104  | FOCUS AREA        | 125  |\n| IMAGE QUALITY             | 105  | FOCUS MODE        | 125  |\n| RAW RECORDING             | 106  | AF MODE           | 125  |\n| FILM SIMULATION           | 106  | AF-C CUSTOM SETTINGS | 126 |\n| MONOCHROMATIC COLOR       | 108  | STORE AF MODE BY ORIENTATION | 130 |\n| GRAIN EFFECT              | 108  | AF POINT DISPLAY  | 130  |\n| COLOR CHROME EFFECT       | 108  | NUMBER OF FOCUS POINTS | 130 |\n| COLOR CHROME FX BLUE      | 109  | PRE-AF            | 131  |\n| WHITE BALANCE             | 109  | !Photo Icon !Movie Icon AF ILLUMINATOR | 131 |\n| DYNAMIC RANGE             | 113  | FACE/EYE DETECTION SETTING | 132 |\n| D RANGE PRIORITY          | 114  | AF+MF             | 134  |\n| TONE CURVE                | 114  | MF ASSIST         | 135  |\n| COLOR                     | 115  | FOCUS CHECK       | 135  |\n| SHARPNESS                 | 115  | INTERLOCK SPOT AE & FOCUS AREA | 136 |\n| HIGH ISO NR               | 115  | !Photo Icon INSTANT AF SETTING | 136 |\n| CLARITY                   | 116  | !Movie Icon DEPTH-OF-FIELD SCALE | 136 |\n| LONG EXPOSURE NR          | 116  | RELEASE/FOCUS PRIORITY | 137 |\n| LENS MODULATION OPTIMIZER | 117  | !Photo Icon AF RANGE LIMITER | 137 |\n| COLOR SPACE               | 117  | !Movie Icon TOUCH SCREEN MODE | 138 |\n| PIXEL MAPPING             | 117  |                   |      |\n| SELECT CUSTOM SETTING     | 118  |                   |      |\n| EDIT/SAVE CUSTOM SETTING  | 118  |                   |      |\n| AUTO UPDATE CUSTOM SETTING| 122  |                   |      |\n| !Photo Icon MOUNT ADAPTOR SETTING | 123  | | |', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'x-e4'}, parsing_result='# Menu List\n\n## Shooting Setting\n- **Sports Finder Mode** - 140\n- **Pre-Shot ES** - 141\n- **Self-Timer** - 141\n- **Save Self-Timer Setting** - 142\n- **Self-Timer Lamp** - 142\n- **Interval Timer Shooting** - 143\n- **Interval Timer Shooting Exposure Smoothing** - 144\n- **AE BKT Setting** - 144\n- **Film Simulation BKT** - 145\n- **Focus BKT Setting** - 145\n- **Multiple Exposure CTRL** - 145\n- **Photometry** - 145\n- **Shutter Type** - 146\n- **Flicker Reduction** - 147\n- **IS Mode** - 147\n- **ISO** - 148\n- **Wireless Communication** - 148\n\n## Flash Setting\n- **Flash Function Setting** - 149\n- **Red Eye Removal** - 149\n- **TTL-Lock Mode** - 150\n- **LED Light Setting** - 150\n- **Commander Setting** - 151\n- **CH Setting** - 151\n\n## Movie Setting\n- **Movie Mode** - 152\n- **File Format** - 152\n- **Full HD High Speed Rec** - 152\n- **IS Mode** - 152\n- **Audio Setting** - 153\n- **Mic/Remote Release** - 154', embedding_result=[])]

# %%
for document in documents:
    if document.metadata['page'] == 22:
        print(document.parsing_result)
# Out:
# # Technical Notes
#
# ## Accessories from Fujifilm
# - Page 298
#
# ## Software for Use with Your Camera
# - FUJIFILM Camera Remote .................................................. 301
# - FUJIFILM PC AutoSave ....................................................... 301
# - RAW FILE CONVERTER EX powered by SILKYPIX .......... 301
# - Capture One Express Fujifilm ........................................... 301
# - Capture One Pro Fujifilm .................................................. 302
# - FUJIFILM X Acquire .......................................................... 302
# - FUJIFILM X RAW STUDIO .................................................. 302
# - FUJIFILM X Webcam ......................................................... 302
#
# ## For Your Safety
# - Page 303
#
# ## Product Care
# - Page 312
#
# ## Cleaning the Image Sensor
# - Page 313
#
# ## Firmware Updates
# - Checking the Firmware Version ...................................... 314
#
# ## Troubleshooting
# - Page 315
#
# ## Warning Messages and Displays
# - Page 324
#
# ## Memory Card Capacity
# - Page 328
#
# ## Specifications
# - Page 329

# %%
from CameraDocument import CameraDocument
import os
from glob import glob
import re

camera_model = 'x-e4'
json_dir = "./data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "add_metadata")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)
json_list[:5]

documents = []
for i, path in enumerate(json_list):
    document = CameraDocument()
    document.load_json(path)
    documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 1, 'model': 'x-e4'}, parsing_result='!Before You Begin', embedding_result=[]),
#  CameraDocument(metadata={'page': 2, 'model': 'x-e4'}, parsing_result='\n# Parts of the Camera\n\nThe parts of the camera are listed below.\n\n!Camera Diagram\n\n1. **Shutter button** .................................................. 44\n2. **Exposure compensation dial** .................. 4, 80\n3. **Q (quick menu) button** ............................. 247\n4. **Shutter speed dial** .................................... 4, 56, 59, 63, 65\n5. **Hot shoe** ..................................................... 267\n6. **Microphone** ............................................... 50, 175\n7. **Strap eyelet** ................................................. 28\n8. **Connector cover**\n9. **Lens signal contacts**\n10. **Lens release button** .................................. 29\n11. **AF-assist illuminator** ................................. 131\n    - Self-timer lamp ........................................... 141\n    - Tally light .................................................... 163\n12. **Front command dial** ................................ 6\n13. **ON/OFF switch** ......................................... 35\n14. **Fn button** .................................................. 253\n15. **Body cap** .................................................. 29\n16. **Microphone/remote release connector** (ø3.5 mm) ................. 3, 50, 154\n17. **USB connector (Type-C)** ....................... 33, 50, 287\n18. **HDMI Micro connector (Type D)** .......... 282\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'x-e4'}, parsing_result='\n# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n19. **Diopter adjustment control**  \n   - Page: 9\n\n20. **Electronic viewfinder (EVF)**  \n   - Pages: 10, 14, 16, 21\n\n21. **Eye sensor**  \n   - Page: 15\n\n22. **DRIVE/DELETE button**  \n   - Pages: 5, 46, 87\n\n23. **PLAY (playback) button**  \n   - Page: 45\n\n24. **AEL (exposure lock)/AFL (focus lock) button**  \n   - Pages: 86, 253\n\n25. **Indicator lamp**  \n   - Pages: 7, 163  \n   - **Tally light**  \n     - Page: 163\n\n26. **Focus stick (focus lever)**  \n   - Pages: 5, 74, 224\n\n27. **MENU/OK button**  \n   - Page: 19\n\n28. **DISP (display)/BACK button**  \n   - Pages: 16, 183\n\n29. **Cable channel cover for DC coupler**  \n   - Page: 298\n\n30. **Battery-chamber cover latch**  \n   - Page: 30\n\n31. **Battery-chamber cover**  \n   - Page: 30\n\n32. **Tripod mount**\n\n33. **Speaker**  \n   - Pages: 52, 214\n\n34. **LCD monitor**  \n   - Pages: 8, 12, 14  \n   - **Touch screen**  \n     - Pages: 21, 138, 230\n\n35. **Battery chamber**  \n   - Page: 30\n\n36. **Memory card slot**  \n   - Page: 30\n\n37. **Battery latch**  \n   - Page: 31\n\n38. **Serial number plate**  \n   - See below\n\n> 💡 **Note:**\n> - **16:** Use of an optional RR-100 remote release requires a third-party adapter to convert the female three-pin, ø2.5 mm connector to a male three-pin, ø3.5 mm connector.\n> - **38:** Do not remove the serial number plate, which provides the CMIT ID, serial number, and other important information.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'x-e4'}, parsing_result='\n# Before You Begin\n\n## The Shutter Speed Dial\nRotate the shutter speed dial to choose the shutter speed (📖 56).\n\n!Shutter Speed Dial\n\n## The Exposure Compensation Dial\nRotate the dial to choose an exposure compensation amount (📖 80).\n\n!Exposure Compensation Dial\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'x-e4'}, parsing_result='# Parts of the Camera\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus Stick\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING** (page 224).\n\n## The DRIVE/DELETE Button\n\nPressing the **DRIVE/DELETE** button displays the drive-mode menu, where you can choose from the following drive modes.\n\n!Drive/Delete Button\n\n| Mode                | Page |\n|---------------------|------|\n| Single frame        | 42   |\n| High-speed burst    | 92   |\n| Low-speed burst     | 92   |\n| ISO BKT             | 88   |\n| WHITE BALANCE BKT   | 88   |\n| Bracketing          | 89   |\n| HDR                 | 93   |\n| Adv. MODE           |      |\n| • Panorama          | 95   |\n| • Multiple Exposure | 98   |\n| Filter              | 100  |\n| Movie               | 48   |', embedding_result=[])]

# %%
x_e4_contents = {
    "Before You Begin": {
        "page_range": [
            1,
            27
        ],
        "sections": {
            "Parts of the Camera": {
                "page_range": [
                    2,
                    10
                ],
                "subsections": {
                    "The Shutter Speed Dial": [4, 5],
                    "The Exposure Compensation Dial": [4, 5],
                    "The Focus Stick (Focus Lever)": [5, 6],
                    "The DRIVE/DELETE Button": [5, 6],
                    "The Command Dial": [6, 7],
                    "The Indicator Lamp": [7, 8],
                    "The LCD Monitor": [8, 9],
                    "Focusing the Viewfinder": [9, 10]
                }
            },
            "Camera Displays": {
                "page_range": [
                    10,
                    19
                ],
                "subsections": {
                    "The Electronic Viewfinder": [10, 12],
                    "The LCD Monitor": [12, 14],
                    "Adjusting Display Brightness": [14, 16],
                    "Display Rotation": [14, 16],
                    "Choosing a Display Mode": [14, 16],
                    "The DISP/BACK Button": [16, 17],
                    "Customizing the Standard Display": [17, 19]
                }
            },
            "Using the Menus": {
                "page_range": [
                    19,
                    21
                ],
                "subsections": {
                    "The Menus": [19, 20],
                    "Selecting a Menu Tab": [20, 21]
                }
            },
            "Touch Screen Mode": {
                "page_range": [
                    21,
                    27
                ],
                "subsections": {
                    "Shooting Touch Controls": [21, 25],
                    "Playback Touch Controls": [25, 27]
                }
            }
        }
    },
    "First Steps": {
        "page_range": [
            27,
            41
        ],
        "sections": {
            "Attaching the Strap": {
                "page_range": [
                    28,
                    29
                ],
            },
            "Attaching a Lens": {
                "page_range": [
                    29,
                    30
                ],
            },
            "Inserting the Battery and a Memory Card": {
                "page_range": [
                    30,
                    33
                ],
                "subsections": {
                    "Compatible Memory Cards": [32, 33]
                }
            },
            "Charging the Battery": {
                "page_range": [
                    33,
                    35
                ],
            },
            "Turning the Camera On and Off": {
                "page_range": [
                    35,
                    36
                ],
            },
            "Checking the Battery Level": {
                "page_range": [
                    36,
                    37
                ],
            },
            "Basic Setup": {
                "page_range": [
                    37,
                    41
                ],
                "subsections": {
                    "Choosing a Different Language": [39, 41],
                    "Changing the Time and Date": [39, 41]
                }
            }
        }
    },
    "Basic Photography and Playback": {
        "page_range": [
            41,
            47
        ],
        "sections": {
            "Taking Photographs (Mode P)": {
                "page_range": [42, 45],
            },
            "Viewing Pictures": {
                "page_range": [45, 46],
            },
            "Deleting Pictures": {
                "page_range": [46, 47],
            }
        }
    },
    "Movie Recording and Playback": {
        "page_range": [
            47,
            55
        ],
        "sections": {
            "Recording Movies": {
                "page_range": [48, 52],
                "subsections": {
                    "Recording Movies": [48, 51],
                    "Adjusting Movie Settings": [51, 52],
                },
            },
            "Viewing Movies": {
                "page_range": [52, 55],
            }
        }
    },
    "Taking Photographs": {
        "page_range": [
            55,
            103
        ],
        "sections": {
            "P, S, A, and M Modes": {
                "page_range": [56, 68],
                "subsections": {
                    "Mode P: Program AE": [56, 59],
                    "Mode S: Shutter-Priority AE": [59, 63],
                    "Mode A: Aperture-Priority AE": [63, 65],
                    "Mode M: Manual Exposure": [65, 67],
                    "Front Command Dial Roles by Mode": [67, 68],
                },
            },
            "Autofocus": {
                "page_range": [68, 77],
                "subsections": {
                    "Focus Mode": [69, 71],
                    "Autofocus Options (AF Mode)": [71, 73],
                    "Focus-Point Selection": [73, 77],
                },
            },
            "Manual Focus": {
                "page_range": [77, 80],
                "subsections": {
                    "Checking Focus": [78, 80],
                },
            },
            "Exposure Compensation": {
                "page_range": [80, 82],
                "subsections": {
                    "C (Custom)": [81, 82],
                },
            },
            "Sensitivity": {
                "page_range": [82, 84],
                "subsections": {
                    "Auto Sensitivity (A)": [83, 84],
                },
            },
            "Metering": {
                "page_range": [84, 85],
            },
            "Focus/Exposure Lock": {
                "page_range": [85, 87],
                "subsections": {
                    "Other Controls": [86, 87],
                },
            },
            "Bracketing": {
                "page_range": [87, 92],
                "subsections": {
                    "ISO BKT": [88, 89],
                    "White Balance BKT": [88, 89],
                    "BKT Bracketing": [89, 92],
                },
            },
            "Continuous Shooting (Burst Mode)": {
                "page_range": [92, 93],
            },
            "HDR": {
                "page_range": [93, 95],
            },
            "Panoramas": {
                "page_range": [95, 98],
            },
            "Multiple Exposures": {
                "page_range": [98, 100],
            },
            "Filters": {
                "page_range": [100, 101],
            },
            "Self-Portraits (Selfies)": {
                "page_range": [101, 103],
            }
        }
    },
    "The Shooting Menus": {
        "page_range": [
            103,
            181
        ],
        "sections": {
            "IMAGE QUALITY SETTING (Still Photography)": {
                "page_range": [104, 125],
                "subsections": {
                    "IMAGE SIZE": [104, 105],
                    "IMAGE QUALITY": [105, 106],
                    "RAW RECORDING": [106, 108],
                    "FILM SIMULATION": [106, 108],
                    "MONOCHROMATIC COLOR": [108, 109],
                    "GRAIN EFFECT": [108, 109],
                    "COLOR CHROME EFFECT": [108, 109],
                    "COLOR CHROME FX BLUE": [109, 113],
                    "WHITE BALANCE": [109, 113],
                    "DYNAMIC RANGE": [113, 114],
                    "D RANGE PRIORITY": [114, 115],
                    "TONE CURVE": [114, 115],
                    "COLOR": [115, 116],
                    "SHARPNESS": [115, 116],
                    "HIGH ISO NR": [115, 116],
                    "CLARITY": [116, 117],
                    "LONG EXPOSURE NR": [116, 117],
                    "LENS MODULATION OPTIMIZER": [116, 117],
                    "COLOR SPACE": [117, 118],
                    "PIXEL MAPPING": [117, 118],
                    "SELECT CUSTOM SETTING": [118, 122],
                    "EDIT/SAVE CUSTOM SETTING": [118, 122],
                    "AUTO UPDATE CUSTOM SETTING": [122, 123],
                    "MOUNT ADAPTER SETTING": [123, 125]
                }
            },
            "AF/MF SETTING (Still Photography)": {
                "page_range": [125, 140],
                "subsections": {
                    "FOCUS AREA": [125, 126],
                    "FOCUS MODE": [125, 126],
                    "AF MODE": [125, 126],
                    "AF-C CUSTOM SETTINGS": [126, 130],
                    "STORE AF MODE BY ORIENTATION": [130, 131],
                    "AF POINT DISPLAY": [130, 131],
                    "NUMBER OF FOCUS POINTS": [130, 131],
                    "PRE-AF": [131, 132],
                    "AF ILLUMINATOR": [131, 132],
                    "FACE/EYE DETECTION SETTING": [132, 134],
                    "AF+MF": [134, 135],
                    "MF ASSIST": [134, 135],
                    "FOCUS CHECK": [135, 136],
                    "INTERLOCK SPOT AE & FOCUS AREA": [136, 137],
                    "INSTANT AF SETTING": [136, 137],
                    "DEPTH-OF-FIELD SCALE": [136, 137],
                    "RELEASE/FOCUS PRIORITY": [137, 138],
                    "AF RANGE LIMITER": [137, 138],
                    "TOUCH SCREEN MODE": [138, 140]
                }
            },
            "SHOOTING SETTING (Still Photography)": {
                "page_range": [140, 149],
                "subsections": {
                    "SPORTS FINDER MODE": [140, 141],
                    "PRE-SHOT ES": [141, 142],
                    "SELF-TIMER": [141, 142],
                    "SAVE SELF-TIMER SETTING": [142, 143],
                    "SELF-TIMER LAMP": [142, 143],
                    "INTERVAL TIMER SHOOTING": [143, 144],
                    "INTERVAL TIMER SHOOTING EXPOSURE SMOOTHING": [144, 145],
                    "AE BKT SETTING": [144, 145],
                    "FILM SIMULATION BKT": [145, 146],
                    "FOCUS BKT SETTING": [145, 146],
                    "MULTIPLE EXPOSURE CTRL": [145, 146],
                    "PHOTOMETRY": [145, 146],
                    "SHUTTER TYPE": [146, 147],
                    "FLICKER REDUCTION": [147, 148],
                    "IS MODE": [147, 148],
                    "ISO": [148, 149],
                    "WIRELESS COMMUNICATION": [148, 149]
                }
            },
            "FLASH SETTING (Still Photography)": {
                "page_range": [149, 152],
                "subsections": {
                    "FLASH FUNCTION SETTING": [149, 150],
                    "RED EYE REMOVAL": [149, 150],
                    "TTL-LOCK MODE": [150, 151],
                    "LED LIGHT SETTING": [150, 151],
                    "COMMANDER SETTING": [151, 152],
                    "CH SETTING": [151, 152]
                }
            },
            "MOVIE SETTING (Still Photography)": {
                "page_range": [152, 155],
                "subsections": {
                    "MOVIE MODE": [152, 153],
                    "FILE FORMAT": [152, 153],
                    "FULL HD HIGH SPEED REC": [152, 153],
                    "IS MODE": [152, 153],
                    "AUDIO SETTING": [153, 154],
                    "MIC/REMOTE RELEASE": [154, 155]
                }
            },
            "MOVIE SETTING (Movie Recording)": {
                "page_range": [155, 164],
                "subsections": {
                    "MOVIE MODE": [155, 156],
                    "FILE FORMAT": [156, 157],
                    "FULL HD HIGH SPEED REC": [157, 158],
                    "FIX MOVIE CROP MAGNIFICATION": [158, 159],
                    "F-Log RECORDING": [158, 159],
                    "4K MOVIE OUTPUT": [159, 160],
                    "FULL HD MOVIE OUTPUT": [159, 160],
                    "HDMI OUTPUT INFO DISPLAY": [160, 161],
                    "4K HDMI STANDBY QUALITY": [160, 161],
                    "HDMI REC CONTROL": [160, 161],
                    "PHOTOMETRY": [160, 162],
                    "IS MODE": [161, 162],
                    "ISO": [161, 162],
                    "ZEBRA SETTING": [162, 163],
                    "ZEBRA LEVEL": [162, 163],
                    "MOVIE OPTIMIZED CONTROL": [162, 163],
                    "TALLY LIGHT": [163, 164],
                    "WIRELESS COMMUNICATION": [163, 164]
                }
            },
            "IMAGE QUALITY SETTING (Movie Recording)": {
                "page_range": [164, 168],
                "subsections": {
                    "FILM SIMULATION": [164, 165],
                    "MONOCHROMATIC COLOR": [164, 165],
                    "WHITE BALANCE": [164, 165],
                    "DYNAMIC RANGE": [165, 166],
                    "TONE CURVE": [165, 166],
                    "COLOR": [165, 166],
                    "SHARPNESS": [166, 167],
                    "HIGH ISO NR": [166, 167],
                    "INTERFRAME NR": [166, 167],
                    "PERIPHERAL LIGHT CORRECTION": [167, 168],
                    "MOUNT ADAPTER SETTING": [167, 168]
                }
            },
            "AF/MF SETTING (Movie Recording)": {
                "page_range": [168, 175],
                "subsections": {
                    "FOCUS AREA": [168, 169],
                    "FOCUS MODE": [168, 169],
                    "AF MODE": [168, 169],
                    "AF-C CUSTOM SETTING": [169, 170],
                    "AF ILLUMINATOR": [169, 170],
                    "FACE/EYE DETECTION SETTING": [170, 171],
                    "MF ASSIST": [170, 171],
                    "FOCUS CHECK": [171, 172],
                    "INSTANT AF SETTING": [171, 172],
                    "DEPTH-OF-FIELD SCALE": [171, 172],
                    "AF RANGE LIMITER": [171, 172],
                    "TOUCH SCREEN MODE": [172, 174],
                    "FOCUS CHECK LOCK": [174, 175]
                }
            },
            "AUDIO SETTING (Movie Recording)": {
                "page_range": [175, 178],
                "subsections": {
                    "INTERNAL MIC LEVEL ADJUSTMENT": [175, 176],
                    "EXTERNAL MIC LEVEL ADJUSTMENT": [175, 176],
                    "MIC JACK SETTING": [176, 177],
                    "MIC LEVEL LIMITER": [176, 177],
                    "WIND FILTER": [176, 177],
                    "LOW CUT FILTER": [176, 177],
                    "HEADPHONES VOLUME": [177, 178],
                    "MIC/REMOTE RELEASE": [177, 178]
                }
            },
            "TIME CODE SETTING (Movie Recording)": {
                "page_range": [178, 181],
                "subsections": {
                    "TIME CODE DISPLAY": [178, 179],
                    "START TIME SETTING": [178, 179],
                    "COUNT UP SETTING": [178, 179],
                    "DROP FRAME": [179, 181],
                    "HDMI TIME CODE OUTPUT": [179, 181]
                }
            },                        
        }
    },
    "Playback and the Playback Menu": {
        "page_range": [
            181,
            207
        ],
        "sections": {
            "The Playback Display": {
                "page_range": [182, 185],
                "subsections": {
                    "The DISP/BACK Button": [183, 185]
                }
            },
            "Viewing Pictures": {
                "page_range": [185, 187],
                "subsections": {
                    "Playback Zoom": [186, 187],
                    "Multi-Frame Playback": [186, 187],
                    "Viewing Other Pictures": [186, 187]
                }
            },
            "The Playback Menu": {
                "page_range": [187, 207],
                "subsections": {
                    "RAW CONVERSION": [187, 190],
                    "ERASE": [190, 192],
                    "CROP": [192, 193],
                    "RESIZE": [193, 194],
                    "PROTECT": [194, 195],
                    "IMAGE ROTATE": [195, 196],
                    "RED EYE REMOVAL": [196, 197],
                    "VOICE MEMO SETTING": [197, 198],
                    "RATING": [198, 199],
                    "IMAGE TRANSFER ORDER": [199, 200],
                    "WIRELESS COMMUNICATION": [200, 201],
                    "SLIDE SHOW": [200, 201],
                    "PHOTOBOOK ASSIST": [201, 202],
                    "PC AUTO SAVE": [202, 203],
                    "PRINT ORDER (DPOF)": [203, 204],
                    "instax PRINTER PRINT": [204, 205],
                    "DISP ASPECT": [205, 207]
                }
            }
        }
    },
    "The Setup Menus": {
        "page_range": [
            207,
            243
        ],
        "sections": {
            "USER SETTING": {
                "page_range": [208, 213],
                "subsections": {
                    "FORMAT": [208, 209],
                    "DATE/TIME": [209, 210],
                    "TIME DIFFERENCE": [209, 210],
                    "LANG.": [210, 211],
                    "MY MENU SETTING": [210, 211],
                    "SENSOR CLEANING": [211, 212],
                    "SOUND & FLASH": [211, 212],
                    "RESET": [212, 213],
                    "REGULATORY": [212, 213]
                }
            },
            "SOUND SETTING": {
                "page_range": [213, 215],
                "subsections": {
                    "AF BEEP VOL.": [213, 214],
                    "SELF-TIMER BEEP VOL.": [213, 214],
                    "OPERATION VOL.": [214, 215],
                    "SHUTTER VOLUME": [214, 215],
                    "SHUTTER SOUND": [214, 215],
                    "PLAYBACK VOLUME": [214, 215]
                }
            },
            "SCREEN SETTING": {
                "page_range": [215, 224],
                "subsections": {
                    "VIEW MODE SETTING": [215, 216],
                    "EVF BRIGHTNESS": [215, 216],
                    "EVF COLOR": [215, 216],
                    "EVF COLOR ADJUSTMENT": [216, 217],
                    "LCD BRIGHTNESS": [216, 217],
                    "LCD COLOR": [216, 217],
                    "LCD COLOR ADJUSTMENT": [216, 217],
                    "IMAGE DISP.": [217, 218],
                    "AUTOROTATE DISPLAYS": [217, 218],
                    "PREVIEW EXP./WB IN MANUAL MODE": [218, 219],
                    "NATURAL LIVE VIEW": [218, 219],
                    "F-Log VIEW ASSIST": [219, 220],
                    "FRAMING GUIDELINE": [219, 220],
                    "AUTOROTATE PB": [220, 221],
                    "FOCUS SCALE UNITS": [220, 221],
                    "APERTURE UNIT FOR CINEMA LENS": [220, 221],
                    "DISP. CUSTOM SETTING": [220, 221],
                    "LARGE INDICATORS MODE(EVF)": [221, 222],
                    "LARGE INDICATORS MODE(LCD)": [221, 222],
                    "LARGE INDICATORS DISP. SETTING": [222, 223],
                    "INFORMATION CONTRAST ADJ.": [222, 223],
                    "Q MENU BACKGROUND": [223, 224],
                }
            },
            "BUTTON/DIAL SETTING": {
                "page_range": [224, 232],
                "subsections": {
                    "FOCUS LEVER SETTING": [224, 225],
                    "EDIT/SAVE QUICK MENU": [225, 226],
                    "FUNCTION (Fn) SETTING": [225, 226],
                    "COMMAND DIAL SETTING": [226, 227],
                    "SHUTTER AF": [227, 228],
                    "SHUTTER AE": [227, 228],
                    "SHOOT WITHOUT LENS": [227, 228],
                    "SHOOT WITHOUT CARD": [228, 229],
                    "FOCUS RING": [228, 229],
                    "FOCUS RING OPERATION": [228, 229],
                    "AE/AF-LOCK MODE": [229, 230],
                    "AWB-LOCK MODE": [229, 230],
                    "APERTURE RING SETTING (A)": [229, 230],
                    "APERTURE SETTING": [230, 231],
                    "TOUCH SCREEN SETTING": [230, 231]
                }
            },
            "POWER MANAGEMENT": {
                "page_range": [232, 234],
                "subsections": {
                    "AUTO POWER OFF": [232, 233],
                    "PERFORMANCE": [233, 234],
                    "BOOST SETTING": [233, 234]
                }
            },
            "SAVE DATA SETTING": {
                "page_range": [234, 237],
                "subsections": {
                    "FRAME NO.": [234, 235],
                    "SAVE ORG IMAGE": [235, 236],
                    "EDIT FILE NAME": [235, 236],
                    "SELECT FOLDER": [236, 237],
                    "COPYRIGHT INFO": [236, 237]
                }
            },
            "CONNECTION SETTING": {
                "page_range": [237, 243],
                "subsections": {
                    "Bluetooth SETTINGS": [237, 238],
                    "PC AUTO SAVE": [238, 239],
                    "instax PRINTER CONNECTION SETTING": [239, 240],
                    "CONNECTION MODE": [240, 241],
                    "USB POWER SUPPLY SETTING": [241, 242],
                    "GENERAL SETTINGS": [242, 243],
                    "INFORMATION": [242, 243],
                    "RESET WIRELESS SETTING": [242, 243]
                }
            }                       
        }
    },
    "Shortcuts": {
        "page_range": [
            243,
            259
        ],
        "sections": {
            "Shortcut Options": {
                "page_range": [244, 245],
                "subsections": {}
            },
            "MY MENU": {
                "page_range": [245, 247],
                "subsections": {
                    "MY MENU SETTING": [245, 247]
                }
            },
            "The Quick Menu": {
                "page_range": [247, 253],
                "subsections": {
                    "The Quick Menu Display": [247, 249],
                    "Viewing and Changing Settings": [249, 250],
                    "Editing the Quick Menu": [250, 253]
                }
            },
            "Function Controls": {
                "page_range": [253, 259],
                "subsections": {
                    "The Function Buttons": [253, 256],
                    "Touch-Function Gestures": [256, 259]
                }
            }
        }
    },
    "Peripherals and Optional Accessories": {
        "page_range": [
            259,
            281
        ],
        "sections": {
            "Lenses": {
                "page_range": [260, 266],
                "subsections": {
                    "Lens Parts": [260, 261],
                    "Removing Lens Caps": [261, 262],
                    "Attaching Lens Hoods": [261, 262],
                    "Lenses with Aperture Rings": [262, 263],
                    "Lenses with No Aperture Rings": [263, 264],
                    "Lenses with O.I.S. Switches": [263, 264],
                    "Manual Focus Lenses": [264, 265],
                    "Lens Care": [265, 266]
                }
            },
            "External Flash Units": {
                "page_range": [266, 278],
                "subsections": {
                    "Using an External Flash": [267, 268],
                    "EF-X8": [268, 270],
                    "SYNC TERMINAL": [270, 271],
                    "SHOE MOUNT FLASH": [271, 274],
                    "COMMANDER(OPTICAL)": [274, 278]
                }
            },
            "Handgrips": {
                "page_range": [278, 279],
                "subsections": {}
            },
            "Thumb Rests": {
                "page_range": [279, 281],
                "subsections": {}
            }
        }
    },
    "Connections": {
        "page_range": [
            281,
            297
        ],
        "sections": {
            "HDMI Output": {
                "page_range": [282, 284],
                "subsections": {
                    "Connecting to HDMI Devices": [282, 283],
                    "Shooting": [283, 284],
                    "Playback": [283, 284]
                }
            },
            "Wireless Connections (Bluetooth®, Wireless LAN/Wi-Fi)": {
                "page_range": [284, 287],
                "subsections": {
                    "Smartphones and Tablets: FUJIFILM Camera Remote": [284, 286],
                    "Copying Pictures to a Computer: PC AutoSave": [286, 287]
                }
            },
            "Connecting via USB": {
                "page_range": [287, 295],
                "subsections": {
                    "Connecting to Computers": [287, 290],
                    "Copying Pictures to a Computer": [290, 291],
                    "Using Your Camera as a Webcam (FUJIFILM X Webcam)": [290, 291],
                    "Converting RAW Images: FUJIFILM X RAW STUDIO": [291, 292],
                    "Backing Up and Restoring Camera Settings (FUJIFILM X Acquire)": [291, 292],
                    "Connecting to Smartphones": [292, 295]
                }
            },
            "instax SHARE Printers": {
                "page_range": [295, 297],
                "subsections": {
                    "Establishing a Connection": [295, 296],
                    "Printing Pictures": [296, 297]
                }
            }
        }
    },
    "Technical Notes": {
        "page_range": [
            297,
            335
        ],
        "sections": {
            "Accessories from Fujifilm": {
                "page_range": [298, 301],
                "subsections": {}
            },
            "Software for Use with Your Camera": {
                "page_range": [301, 303],
                "subsections": {
                    "FUJIFILM Camera Remote": [301, 302],
                    "FUJIFILM PC AutoSave": [301, 302],
                    "RAW FILE CONVERTER EX powered by SILKYPIX": [301, 302],
                    "Capture One Express Fujifilm": [301, 302],
                    "Capture One Pro Fujifilm": [302, 303],
                    "FUJIFILM X Acquire": [302, 303],
                    "FUJIFILM X RAW STUDIO": [302, 303],
                    "FUJIFILM X Webcam": [302, 303]
                }
            },
            "For Your Safety": {
                "page_range": [303, 312],
                "subsections": {}
            },
            "Product Care": {
                "page_range": [312, 313],
                "subsections": {}
            },
            "Cleaning the Image Sensor": {
                "page_range": [313, 314],
                "subsections": {}
            },
            "Firmware Updates": {
                "page_range": [314, 315],
                "subsections": {
                    "Checking the Firmware Version": [314, 315]
                }
            },
            "Troubleshooting": {
                "page_range": [315, 324],
                "subsections": {}
            },
            "Warning Messages and Displays": {
                "page_range": [324, 328],
                "subsections": {}
            },
            "Memory Card Capacity": {
                "page_range": [328, 329],
                "subsections": {}
            },
            "Specifications": {
                "page_range": [329, 335],
                "subsections": {}
            }
        }
    }
}

# %%
chapter_dict = {"chapter":{}}
for chapter in x_e4_contents.keys():
    chapter_dict["chapter"][chapter] = x_e4_contents[chapter]["page_range"]

# %%
cover_page_list = []
for chapter in chapter_dict["chapter"]:
    cover_page_list.append(chapter_dict["chapter"][chapter][0])

cover_erase_documents = []
for document in documents:
    if document.metadata['page'] not in cover_page_list:
        cover_erase_documents.append(document)

# %%
print(cover_page_list)
# Out:
# [1, 27, 41, 47, 55, 103, 181, 207, 243, 259, 281, 297]

# %%
for doc in cover_erase_documents:
    if "MEMO" in doc.parsing_result:
        print(doc.metadata['page'])
# Out:
# 19
# 26
# 40
# 54
# 102
# 180
# 197
# 206
# 258
# 280
# 324
# 325
# 335

# %%
memo_page_list = [26, 40, 54, 102, 180, 206, 258, 280, 335, 336]

memo_erase_documents = []
for document in cover_erase_documents:
    if document.metadata['page'] not in memo_page_list:
        memo_erase_documents.append(document)

# %% [markdown]
# # add metadata
# - metadata: {
#     "chapter":,
#     "section":,
#     "subsection":
# }

# %%
memo_erase_documents
# Out:
# [CameraDocument(metadata={'page': 2, 'model': 'x-e4'}, parsing_result='\n# Parts of the Camera\n\nThe parts of the camera are listed below.\n\n!Camera Diagram\n\n1. **Shutter button** .................................................. 44\n2. **Exposure compensation dial** .................. 4, 80\n3. **Q (quick menu) button** ............................. 247\n4. **Shutter speed dial** .................................... 4, 56, 59, 63, 65\n5. **Hot shoe** ..................................................... 267\n6. **Microphone** ............................................... 50, 175\n7. **Strap eyelet** ................................................. 28\n8. **Connector cover**\n9. **Lens signal contacts**\n10. **Lens release button** .................................. 29\n11. **AF-assist illuminator** ................................. 131\n    - Self-timer lamp ........................................... 141\n    - Tally light .................................................... 163\n12. **Front command dial** ................................ 6\n13. **ON/OFF switch** ......................................... 35\n14. **Fn button** .................................................. 253\n15. **Body cap** .................................................. 29\n16. **Microphone/remote release connector** (ø3.5 mm) ................. 3, 50, 154\n17. **USB connector (Type-C)** ....................... 33, 50, 287\n18. **HDMI Micro connector (Type D)** .......... 282\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'x-e4'}, parsing_result='\n# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n19. **Diopter adjustment control**  \n   - Page: 9\n\n20. **Electronic viewfinder (EVF)**  \n   - Pages: 10, 14, 16, 21\n\n21. **Eye sensor**  \n   - Page: 15\n\n22. **DRIVE/DELETE button**  \n   - Pages: 5, 46, 87\n\n23. **PLAY (playback) button**  \n   - Page: 45\n\n24. **AEL (exposure lock)/AFL (focus lock) button**  \n   - Pages: 86, 253\n\n25. **Indicator lamp**  \n   - Pages: 7, 163  \n   - **Tally light**  \n     - Page: 163\n\n26. **Focus stick (focus lever)**  \n   - Pages: 5, 74, 224\n\n27. **MENU/OK button**  \n   - Page: 19\n\n28. **DISP (display)/BACK button**  \n   - Pages: 16, 183\n\n29. **Cable channel cover for DC coupler**  \n   - Page: 298\n\n30. **Battery-chamber cover latch**  \n   - Page: 30\n\n31. **Battery-chamber cover**  \n   - Page: 30\n\n32. **Tripod mount**\n\n33. **Speaker**  \n   - Pages: 52, 214\n\n34. **LCD monitor**  \n   - Pages: 8, 12, 14  \n   - **Touch screen**  \n     - Pages: 21, 138, 230\n\n35. **Battery chamber**  \n   - Page: 30\n\n36. **Memory card slot**  \n   - Page: 30\n\n37. **Battery latch**  \n   - Page: 31\n\n38. **Serial number plate**  \n   - See below\n\n> 💡 **Note:**\n> - **16:** Use of an optional RR-100 remote release requires a third-party adapter to convert the female three-pin, ø2.5 mm connector to a male three-pin, ø3.5 mm connector.\n> - **38:** Do not remove the serial number plate, which provides the CMIT ID, serial number, and other important information.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'x-e4'}, parsing_result='\n# Before You Begin\n\n## The Shutter Speed Dial\nRotate the shutter speed dial to choose the shutter speed (📖 56).\n\n!Shutter Speed Dial\n\n## The Exposure Compensation Dial\nRotate the dial to choose an exposure compensation amount (📖 80).\n\n!Exposure Compensation Dial\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'x-e4'}, parsing_result='# Parts of the Camera\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus Stick\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING** (page 224).\n\n## The DRIVE/DELETE Button\n\nPressing the **DRIVE/DELETE** button displays the drive-mode menu, where you can choose from the following drive modes.\n\n!Drive/Delete Button\n\n| Mode                | Page |\n|---------------------|------|\n| Single frame        | 42   |\n| High-speed burst    | 92   |\n| Low-speed burst     | 92   |\n| ISO BKT             | 88   |\n| WHITE BALANCE BKT   | 88   |\n| Bracketing          | 89   |\n| HDR                 | 93   |\n| Adv. MODE           |      |\n| • Panorama          | 95   |\n| • Multiple Exposure | 98   |\n| Filter              | 100  |\n| Movie               | 48   |', embedding_result=[]),
#  CameraDocument(metadata={'page': 6, 'model': 'x-e4'}, parsing_result='# The Command Dial\n\nThe front command dial is used for the operations below.\n\n!Command Dial\n\n## Shooting\n\n- Choose the desired combination of shutter speed and aperture (program shift).\n- Choose a shutter speed.\n- Adjust aperture.\n- Adjust exposure compensation.\n- Adjust sensitivity.\n\n> 💡 **Note:**\n> - During shooting, the role of the front command dial changes each time the center of the dial is pressed.\n> - For information on the roles performed by the dials during shooting, see “Front Command Dial Roles by Mode” (page 67).\n\n## Menus\n\nRotate the dial to select menu tabs or page through menus.\n\n## Q Menu\n\nRotate the dial to change settings in the quick menu and press the center of the dial to select.\n\n## Playback\n\n- View other pictures.\n- Zoom in or out during full- or multi-frame playback.\n\n> 💡 **Note:**\n> - Press the center of the front command dial to switch between the two roles.', embedding_result=[]),
#  CameraDocument(metadata={'page': 7, 'model': 'x-e4'}, parsing_result='# The Indicator Lamp\n\nCamera status is shown by the indicator lamp.\n\n!Indicator Lamp\n\n| Indicator Lamp          | Camera Status                                                                                   |\n|-------------------------|-------------------------------------------------------------------------------------------------|\n| Glows green             | Focus locked.                                                                                   |\n| Blinks green            | Focus or slow shutter speed warning. Pictures can be taken.                                     |\n| Blinks green and orange | - **Camera on:** Recording pictures. Additional pictures can be taken.                          |\n|                         | - **Camera off:** Uploading pictures to a smartphone or tablet.*                                |\n| Glows orange            | Recording pictures. No additional pictures can be taken at this time.                           |\n| Blinks orange           | Flash charging; flash will not fire when picture is taken.                                      |\n| Blinks red              | Lens or memory error.                                                                           |\n\n*Displayed only if pictures are selected for upload.\n\n> - Warnings may also appear in the display.\n> - The indicator lamp remains off while your eye is to the viewfinder.\n> - The **MOVIE SETTING > TALLY LIGHT** option can be used to choose the lamp (indicator or AF-assist) that lights during movie recording and whether the lamp blinks or remains steady.', embedding_result=[]),
#  CameraDocument(metadata={'page': 8, 'model': 'x-e4'}, parsing_result='# The LCD Monitor\n\nYou can adjust the angle of the LCD monitor when framing shots, but be careful not to trap your fingers or other objects.\n\n!LCD Monitor Adjustment\n\n- Do not apply excessive force to the hinge when rotating the LCD monitor, as this could damage the hinge.\n- Be careful that the corners of the monitor do not contact the camera body, as this could leave marks.\n\nThe LCD monitor also functions as a touch screen that can be used for:\n\n- Touch photography (page 22)\n- Focus area selection (page 21)\n- Function selection (page 24)\n- Movie optimized control (page 23)\n- Playback (page 25)\n\n## Tilting the LCD Monitor\n\nBe sure the LCD monitor doesn’t block the eye sensor during shooting, as this will cause the display to flip.\n\n!Tilting the LCD Monitor\n\n- **Normal display**\n- **Display flipped**', embedding_result=[]),
#  CameraDocument(metadata={'page': 9, 'model': 'x-e4'}, parsing_result='# Focusing the Viewfinder\n\nIf the indicators displayed in the viewfinder are blurred, put your eye to the viewfinder and rotate the diopter adjustment control until the display is in sharp focus.\n\n!Diopter Adjustment Control', embedding_result=[]),
#  CameraDocument(metadata={'page': 10, 'model': 'x-e4'}, parsing_result='# Camera Displays\n\nThis section lists the indicators that may be displayed during shooting.\n\n> For illustrative purposes, displays are shown with all indicators lit.\n\n## The Electronic Viewfinder\n\n!The Electronic Viewfinder', embedding_result=[]),
#  CameraDocument(metadata={'page': 11, 'model': 'x-e4'}, parsing_result='\n# Camera Displays\n\n1. **Crop factor** .................................................. 140\n2. **Focus check** .............................................. 78, 135\n3. **Depth-of-field preview** ......................... 64, 78\n4. **Location data download status** ...... 242, 284\n5. **Bluetooth ON/OFF** ................................ 237\n6. **Image transfer status** ....................... 237, 284\n7. **Movie mode** ........................................... 48, 155\n8. **Full HD high-speed recording** .......... 157\n9. **Recording time available/elapsed recording time** .......... 48\n10. **Date and time** .................................. 37, 39, 209\n11. **Number of available frames** ¹ .......... 328\n12. **Image size** .................................................. 104\n13. **File format** .................................................. 156\n14. **Image quality** ........................................... 105\n15. **Temperature warning** .......................... 327\n16. **Touch screen mode** .......................... 21, 138\n17. **White balance** .......................................... 109\n18. **AWB lock** .................................................... 229\n19. **Film simulation** ........................................ 106\n20. **F-Log recording** ...................................... 158\n21. **Dynamic range** ........................................ 113\n22. **D-range priority** ...................................... 114\n23. **Movie optimized control** ...................... 23\n24. **Sound and flash indicator** .................. 211\n25. **Virtual horizon** ........................................... 18\n26. **Boost mode** .............................................. 233\n27. **Histogram** ................................................... 18\n28. **Distance indicator** ² ................................. 78\n29. **Power supply** ............................................. 34\n30. **Battery level** ............................................... 36\n31. **Sensitivity** .................................................... 82\n32. **Exposure compensation** ....................... 80\n33. **Focus frame** ......................................... 73, 85\n34. **Aperture** ........................................... 58, 63, 65\n35. **Time code** .................................................. 178\n36. **Shutter speed** .................................. 58, 59, 65\n37. **TTL lock** ............................................. 150, 255\n38. **AE lock** .................................................. 86, 229\n39. **Metering** ....................................................... 84\n40. **Shooting mode** ......................................... 56\n41. **Focus mode** ² ............................................. 69\n42. **Focus indicator** ² ........................................ 70\n43. **Manual focus indicator** .................. 69, 77\n44. **AF lock** .................................................. 86, 229\n45. **Mic jack setting** ...................................... 176\n46. **Recording level** ² ..................................... 175\n47. **AF+MF indicator** ² .................................. 134\n48. **Shutter type** .............................................. 146\n49. **Continuous mode** ..................................... 92\n50. **Exposure indicator** .................................. 65\n51. **Self-timer indicator** ................................ 141\n52. **Microphone** .................................................. 50\n53. **Remote release** .......................................... 62\n54. **Flash (TTL) mode** .................................... 271\n55. **IS mode** ² .................................................... 147\n56. **Flash compensation** .............................. 271\n\n¹ Shows “9999” if there is space for over 9999 frames.  \n² Not dis ...
#  CameraDocument(metadata={'page': 12, 'model': 'x-e4'}, parsing_result="!The LCD Monitor\n\n# The LCD Monitor\n\nThis image provides a detailed view of the camera's LCD monitor interface, highlighting various icons and indicators used for camera settings and status information.", embedding_result=[]),
#  CameraDocument(metadata={'page': 13, 'model': 'x-e4'}, parsing_result='\n# Camera Displays\n\n1. **Crop factor** .................................................. 140\n2. **Flash compensation** .................................. 271\n3. **Focus check** ........................................... 78, 135\n4. **Depth-of-field preview** ......................... 64, 78\n5. **Location data download status** .......... 242, 284\n6. **Bluetooth ON/OFF** .................................. 237\n7. **Image transfer status** ............................ 237, 284\n8. **Movie mode** ........................................... 48, 155\n9. **Full HD high-speed recording** ............. 157\n10. **Focus frame** ........................................... 73, 85\n11. **Recording time available/elapsed recording time** .......... 48\n12. **Number of available frames¹** .............. 328\n13. **Image size** .............................................. 104\n14. **File format** ............................................. 156\n15. **Image quality** ......................................... 105\n16. **Date and time** ....................................... 37, 39, 209\n17. **Touch screen mode** ............................. 21, 138\n18. **AWB lock** ............................................... 229\n19. **White balance** ....................................... 109\n20. **Film simulation** ..................................... 106\n21. **F-Log recording** ................................... 158\n22. **Dynamic range** ..................................... 113\n23. **D-range priority** ................................... 114\n24. **Movie optimized control** .................... 23\n25. **Boost mode** .......................................... 233\n26. **Temperature warning** ......................... 327\n27. **Sound and flash indicator** .................. 211\n28. **Power supply** ........................................ 34\n29. **Battery level** .......................................... 36\n30. **Distance indicator²** .............................. 78\n31. **Sensitivity** .............................................. 82\n32. **Histogram** ............................................. 18\n33. **Exposure compensation** ..................... 80\n34. **Aperture** ................................................. 58, 63, 65\n35. **Time code** ............................................. 178\n36. **Shutter speed** ....................................... 58, 59, 65\n37. **TTL lock** ................................................. 150, 255\n38. **AE lock** .................................................. 86, 229\n39. **Metering** ................................................ 84\n40. **Shooting mode** .................................... 56\n41. **Focus mode²** ......................................... 69\n42. **Focus indicator²** ................................... 70\n43. **Manual focus indicator²** .................... 69, 77\n44. **AF lock** .................................................. 86, 229\n45. **Mic jack setting** ................................... 176\n46. **AF+MF indicator²** ............................... 134\n47. **Shutter type** ......................................... 146\n48. **Recording level** ................................... 175\n49. **Continuous mode** ............................... 92\n50. **Exposure indicator** ............................. 65\n51. **Self-timer indicator** ............................ 141\n52. **Microphone** .......................................... 50\n53. **Remote release** ................................... 62\n54. **Flash (TTL) mode** ............................... 271\n55. **IS mode²** ............................................... 147\n\n> ¹ Shows "9999" if there is space for over 9999 frames.\n> \n> ² Not displayed when ON is selected for **SCREEN SET-UP > LARGE INDICATORS MODE(LCD)**.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 14, 'model': 'x-e4'}, parsing_result='\n## Adjusting Display Brightness\n\nThe brightness and hue of the viewfinder and LCD monitor can be adjusted using the items in the !SCREEN SET-UP menu. Choose **EVF BRIGHTNESS** or **EVF COLOR** to adjust viewfinder brightness or hue, **LCD BRIGHTNESS** or **LCD COLOR** to do the same for the LCD monitor.\n\n## Display Rotation\n\nWhen **ON** is selected for !SCREEN SET-UP > **AUTOROTATE DISPLAYS**, the indicators in the viewfinder and LCD monitor automatically rotate to match camera orientation.\n\n## Choosing a Display Mode\n\nUse !SCREEN SET-UP > **VIEW MODE SETTING** to choose from the following display modes. You can choose separate display modes for shooting and playback.\n\n### SHOOTING\n\n| Option                  | Description                                                                                                                                   |\n|-------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------|\n| !EYE SENSOR | Putting your eye to the viewfinder turns the viewfinder on and the LCD monitor off; taking your eye away turns the viewfinder off and LCD monitor on. |\n| !EVF ONLY   | Viewfinder on, LCD monitor off.                                                                                                        |\n| !LCD ONLY   | LCD monitor on, viewfinder off.                                                                                                        |\n| !EVF ONLY + SENSOR | Putting your eye to the viewfinder turns the viewfinder on; taking it away turns the viewfinder off. The LCD monitor remains off.                      |\n| !EYE SENSOR + LCD IMAGE DISP. | Putting your eye to the viewfinder during shooting turns the viewfinder on, but the LCD monitor is used for the display of images once you remove your eye from the viewfinder after shooting. The options selected for !SCREEN SET-UP > **IMAGE DISP.** apply to display in the LCD monitor. |\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 15, 'model': 'x-e4'}, parsing_result='# PLAYBACK\n\n| Option      | Description                                                                                                                                  |\n|-------------|----------------------------------------------------------------------------------------------------------------------------------------------|\n| !Eye Sensor Icon EYE SENSOR | Putting your eye to the viewfinder turns the viewfinder on and the LCD monitor off; taking your eye away turns the viewfinder off and LCD monitor on. |\n| !EVF Icon EVF ONLY     | Viewfinder on, LCD monitor off.                                                                                                                        |\n| !LCD Icon LCD ONLY     | LCD monitor on, viewfinder off.                                                                                                                        |\n\n## The Eye Sensor\n\nThe eye sensor may respond to objects other than your eye or to light shining directly on the sensor.\n\n!Eye Sensor', embedding_result=[]),
#  CameraDocument(metadata={'page': 16, 'model': 'x-e4'}, parsing_result='# The DISP/BACK Button\n\nThe **DISP/BACK** button controls the display of indicators in the viewfinder and LCD monitor.\n\n!DISP/BACK Button\n\n> 💡 **Note:**  \n> Indicators for the EVF and LCD must be selected separately. To choose the EVF display, place your eye to the viewfinder while using the **DISP/BACK** button.\n\n## Viewfinder (EVF)\n\n- **Standard indicators**  \n  !Standard Indicators EVF\n\n- **Full screen (no indicators)**  \n  !Full Screen EVF\n\n## LCD Monitor\n\n- **Standard indicators**  \n  !Standard Indicators LCD\n\n- **No indicators**  \n  !No Indicators LCD\n\n- **Info display (still photography only)**  \n  !Info Display', embedding_result=[]),
#  CameraDocument(metadata={'page': 17, 'model': 'x-e4'}, parsing_result='# Customizing the Standard Display\n\nTo choose the items shown in the standard indicator display:\n\n1. **Display standard indicators.**  \n   Use the **DISP/BACK** button to display standard indicators.\n\n2. **Select DISP. CUSTOM SETTING.**  \n   Select **SCREEN SET-UP > DISP. CUSTOM SETTING** in the setup menu.\n\n3. **Choose items.**  \n   Highlight items and press **MENU/OK** to select or deselect.\n\n   | Item                     | Default | Item                     | Default |\n   |--------------------------|---------|--------------------------|---------|\n   | FRAMING GUIDELINE        |         | CONTINUOUS MODE          | ✔       |\n   | ELECTRONIC LEVEL         |         | DUAL IS MODE             | ✔       |\n   | FOCUS FRAME              | ✔       | TOUCH SCREEN MODE        | ✔       |\n   | AF DISTANCE INDICATOR    |         | WHITE BALANCE            | ✔       |\n   | MF DISTANCE INDICATOR    | ✔       | FILM SIMULATION          | ✔       |\n   | HISTOGRAM                |         | DYNAMIC RANGE            | ✔       |\n   | LIVE VIEW HIGHLIGHT ALERT|         | BOOST MODE               | ✔       |\n   | SHOOTING MODE            | ✔       | FRAMES REMAINING         | ✔       |\n   | APERTURE/S-SPEED/ISO     | ✔       | IMAGE SIZE/QUALITY       | ✔       |\n   | INFORMATION BACKGROUND   | ✔       | MOVIE MODE & REC. TIME   | ✔       |\n   | Expo. Comp. (Digit)      |         | IMAGE TRANSFER ORDER     | ✔       |\n   | Expo. Comp. (Scale)      | ✔       | MIC LEVEL                | ✔       |\n   | FOCUS MODE               | ✔       | GUIDANCE MESSAGE         | ✔       |\n   | PHOTOMETRY               | ✔       | BATTERY LEVEL            | ✔       |\n   | SHUTTER TYPE             | ✔       | FRAMING OUTLINE          |         |\n   | FLASH                    | ✔       |                          |         |\n\n4. **Press DISP/BACK to save changes.**\n\n5. **Press DISP/BACK as needed to exit the menus and return to the shooting display.**', embedding_result=[]),
#  CameraDocument(metadata={'page': 18, 'model': 'x-e4'}, parsing_result='# Camera Displays\n\n## Virtual Horizon\n\nSelecting **ELECTRONIC LEVEL** displays a virtual horizon. The camera is level when the two lines overlap. Note that the virtual horizon may not be displayed if the camera lens is pointed up or down. For a 3D display (shown), press the function button to which **ELECTRONIC LEVEL** is assigned.\n\n!Virtual Horizon Display\n\n## Framing Outline\n\nEnable **FRAMING OUTLINE** to make the borders of the frame easier to see against dark backgrounds.\n\n## Histograms\n\nHistograms show the distribution of tones in the image. Brightness is shown by the horizontal axis, the number of pixels by the vertical axis.\n\n!Histogram Display\n\n- **Optimal exposure:** Pixels are distributed in an even curve throughout the tone range.\n- **Overexposed:** Pixels are clustered on the right side of the graph.\n- **Underexposed:** Pixels are clustered on the left side of the graph.\n\nTo view separate RGB histograms and a display showing areas of the frame that will be overexposed at current settings superimposed on the view through the lens, press the function button to which **HISTOGRAM** is assigned.\n\n1. Overexposed areas blink\n2. RGB histograms\n\n!RGB Histogram Display', embedding_result=[]),
#  CameraDocument(metadata={'page': 19, 'model': 'x-e4'}, parsing_result='# Using the Menus\n\nTo display the menus, press **MENU/OK**.\n\n!Menu Button\n\n## The Menus\n\nDifferent menus are displayed during still photography, movie recording, and playback.\n\n### Still Photography\n\n!Still Photography Menu\n\n- **IMAGE QUALITY SETTING**\n  - IMAGE SIZE\n  - IMAGE QUALITY\n  - RAW RECORDING\n  - FILM SIMULATION\n  - MONOCHROMATIC COLOR\n  - GRAIN EFFECT\n  - COLOR CHROME EFFECT\n  - COLOR CHROME FX BLUE\n\n### Movie Recording\n\n!Movie Recording Menu\n\n- **MOVIE SETTING**\n  - MOVIE MODE\n  - FILE FORMAT\n  - FULL HD HIGH SPEED REC\n  - FHD/4K MOVIE CROPPING\n  - F-Log RECORDING\n  - 4K MOVIE OUTPUT\n  - FULL HD MOVIE OUTPUT\n  - HDMI OUTPUT INFO DISPLAY\n\n### Playback\n\n!Playback Menu\n\n- **PLAY BACK MENU**\n  - RAW CONVERSION\n  - ERASE\n  - CROP\n  - RESIZE\n  - PROTECT\n  - IMAGE ROTATE\n  - RED EYE REMOVAL\n  - VOICE MEMO SETTING', embedding_result=[]),
#  CameraDocument(metadata={'page': 20, 'model': 'x-e4'}, parsing_result='# Selecting a Menu Tab\n\nTo navigate the menus:\n\n1. Press **MENU/OK** to display the menus.\n\n   !Menu Display\n\n2. Press the focus stick (focus lever) left to highlight the tab for the current menu.\n\n   !Focus Stick Left\n\n3. Press the focus stick up or down to highlight the tab containing the desired item.\n\n4. Press the focus stick right to place the cursor in the menu.\n\n> 💡 **Note:**  \n> The front command dial can be used to highlight items when menus are displayed.', embedding_result=[]),
#  CameraDocument(metadata={'page': 21, 'model': 'x-e4'}, parsing_result='\n## Touch Screen Mode\nThe LCD monitor also functions as a touch screen.\n\n### Shooting Touch Controls\nTo enable touch controls, select ON for  \n**BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH SCREEN SETTING**.\n\n!Touch Screen Settings\n\n### EVF\nThe LCD monitor can be used to select the focus area while pictures are being framed in the electronic viewfinder (EVF). Use  \n**BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > EVF TOUCH SCREEN AREA SETTINGS** to choose the area of the monitor employed for touch controls.\n\n!EVF Touch Controls\n\n> 💡 **Note:**\n> When **FACE DETECTION ON** is selected for **AF/MF SETTING > FACE/EYE DETECTION SETTING**, you can choose the face used for focus.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 22, 'model': 'x-e4'}, parsing_result='\n# LCD Monitor\n\nThe operation performed can be selected by tapping the touch screen mode indicator in the display. Touch controls can be used for the following operations:\n\n| Mode          | Description                                                                                                                                                                                                 |\n|---------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| !Touch Shooting Icon **TOUCH SHOOTING** | Tap your subject in the display to focus and release the shutter. In burst mode, pictures will be taken while you keep your finger on the display.                                                                 |\n| !AF Icon **AF**               | - If **SINGLE AF** is selected for focus mode, the camera will focus when you tap your subject in the display. Focus locks at the current distance until you tap the **AF OFF** icon. <br> - If **CONTINUOUS AF** is selected for focus mode, the camera will initiate focus when you tap your subject in the display. The camera will continue to adjust focus for changes in the distance to the subject until you tap the **AF OFF** icon. <br> - When **MANUAL FOCUS** is selected for focus mode, you can tap the display to focus on the selected subject using autofocus. |\n| !AF OFF Icon **AF OFF**       |                                                                                                                                                                                                                             |\n| !Area Icon **AREA**           | Tap to select a point for focus or zoom. The focus frame will move to the selected point.                                                                                                                                   |\n| !Off Icon **OFF**             | Touch controls disabled.                                                                                                                                                                                                    |\n\n> !Note Icon **Note:**\n> - Different touch controls are used during focus zoom (📖 139).\n\n- To disable touch controls and hide the touch screen mode indicator, select **OFF** for !Button/Dial Setting Icon **BUTTON/DIAL SETTING** > **TOUCH SCREEN SETTING** > !Touch Screen Setting Icon **TOUCH SCREEN SETTING**.\n- Touch control settings can be adjusted using !AF/MF Setting Icon **AF/MF SETTING** > !Touch Screen Mode Icon **TOUCH SCREEN MODE**. For information on the touch controls available during movie recording, see “Movie Recording (📖 TOUCH SCREEN MODE; 📖 172)”.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 23, 'model': 'x-e4'}, parsing_result='\n# MOVIE OPTIMIZED CONTROL\n\nSelecting **ON** for **MOVIE SETTING > MOVIE OPTIMIZED CONTROL** or tapping the movie-optimized mode button in the shooting display optimizes the command dials and touch controls for movie recording. This can be used to prevent camera sounds being recorded with movie footage.\n\n- **SHUTTER SPEED**\n- **APERTURE**\n- **EXPOSURE COMPENSATION**\n- **ISO**\n- **INTERNAL MIC LEVEL ADJUSTMENT/EXTERNAL MIC LEVEL ADJUSTMENT**\n- **WIND FILTER**\n- **HEADPHONES VOLUME**\n- **FILM SIMULATION**\n- **WHITE BALANCE**\n- **FOCUS MODE**\n\n!Movie-optimized mode button\n\n> 💡 **Note:**\n> - Enabling movie-optimized controls disables the shutter speed and exposure compensation dials and aperture ring.\n> - When movie-optimized control is enabled, the movie-optimized mode button can be used to change shooting settings or disable movie-optimized control.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 24, 'model': 'x-e4'}, parsing_result='# Touch Function\n\nFunctions can be assigned to the following flick gestures in much the same way as function buttons (📖 256):\n\n- Flick up: **T-Fn1**\n- Flick left: **T-Fn2**\n- Flick right: **T-Fn3**\n- Flick down: **T-Fn4**\n\n!Touch Function Gestures\n\n> 💡 **Note:**\n> - In some cases, touch-function flick gestures display a menu; tap to select the desired option.\n> - Touch-function gestures are disabled by default. To enable touch-function gestures, select **ON** for **BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH FUNCTION**.', embedding_result=[]),
#  CameraDocument(metadata={'page': 25, 'model': 'x-e4'}, parsing_result='# Playback Touch Controls\n\nWhen **ON** is selected for **BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH SCREEN SETTING**, touch controls can be used for the following playback operations:\n\n- **Swipe:** Swipe a finger across the display to view other images.\n  \n  !Swipe Gesture\n\n- **Pinch-out:** Place two fingers on the display and spread them apart to zoom in.\n\n  !Pinch-out Gesture\n\n- **Pinch-in:** Place two fingers on the display and slide them together to zoom out.\n\n  !Pinch-in Gesture\n\n  > !Note Icon Pictures can be zoomed out until the entire image is visible but no further.\n\n- **Double-tap:** Tap the display twice to zoom in on the focus point.\n\n  !Double-tap Gesture\n\n- **Drag:** View other areas of the image during playback zoom.\n\n  !Drag Gesture', embedding_result=[]),
#  CameraDocument(metadata={'page': 28, 'model': 'x-e4'}, parsing_result='# Attaching the Strap\n\nAttach the strap.\n\nAttach the strap to the two strap eyelets as shown below.\n\n!Attaching the Strap\n\n> 💡 **Note:**\n> - To avoid dropping the camera, be sure the strap is correctly secured.\n> - Do not attach the strap buckles to the strap eyelets. Failure to observe this precaution could deform or break the strap eyelets.', embedding_result=[]),
#  CameraDocument(metadata={'page': 29, 'model': 'x-e4'}, parsing_result='\n## Attaching a Lens\n\nThe camera can be used with lenses for the FUJIFILM X-mount.\n\nRemove the body cap from the camera and the rear cap from the lens. Place the lens on mount, keeping the marks on the lens and camera aligned (①), and then rotate the lens until it clicks into place (②).\n\n!Attaching a Lens\n\n> 💡 **Note:**\n> - When attaching lenses, ensure that dust or other foreign matter does not enter the camera.\n> - Be careful not to touch the camera’s internal parts.\n> - Rotate the lens until it clicks securely into place.\n> - Do not press the lens release button while attaching the lens.\n\n### Removing Lenses\n\nTo remove the lens, turn the camera off, then press the lens release button (①) and rotate the lens as shown (②).\n\n!Removing a Lens\n\n> 💡 **Note:**\n> - To prevent dust accumulating on the lens or inside the camera, replace the lens caps and camera body cap when the lens is not attached.\n\n### Lenses and Other Optional Accessories\n\nThe camera can be used with lenses and accessories for the FUJIFILM X-mount.\n\n> 💡 **Precautions:**\n> - Check that the lenses are free of dust and other foreign matter.\n> - Do not change lenses in direct sunlight or under another bright light source. Light focused into the interior of the camera could cause it to malfunction.\n> - Attach the lens caps before exchanging lenses.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 30, 'model': 'x-e4'}, parsing_result='\n# Inserting the Battery and a Memory Card\n\nInsert the battery and memory card as described below.\n\n1. **Slide the battery-chamber cover latch**  \n   Slide the battery-chamber cover latch as shown and open the battery-chamber cover.\n\n   !Open Battery Chamber\n\n2. **Insert the battery**  \n   Using the battery to keep the battery latch pressed to one side, insert the battery contacts first in the direction shown by the arrow.\n\n   !Insert Battery\n\n3. **Insert the memory card**  \n   !Insert Memory Card\n\n   > 💡 **Note:**  \n   > The optional SD, SDHC, and SDXC memory cards the camera uses to store pictures are referred to as "memory cards".\n\n4. **Close the battery-chamber cover**  \n   Close the battery-chamber cover and slide the battery-chamber cover latch closed.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 31, 'model': 'x-e4'}, parsing_result='# Inserting the Battery and a Memory Card\n\n## Removing the Battery\n\nBefore removing the battery or memory card, **turn the camera off** and open the battery-chamber cover.\n\nTo remove the battery, press the battery latch to the side, and slide the battery out of the camera as shown.\n\n!Removing the Battery\n\n> ⚠️ **Note:**  \n> The battery may become hot when used in high-temperature environments. Observe caution when removing the battery.\n\n## Removing Memory Cards\n\nTo remove the memory card, press it in and release it slowly. The card can then be removed by hand.\n\n!Removing Memory Card\n\n- Press the center of the card when ejecting it.\n- When a memory card is removed, the card could be ejected too quickly. Use your finger to hold it and gently release the card.', embedding_result=[]),
#  CameraDocument(metadata={'page': 32, 'model': 'x-e4'}, parsing_result='# Inserting the Battery and a Memory Card\n\n## Compatible Memory Cards\n\n- The camera can be used with SD, SDHC, and SDXC memory cards.\n- The camera supports UHS-I memory cards.\n- To record movies, use cards with a UHS speed class of 3 or better or a video speed class of V30 or better.\n- A list of supported memory cards is available on the Fujifilm website. For details, visit:  \n  https://fujifilm-x.com/support/compatibility/cameras/.\n\n> 💡 **Note:**\n> - Do not turn the camera off or remove the memory card while the memory card is being formatted or data are being recorded to or deleted from the card. Failure to observe this precaution could damage the card.\n> - Memory cards can be locked, making it impossible to format the card or to record or delete images. Before inserting a memory card, slide the write-protect switch to the unlocked position.\n> - Memory cards are small and can be swallowed; keep out of reach of children. If a child swallows a memory card, seek medical assistance immediately.\n> - miniSD or microSD adapters that are larger or smaller than memory cards may not eject normally; if the card does not eject, take the camera to an authorized service representative. Do not forcibly remove the card.\n> - Do not affix labels or other objects to memory cards. Peeling labels can cause camera malfunction.\n> - Movie recording may be interrupted with some types of memory card.\n> - Formatting a memory card in the camera creates a folder in which pictures are stored. Do not rename or delete this folder or use a computer or other device to edit, delete, or rename image files. Always use the camera to delete pictures; before editing or renaming files, copy them to a computer and edit or rename the copies, not the originals. Renaming the files on the camera can cause problems during playback.\n\n!Memory Card Lock', embedding_result=[]),
#  CameraDocument(metadata={'page': 33, 'model': 'x-e4'}, parsing_result='# Charging the Battery\n\nThe battery is not charged at shipment. Charge the battery before use.\n\n> 💡 **Note:**\n> - An NP-W126S rechargeable battery is supplied with the camera.\n> - Turn the camera off for charging.\n\n- The camera can be charged via USB. USB charging is available with computers with a manufacturer-approved operating system and USB interface.\n\n!Charging via USB\n\n*Leave the computer on during charging.*\n\n> 💡 **Note:**\n> - The battery will not charge while the camera is on.\n> - Connect the supplied USB cable.\n> - Connect the camera directly to the computer; do not use a USB hub or keyboard.\n> - Charging stops if the computer enters sleep mode. To resume charging, activate the computer and disconnect and reconnect the USB cable.\n> - Charging may not be supported depending on the model of computer, computer settings, and the computer’s current state.\n> - The battery takes about 5 hours to charge with a charging input of 5 V/500 mA.\n\n- To charge the battery from a household AC power outlet, use a BC-W126S battery charger (available separately).', embedding_result=[]),
#  CameraDocument(metadata={'page': 34, 'model': 'x-e4'}, parsing_result='# Charging the Battery\n\n## Charge Status\n\nThe indicator lamp shows battery charge status as follows:\n\n| Indicator lamp | Battery status       |\n|----------------|----------------------|\n| On             | Battery charging.    |\n| Off            | Charging complete.   |\n| Blinks         | Charging error.      |\n\n!Battery Indicator\n\n- Do not affix labels or other objects to the battery. Failure to observe this precaution could make it impossible to remove the battery from the camera.\n- Do not short the battery terminals. The battery could overheat.\n- Read the cautions in “The Battery and Power Supply”.\n- Use only genuine Fujifilm rechargeable batteries designated for use in this camera. Failure to observe this precaution could result in product malfunction.\n- Do not remove the labels from the battery or attempt to split or peel the outer casing.\n- The battery gradually loses its charge when not in use. Charge the battery one or two days before use.\n- If the battery fails to hold a charge, it has reached the end of its charging life and must be replaced.\n- Remove dirt from the battery terminals with a clean, dry cloth. Failure to observe this precaution could prevent the battery from charging.\n- Note that charging times increase at low or high temperatures.\n\n> 💡 **Note:**\n> - If the camera is turned on during charging, charging will end and the USB connection will instead be used to power the camera. The battery level will begin to gradually decline.\n> - The camera will display a “power supply” icon when powered via USB.', embedding_result=[]),
#  CameraDocument(metadata={'page': 35, 'model': 'x-e4'}, parsing_result='# Turning the Camera On and Off\n\nUse the **ON/OFF** switch to turn the camera on and off.\n\nSlide the switch to **ON** to turn the camera on, or to **OFF** to turn the camera off.\n\n!ON/OFF Switch\n\n> 💡 **Note:**\n> - Fingerprints and other marks on the lens or viewfinder can affect pictures or the view through the viewfinder. Keep the lens and viewfinder clean.\n\n- Pressing the **PLAY** button during shooting starts playback.\n- Press the shutter button halfway to return to shooting mode.\n- The camera will turn off automatically if no operations are performed for the length of time selected for **POWER MANAGEMENT > AUTO POWER OFF**. To reactivate the camera after it has turned off automatically, press the shutter button halfway or turn the **ON/OFF** switch to **OFF** and then back to **ON**.', embedding_result=[]),
#  CameraDocument(metadata={'page': 36, 'model': 'x-e4'}, parsing_result='# Checking the Battery Level\n\nAfter turning the camera on, check the battery level in the display.\n\nBattery level is shown as follows:\n\n!Battery Level Display\n\n| Indicator        | Description                                      |\n|------------------|--------------------------------------------------|\n| !Partially Discharged | Battery partially discharged.                    |\n| !80% Full             | Battery about 80% full.                         |\n| !60% Full             | Battery about 60% full.                         |\n| !40% Full             | Battery about 40% full.                         |\n| !20% Full             | Battery about 20% full.                         |\n| !Low Battery          | Low battery. Charge as soon as possible.        |\n| !Exhausted            | Battery exhausted. Turn camera off and recharge battery. |', embedding_result=[]),
#  CameraDocument(metadata={'page': 37, 'model': 'x-e4'}, parsing_result='\n## Basic Setup\n\nWhen you turn the camera on for the first time, you can choose a language and set the camera clock. At default settings, you can also pair the camera with a smartphone or tablet so that you can later synchronize the clocks or download pictures. Follow the steps below when turning the camera on for the first time.\n\n> 💡 **Note:**  \n> If you intend to pair the camera with a smartphone or tablet, install and launch the latest version of the FUJIFILM Camera Remote App on the smart device before proceeding. For more information, visit:  \n> http://app.fujifilm-dsc.com/en/camera_remote/\n\n1. **Turn the camera on.**  \n   A language-selection dialog will be displayed.\n\n   !Turn Camera On\n\n2. **Choose a language.**  \n   Highlight a language and press **MENU/OK**.\n\n   !Choose Language\n\n3. **Pair the camera with the smartphone or tablet.**  \n   Press **MENU/OK** to pair the camera with a smartphone or tablet running the FUJIFILM Camera Remote app.\n\n   !Pairing with Smartphone\n\n   > 💡 **Tip:**  \n   > To skip pairing, press **DISP/BACK**.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 38, 'model': 'x-e4'}, parsing_result='\n## 4. Check the time.\n\nWhen pairing is complete, you will be prompted to set the camera clock to the time reported by the smartphone or tablet. Check that the time is correct.\n\n!Pairing Complete Screen\n\n> 💡 **Tip:**  \n> To set the clock manually, press **DISP/BACK** (📖 39).\n\n## 5. Synchronize the camera settings with the settings configured on your smartphone or tablet.\n\n!Smartphone Sync Setting\n\n> 💡 **Note:**  \n> The option selected can be changed at any time using  \n> **CONNECTION SETTING > Bluetooth SETTINGS**.\n\n## 6. Set the clock.\n\nPress **MENU/OK** to set the camera clock to the time reported by the smartphone or tablet and exit to shooting mode.\n\n## 7. Format the memory card (📖 208).\n\n> 💡 **Important:**  \n> Format memory cards before first use, and be sure to reformat all memory cards after using them in a computer or other device.\n\n> 💡 **Note:**  \n> If the battery is removed for an extended period, the camera clock will be reset and the language-selection dialog will be displayed when the camera is turned on.\n\n### Skipping the Current Step\n\nIf you skip a step, a confirmation dialog will be displayed; select **NO** to avoid repeating any steps you skipped the next time the camera is turned on.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 39, 'model': 'x-e4'}, parsing_result='\n# Basic Setup\n\n## Choosing a Different Language\n\nTo change the language:\n\n1. **Display language options.**  \n   Select **USER SETTING > 言語/LANG.**\n\n2. **Choose a language.**  \n   Highlight the desired option and press **MENU/OK**.\n\n## Changing the Time and Date\n\nTo set the camera clock:\n\n1. **Display DATE/TIME options.**  \n   Select **USER SETTING > DATE/TIME.**\n\n2. **Set the clock.**  \n   Press the focus stick (focus lever) left or right to highlight the year, month, day, hour, or minute and press up or down to change. Press **MENU/OK** to set the clock.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 42, 'model': 'x-e4'}, parsing_result='\n# Taking Photographs (Mode P)\n\nThis section describes how to take pictures using program AE (mode P). See pages 56–65 for information on S, A, and M modes.\n\n1. Press the **DRIVE/DELETE** button and select **STILL IMAGE** in the drive-mode menu.\n\n   !Drive/Delete Button\n\n2. Rotate the shutter-speed dial to **P** and confirm that the camera displays shooting information for program AE.\n\n   !Shutter-Speed Dial\n\n3. **Check the shooting mode.**  \n   Confirm that **P** appears in the display.\n\n   !Shooting Mode Display\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 43, 'model': 'x-e4'}, parsing_result='\n# Taking Photographs (Mode P)\n\n## 4. Ready the Camera\n\n- Hold the camera steady with both hands—shaking or unsteady hands can blur your shots.\n\n!Holding Camera Correctly\n\n- To prevent pictures that are out of focus or too dark (underexposed), keep your fingers and other objects away from the lens and AF-assist illuminator.\n\n!Avoid Blocking Lens\n\n## 5. Frame the Picture\n\n### Lenses with Zoom Rings\n\nUse the zoom ring to frame the picture in the display. Rotate the ring left to zoom out, right to zoom in.\n\n!Zoom Ring Illustration\n', embedding_result=[]),
# ...
#  CameraDocument(metadata={'page': 326, 'model': 'x-e4'}, parsing_result='\n| Warning          | Description                                                                                                                                                      |\n|------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| **WRITE ERROR**  | - **Memory card error or connection error:** Reinsert the card or turn the camera off and then on again. If the message persists, contact a Fujifilm dealer.     |\n|                  | - **Not enough memory remaining to record additional pictures:** Delete pictures or insert a memory card with more free space.                                   |\n|                  | - **The memory card is not formatted:** Format the memory card.                                                                                                  |\n|                  | - **The memory card was removed while data were being recorded:** Do not remove the memory card during recording.                                                |\n| **FRAME NO. FULL** | The camera has run out of frame numbers (current frame number is 999-9999). Insert a formatted memory card and select RENEW for **SAVE DATA SET-UP > FRAME NO.** Take a picture to reset frame numbering to 100-0001, then select CONTINUOUS for **FRAME NO.** |\n| **READ ERROR**   | - **The file is corrupt or was not created with the camera:** The file cannot be viewed.                                                                         |\n|                  | - **The memory card contacts require cleaning:** Clean the contacts with a soft, dry cloth. If the message is repeated, format the card. If the message persists, replace the card. |\n|                  | - **Camera malfunction:** Contact a Fujifilm dealer.                                                                                                             |\n| **PROTECTED FRAME** | An attempt was made to delete or rotate a protected picture. Remove protection and try again.                                                                  |\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 327, 'model': 'x-e4'}, parsing_result='\n# Warning Messages and Displays\n\n| Warning                                      | Description                                                                                                                                  |\n|----------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------|\n| CAN NOT CROP                                 | The picture is damaged or was not created with the camera.                                                                                   |\n| DPOF FILE ERROR                              | Print orders can contain no more than 999 pictures. Copy any additional pictures you wish to print to another memory card and create a second print order. |\n| CAN NOT SET DPOF                             | The picture cannot be printed using DPOF.                                                                                                    |\n| !Icon CAN NOT SET DPOF   | Movies cannot be printed using DPOF.                                                                                                         |\n| CAN NOT ROTATE                               | The selected picture cannot be rotated.                                                                                                      |\n| !Icon CAN NOT ROTATE     | Movies cannot be rotated.                                                                                                                    |\n| !Icon CANNOT EXECUTE     | Red-eye removal cannot be applied to movies.                                                                                                 |\n| !Icon CANNOT EXECUTE     | Red-eye removal cannot be applied to pictures created with other devices.                                                                    |\n| MISMATCH: 4K MODE AND EXTERNAL MONITOR CHANGE MOVIE MODE | The movie mode selected with the camera is not compatible with the device to which the camera is connected via HDMI. Try selecting a different movie mode. |\n| !Icon (yellow)           | Turn the camera off and wait for it to cool. Mottling may increase in pictures taken when this warning is displayed.                          |\n| !Icon (red)              | Turn the camera off and wait for it to cool. While this warning is displayed, movie recording may not be available, mottling may increase, and performance, including frame advance rate and display quality, may drop. |\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 328, 'model': 'x-e4'}, parsing_result='# Memory Card Capacity\n\nThe following table shows the recording time or number of pictures available at different image sizes. All figures are approximate; file size varies with the scene recorded, producing wide variations in the number of files that can be stored. The number of exposures or length remaining may not diminish at an even rate.\n\n!Memory Card Capacity Table\n\n| Capacity | 16 GB | 32 GB |\n|----------|-------|-------|\n| **FINE** | 1030  | 2060  |\n| **NORMAL** | 1540 | 3090  |\n| **RAW (UNCOMPRESSED)** | 270 | 550 |\n| **RAW (LOSSLESS COMPRESSED)** | 500 | 1010 |\n| **RAW (COMPRESSED)** | 690 | 1400 |\n| **4K 2160** | 20 minutes | 40 minutes |\n| **FHD 1080** | 20 minutes | 40 minutes |\n\n1. Use a UHS speed class 3 card or better.\n2. Assumes default bit rate.\n\n> 💡 **Note:**\n> If the memory card has a capacity of over 32 GB, movies will be recorded in single files, regardless of size. If the card has a capacity of 32 GB or less, movies over 4 GB in size will be recorded uninterrupted across multiple files.', embedding_result=[]),
#  CameraDocument(metadata={'page': 329, 'model': 'x-e4'}, parsing_result='\n# Specifications\n\n## System\n\n- **Model:** FUJIFILM X-E4\n- **Product Number:** FF200002\n- **Effective pixels:** Approx. 26.1 million\n- **Image sensor:** 23.5 mm × 15.6 mm (APS-C), X-Trans CMOS 4 sensor with primary color filter\n- **Storage media:** Fujifilm-recommended SD/SDHC/SDXC memory cards\n- **Memory card slot:** SD memory card slot (UHS-I compliant)\n- **File system:** Compliant with Design Rule for Camera File System (DCF2.0), Exif 2.32, and Digital Print Order Format (DPOF)\n\n## File format\n\n- **Still pictures:** Exif 2.32 JPEG (compressed); RAW (original RAF format, uncompressed or compressed using a reversible or non-reversible algorithm; special purpose software required); RAW+JPEG available\n- **Movies:** MPEG-4 AVC/H.264 standard with stereo sound (MOV/MP4)\n- **Audio (voice memos):** Stereo sound (WAV)\n\n## Image size\n\n- **L 3:2** (6240 × 4160)\n- **L 16:9** (6240 × 3512)\n- **M 3:2** (4416 × 2944)\n- **M 16:9** (4416 × 2488)\n- **S 3:2** (3120 × 2080)\n- **S 16:9** (3120 × 1760)\n- **L 1:1** (4160 × 4160)\n- **M 1:1** (2944 × 2944)\n- **S 1:1** (2080 × 2080)\n- **RAW** (6240 × 4160)\n- **L panorama:** vertical (2160 × 9600)/horizontal (9600 × 1440)\n- **M panorama:** vertical (2160 × 6400)/horizontal (6400 × 1440)\n\n## Lens mount\n\n- **FUJIFILM X mount**\n\n## Sensitivity\n\n- **Still pictures:** Standard output sensitivity equivalent to ISO 160–12800 in increments of ⅓ EV; AUTO1; AUTO2; AUTO3; extended output sensitivity equivalent to ISO 80, 100, 125, 25600, or 51200\n- **Movies:** Standard output sensitivity equivalent to ISO 160–12800 in increments of ⅓ EV; AUTO; extended output sensitivity equivalent to ISO 25600\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 330, 'model': 'x-e4'}, parsing_result='\n# System\n\n## Metering\n- 256-segment through-the-lens (TTL) metering\n- MULTI, SPOT, AVERAGE, CENTER WEIGHTED\n\n## Exposure Control\n- Programmed AE (with program shift)\n- Shutter-priority AE\n- Aperture-priority AE\n- Manual exposure\n\n## Exposure Compensation\n- **Still pictures:** –5 EV to +5 EV in increments of ⅓ EV\n- **Movies:** –2 EV to +2 EV in increments of ⅓ EV\n\n## Shutter Speed\n\n### Mechanical Shutter\n- **Mode P:** 4 s to 1/4000 s\n- **Mode A:** 30 s to 1/4000 s\n- **Modes S and M:** 15 min. to 1/4000 s\n- **Bulb:** Max. 60 min.\n\n### Electronic Shutter\n- **Mode P:** 4 s to 1/32000 s\n- **Mode A:** 30 s to 1/32000 s\n- **Modes S and M:** 15 min. to 1/32000 s\n- **Bulb:** Fixed at 1 s\n\n### Mechanical + Electronic\n- **Mode P:** 4 s to 1/32000 s\n- **Mode A:** 30 s to 1/32000 s\n- **Modes S and M:** 15 min. to 1/32000 s\n- **Bulb:** Max. 60 min.\n\n## Continuous\n\n| CONTINUOUS MODE         | Available frame advance rates (JPEG) |\n|-------------------------|--------------------------------------|\n| 30fps (1.25X CROP) *    | 30                                   |\n| 20fps (1.25X CROP) *    | 20                                   |\n| 10fps (1.25X CROP) *    | 10                                   |\n| 20fps *                 | 20                                   |\n| 10fps *                 | 10                                   |\n| 8.0fps                  | 8.0                                  |\n| 5.0fps                  | 5.0                                  |\n| 4.0fps                  | 4.0                                  |\n| 3.0fps                  | 3.0                                  |\n\n*Available with electronic shutter only.\n\n> 💡 **Note:**  \n> The frame rate and number of frames per burst varies with shooting conditions and type of memory card used.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 331, 'model': 'x-e4'}, parsing_result='\n# Specifications\n\n## System\n\n### Focus\n- **Mode:** Single or continuous AF; manual focus with focus ring\n- **Autofocus system:** Intelligent hybrid AF (TTL contrast-detect/phase-detection AF) with AF-assist illuminator\n- **Focus-area selection:** SINGLE POINT, ZONE, WIDE/TRACKING, ALL\n\n### White Balance\n- Auto (WHITE PRIORITY, AUTO, AMBIENCE PRIORITY), Custom 1, Custom 2, Custom 3, color temperature selection, direct sunlight, shade, daylight fluorescent, warm white fluorescent, cool white fluorescent, incandescent, underwater\n\n### Self-timer\n- Off, 2 sec., 10 sec.\n\n### Flash Mode\n- **MODE:** TTL MODE (FLASH AUTO, STANDARD, SLOW SYNC.), MANUAL, MULTI, OFF\n- **SYNC. MODE:** 1ST CURTAIN, 2ND CURTAIN, AUTO FP (high-speed sync)\n- **RED EYE REMOVAL:** !Flash+Removal, !Flash, !Removal, OFF\n\n### Hot Shoe\n- Accessory shoe with TTL contacts; supports sync speeds as fast as 1/180 s\n\n### Sync Contact\n- X contact; supports sync speeds as fast as 1/180 s\n\n### Sync Terminal\n- —\n\n### Electronic Viewfinder (EVF)\n- 0.39-in., 2360k-dot OLED viewfinder; magnification 0.62× with 50 mm lens (35 mm format equivalent) at infinity and diopter set to −1 m⁻¹; diagonal angle of view approximately 31° (horizontal angle of view approximately 26°)\n  - **Diopter adjustment:** −4 to +2 m⁻¹\n  - **Eyepoint:** Approximately 17.5 mm\n\n### LCD Monitor\n- 3.0-in/7.6 cm, 1620k-dot color touch screen LCD monitor, tilting\n\n### Movies (with Stereo Sound)\n- **Movie size:** 4K 16:9, DCI 17:9, FHD 16:9, HD 17:9\n- **Frame rate:** 59.94P, 50P, 29.97P, 25P, 24P, 23.98P\n- **Bit rate:** 200Mbps, 100Mbps, 50Mbps\n- **Recording/output format:** SD card, 4:2:0, 8-bit/HDMI output, 4:2:2, 10-bit\n\n### High-speed Movies\n- **Movie size:** FULL HD 16:9\n- **Frame advance rate:** 240P, 200P, 120P, 100P\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 332, 'model': 'x-e4'}, parsing_result='\n## Input/output terminals\n\n- **Microphone connector:** ø3.5 mm mini-stereo jack\n- **Headphone jack socket:** The USB connector can be converted to a headphone jack using the supplied headphone adapter\n- **Remote release connector:** ø3.5 mm 3-pole mini jack\n- **Digital input/output:** USB connector (Type-C) USB3.2 Gen1x1\n- **HDMI output:** HDMI Micro connector (type D)\n\n## Power supply/other\n\n- **Power supply:** NP-W126S rechargeable battery (supplied with camera)\n\n### Battery life\n\n- **Battery type:** NP-W126S\n- **Lens:** XF35mmF1.4 R\n- **External flash units:** Disabled\n- **Shooting mode:** Mode P\n\n| PERFORMANCE | Number of shots |\n|-------------|-----------------|\n| **LCD**     |                 |\n| BOOST       | Approx. 270     |\n| NORMAL      | Approx. 460     |\n| **EVF**     |                 |\n| BOOST       | Approx. 270     |\n| NORMAL      | Approx. 430     |\n\n### Total length of footage that can be recorded on a single charge\n\n| Mode               | Actual battery life of movie capture | Continuance battery life of movie capture |\n|--------------------|--------------------------------------|------------------------------------------|\n| **4K**<sup>1</sup> | Approx. 45 minutes                   | Approx. 60 minutes                       |\n| **FHD**<sup>2</sup>| Approx. 50 minutes                   | Approx. 75 minutes                       |\n| **High-speed movies**<sup>3</sup> | Approx. 80 minutes | -                                        |\n\n1. At a frame rate of 29.97 fps.\n2. At a frame rate of 59.94 fps.\n3. At a frame rate of 120 fps.\n\nCIPA standard. Measured using battery supplied with camera and SD memory card.\n\n> **Note:** Battery endurance varies with battery charge level and the figures given above are not guaranteed. Battery endurance will decline at low temperatures.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 333, 'model': 'x-e4'}, parsing_result='\n# Specifications\n\n## Power Supply/Other\n\n- **Camera size (W × H × D):**  \n  121.3 mm × 72.9 mm × 32.7 mm / 4.78 in. × 2.87 in. × 1.29 in. (excluding projections)\n\n- **Camera weight:**  \n  Approx. 315 g / 11.1 oz., excluding battery, accessories, and memory card\n\n- **Shooting weight:**  \n  Approx. 364 g / 12.8 oz., including battery and memory card\n\n- **Operating conditions:**  \n  - Temperature: 0 °C to +40 °C / +32 °F to +104 °F  \n  - Humidity: 10% to 80% (no condensation)\n\n## Wireless Transmitter\n\n### Wireless LAN\n\n- **Standards:**  \n  IEEE 802.11b/g/n (standard wireless protocol)\n\n- **Operating frequency (center frequency):**  \n  2,412 MHz–2,462 MHz (11 channels)\n\n- **Access protocols:**  \n  Infrastructure\n\n### Bluetooth®\n\n- **Standards:**  \n  Bluetooth version 4.2 (Bluetooth Low Energy)\n\n- **Operating frequency (center frequency):**  \n  2,402 MHz–2,480 MHz\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 334, 'model': 'x-e4'}, parsing_result='# Specifications\n\n## NP-W126S Rechargeable Battery\n\n| Specification          | Details                                      |\n|------------------------|----------------------------------------------|\n| **Nominal voltage**    | 7.2 V                                        |\n| **Nominal capacity**   | 1260 mAh                                     |\n| **Operating temperature** | 0 °C to +40 °C / +32 °F to +104 °F        |\n| **Dimensions (W × H × D)** | 36.4 mm × 47.1 mm × 15.7 mm / 1.4 in. × 1.9 in. × 0.6 in. |\n| **Weight**             | Approx. 47 g / 1.7 oz.                       |\n\n> ⚠️ **Note:**\n> - Weight and dimensions vary with the country or region of sale.\n> - Specifications and performance are subject to change without notice. Fujifilm will not be held liable for any errors this manual may contain. The appearance of the product may differ from that described in this manual.', embedding_result=[])]

# %%
for document in memo_erase_documents:
    document.metadata['subsection'] = []

    for chapter in x_e4_contents.keys():
        chapter_page_range = x_e4_contents[chapter]["page_range"]
        if chapter_page_range[0] <= document.metadata['page'] < chapter_page_range[1]:
            document.metadata['chapter'] = chapter

        for section in x_e4_contents[chapter]["sections"].keys():
            section_page_range = x_e4_contents[chapter]["sections"][section]['page_range']
            if section_page_range[0] <= document.metadata['page'] < section_page_range[1]:
                document.metadata['section'] = section

            if "subsections" in x_e4_contents[chapter]["sections"][section]:
                for subsection in x_e4_contents[chapter]["sections"][section]["subsections"].keys():
                    subsection_page_range = x_e4_contents[chapter]["sections"][section]['subsections'][subsection]                  
                    if subsection_page_range[0] <= document.metadata['page'] < subsection_page_range[1]:
                        document.metadata['subsection'].append(subsection)
            else:
                pass

# %%
memo_erase_documents
# Out:
# [CameraDocument(metadata={'page': 2, 'model': 'x-e4', 'subsection': [], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='\n# Parts of the Camera\n\nThe parts of the camera are listed below.\n\n!Camera Diagram\n\n1. **Shutter button** .................................................. 44\n2. **Exposure compensation dial** .................. 4, 80\n3. **Q (quick menu) button** ............................. 247\n4. **Shutter speed dial** .................................... 4, 56, 59, 63, 65\n5. **Hot shoe** ..................................................... 267\n6. **Microphone** ............................................... 50, 175\n7. **Strap eyelet** ................................................. 28\n8. **Connector cover**\n9. **Lens signal contacts**\n10. **Lens release button** .................................. 29\n11. **AF-assist illuminator** ................................. 131\n    - Self-timer lamp ........................................... 141\n    - Tally light .................................................... 163\n12. **Front command dial** ................................ 6\n13. **ON/OFF switch** ......................................... 35\n14. **Fn button** .................................................. 253\n15. **Body cap** .................................................. 29\n16. **Microphone/remote release connector** (ø3.5 mm) ................. 3, 50, 154\n17. **USB connector (Type-C)** ....................... 33, 50, 287\n18. **HDMI Micro connector (Type D)** .......... 282\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'x-e4', 'subsection': [], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='\n# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n19. **Diopter adjustment control**  \n   - Page: 9\n\n20. **Electronic viewfinder (EVF)**  \n   - Pages: 10, 14, 16, 21\n\n21. **Eye sensor**  \n   - Page: 15\n\n22. **DRIVE/DELETE button**  \n   - Pages: 5, 46, 87\n\n23. **PLAY (playback) button**  \n   - Page: 45\n\n24. **AEL (exposure lock)/AFL (focus lock) button**  \n   - Pages: 86, 253\n\n25. **Indicator lamp**  \n   - Pages: 7, 163  \n   - **Tally light**  \n     - Page: 163\n\n26. **Focus stick (focus lever)**  \n   - Pages: 5, 74, 224\n\n27. **MENU/OK button**  \n   - Page: 19\n\n28. **DISP (display)/BACK button**  \n   - Pages: 16, 183\n\n29. **Cable channel cover for DC coupler**  \n   - Page: 298\n\n30. **Battery-chamber cover latch**  \n   - Page: 30\n\n31. **Battery-chamber cover**  \n   - Page: 30\n\n32. **Tripod mount**\n\n33. **Speaker**  \n   - Pages: 52, 214\n\n34. **LCD monitor**  \n   - Pages: 8, 12, 14  \n   - **Touch screen**  \n     - Pages: 21, 138, 230\n\n35. **Battery chamber**  \n   - Page: 30\n\n36. **Memory card slot**  \n   - Page: 30\n\n37. **Battery latch**  \n   - Page: 31\n\n38. **Serial number plate**  \n   - See below\n\n> 💡 **Note:**\n> - **16:** Use of an optional RR-100 remote release requires a third-party adapter to convert the female three-pin, ø2.5 mm connector to a male three-pin, ø3.5 mm connector.\n> - **38:** Do not remove the serial number plate, which provides the CMIT ID, serial number, and other important information.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'x-e4', 'subsection': ['The Shutter Speed Dial', 'The Exposure Compensation Dial'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='\n# Before You Begin\n\n## The Shutter Speed Dial\nRotate the shutter speed dial to choose the shutter speed (📖 56).\n\n!Shutter Speed Dial\n\n## The Exposure Compensation Dial\nRotate the dial to choose an exposure compensation amount (📖 80).\n\n!Exposure Compensation Dial\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'x-e4', 'subsection': ['The Focus Stick (Focus Lever)', 'The DRIVE/DELETE Button'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='# Parts of the Camera\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus Stick\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING** (page 224).\n\n## The DRIVE/DELETE Button\n\nPressing the **DRIVE/DELETE** button displays the drive-mode menu, where you can choose from the following drive modes.\n\n!Drive/Delete Button\n\n| Mode                | Page |\n|---------------------|------|\n| Single frame        | 42   |\n| High-speed burst    | 92   |\n| Low-speed burst     | 92   |\n| ISO BKT             | 88   |\n| WHITE BALANCE BKT   | 88   |\n| Bracketing          | 89   |\n| HDR                 | 93   |\n| Adv. MODE           |      |\n| • Panorama          | 95   |\n| • Multiple Exposure | 98   |\n| Filter              | 100  |\n| Movie               | 48   |', embedding_result=[]),
#  CameraDocument(metadata={'page': 6, 'model': 'x-e4', 'subsection': ['The Command Dial'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='# The Command Dial\n\nThe front command dial is used for the operations below.\n\n!Command Dial\n\n## Shooting\n\n- Choose the desired combination of shutter speed and aperture (program shift).\n- Choose a shutter speed.\n- Adjust aperture.\n- Adjust exposure compensation.\n- Adjust sensitivity.\n\n> 💡 **Note:**\n> - During shooting, the role of the front command dial changes each time the center of the dial is pressed.\n> - For information on the roles performed by the dials during shooting, see “Front Command Dial Roles by Mode” (page 67).\n\n## Menus\n\nRotate the dial to select menu tabs or page through menus.\n\n## Q Menu\n\nRotate the dial to change settings in the quick menu and press the center of the dial to select.\n\n## Playback\n\n- View other pictures.\n- Zoom in or out during full- or multi-frame playback.\n\n> 💡 **Note:**\n> - Press the center of the front command dial to switch between the two roles.', embedding_result=[]),
#  CameraDocument(metadata={'page': 7, 'model': 'x-e4', 'subsection': ['The Indicator Lamp'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='# The Indicator Lamp\n\nCamera status is shown by the indicator lamp.\n\n!Indicator Lamp\n\n| Indicator Lamp          | Camera Status                                                                                   |\n|-------------------------|-------------------------------------------------------------------------------------------------|\n| Glows green             | Focus locked.                                                                                   |\n| Blinks green            | Focus or slow shutter speed warning. Pictures can be taken.                                     |\n| Blinks green and orange | - **Camera on:** Recording pictures. Additional pictures can be taken.                          |\n|                         | - **Camera off:** Uploading pictures to a smartphone or tablet.*                                |\n| Glows orange            | Recording pictures. No additional pictures can be taken at this time.                           |\n| Blinks orange           | Flash charging; flash will not fire when picture is taken.                                      |\n| Blinks red              | Lens or memory error.                                                                           |\n\n*Displayed only if pictures are selected for upload.\n\n> - Warnings may also appear in the display.\n> - The indicator lamp remains off while your eye is to the viewfinder.\n> - The **MOVIE SETTING > TALLY LIGHT** option can be used to choose the lamp (indicator or AF-assist) that lights during movie recording and whether the lamp blinks or remains steady.', embedding_result=[]),
#  CameraDocument(metadata={'page': 8, 'model': 'x-e4', 'subsection': ['The LCD Monitor'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='# The LCD Monitor\n\nYou can adjust the angle of the LCD monitor when framing shots, but be careful not to trap your fingers or other objects.\n\n!LCD Monitor Adjustment\n\n- Do not apply excessive force to the hinge when rotating the LCD monitor, as this could damage the hinge.\n- Be careful that the corners of the monitor do not contact the camera body, as this could leave marks.\n\nThe LCD monitor also functions as a touch screen that can be used for:\n\n- Touch photography (page 22)\n- Focus area selection (page 21)\n- Function selection (page 24)\n- Movie optimized control (page 23)\n- Playback (page 25)\n\n## Tilting the LCD Monitor\n\nBe sure the LCD monitor doesn’t block the eye sensor during shooting, as this will cause the display to flip.\n\n!Tilting the LCD Monitor\n\n- **Normal display**\n- **Display flipped**', embedding_result=[]),
#  CameraDocument(metadata={'page': 9, 'model': 'x-e4', 'subsection': ['Focusing the Viewfinder'], 'chapter': 'Before You Begin', 'section': 'Parts of the Camera'}, parsing_result='# Focusing the Viewfinder\n\nIf the indicators displayed in the viewfinder are blurred, put your eye to the viewfinder and rotate the diopter adjustment control until the display is in sharp focus.\n\n!Diopter Adjustment Control', embedding_result=[]),
#  CameraDocument(metadata={'page': 10, 'model': 'x-e4', 'subsection': ['The Electronic Viewfinder'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='# Camera Displays\n\nThis section lists the indicators that may be displayed during shooting.\n\n> For illustrative purposes, displays are shown with all indicators lit.\n\n## The Electronic Viewfinder\n\n!The Electronic Viewfinder', embedding_result=[]),
#  CameraDocument(metadata={'page': 11, 'model': 'x-e4', 'subsection': ['The Electronic Viewfinder'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='\n# Camera Displays\n\n1. **Crop factor** .................................................. 140\n2. **Focus check** .............................................. 78, 135\n3. **Depth-of-field preview** ......................... 64, 78\n4. **Location data download status** ...... 242, 284\n5. **Bluetooth ON/OFF** ................................ 237\n6. **Image transfer status** ....................... 237, 284\n7. **Movie mode** ........................................... 48, 155\n8. **Full HD high-speed recording** .......... 157\n9. **Recording time available/elapsed recording time** .......... 48\n10. **Date and time** .................................. 37, 39, 209\n11. **Number of available frames** ¹ .......... 328\n12. **Image size** .................................................. 104\n13. **File format** .................................................. 156\n14. **Image quality** ........................................... 105\n15. **Temperature warning** .......................... 327\n16. **Touch screen mode** .......................... 21, 138\n17. **White balance** .......................................... 109\n18. **AWB lock** .................................................... 229\n19. **Film simulation** ........................................ 106\n20. **F-Log recording** ...................................... 158\n21. **Dynamic range** ........................................ 113\n22. **D-range priority** ...................................... 114\n23. **Movie optimized control** ...................... 23\n24. **Sound and flash indicator** .................. 211\n25. **Virtual horizon** ........................................... 18\n26. **Boost mode** .............................................. 233\n27. **Histogram** ................................................... 18\n28. **Distance indicator** ² ................................. 78\n29. **Power supply** ............................................. 34\n30. **Battery level** ............................................... 36\n31. **Sensitivity** .................................................... 82\n32. **Exposure compensation** ....................... 80\n33. **Focus frame** ......................................... 73, 85\n34. **Aperture** ........................................... 58, 63, 65\n35. **Time code** .................................................. 178\n36. **Shutter speed** .................................. 58, 59, 65\n37. **TTL lock** ............................................. 150, 255\n38. **AE lock** .................................................. 86, 229\n39. **Metering** ....................................................... 84\n40. **Shooting mode** ......................................... 56\n41. **Focus mode** ² ............................................. 69\n42. **Focus indicator** ² ........................................ 70\n43. **Manual focus indicator** .................. 69, 77\n44. **AF lock** .................................................. 86, 229\n45. **Mic jack setting** ...................................... 176\n46. **Recording level** ² ..................................... 175\n47. **AF+MF indicator** ² .................................. 134\n48. **Shutter type** .............................................. 146\n49. **Continuous mode** ..................................... 92\n50. **Exposure indicator** .................................. 65\n51. **Self-timer indicator** ................................ 141\n52. **Microphone** .................................................. 50\n53. **Remote release** .......................................... 62\n54. **Flash (TTL) mode** .................................... 271\n55. **IS mode** ² .................................................... 147\n56. **Flash compensation** ...
#  CameraDocument(metadata={'page': 12, 'model': 'x-e4', 'subsection': ['The LCD Monitor'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result="!The LCD Monitor\n\n# The LCD Monitor\n\nThis image provides a detailed view of the camera's LCD monitor interface, highlighting various icons and indicators used for camera settings and status information.", embedding_result=[]),
#  CameraDocument(metadata={'page': 13, 'model': 'x-e4', 'subsection': ['The LCD Monitor'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='\n# Camera Displays\n\n1. **Crop factor** .................................................. 140\n2. **Flash compensation** .................................. 271\n3. **Focus check** ........................................... 78, 135\n4. **Depth-of-field preview** ......................... 64, 78\n5. **Location data download status** .......... 242, 284\n6. **Bluetooth ON/OFF** .................................. 237\n7. **Image transfer status** ............................ 237, 284\n8. **Movie mode** ........................................... 48, 155\n9. **Full HD high-speed recording** ............. 157\n10. **Focus frame** ........................................... 73, 85\n11. **Recording time available/elapsed recording time** .......... 48\n12. **Number of available frames¹** .............. 328\n13. **Image size** .............................................. 104\n14. **File format** ............................................. 156\n15. **Image quality** ......................................... 105\n16. **Date and time** ....................................... 37, 39, 209\n17. **Touch screen mode** ............................. 21, 138\n18. **AWB lock** ............................................... 229\n19. **White balance** ....................................... 109\n20. **Film simulation** ..................................... 106\n21. **F-Log recording** ................................... 158\n22. **Dynamic range** ..................................... 113\n23. **D-range priority** ................................... 114\n24. **Movie optimized control** .................... 23\n25. **Boost mode** .......................................... 233\n26. **Temperature warning** ......................... 327\n27. **Sound and flash indicator** .................. 211\n28. **Power supply** ........................................ 34\n29. **Battery level** .......................................... 36\n30. **Distance indicator²** .............................. 78\n31. **Sensitivity** .............................................. 82\n32. **Histogram** ............................................. 18\n33. **Exposure compensation** ..................... 80\n34. **Aperture** ................................................. 58, 63, 65\n35. **Time code** ............................................. 178\n36. **Shutter speed** ....................................... 58, 59, 65\n37. **TTL lock** ................................................. 150, 255\n38. **AE lock** .................................................. 86, 229\n39. **Metering** ................................................ 84\n40. **Shooting mode** .................................... 56\n41. **Focus mode²** ......................................... 69\n42. **Focus indicator²** ................................... 70\n43. **Manual focus indicator²** .................... 69, 77\n44. **AF lock** .................................................. 86, 229\n45. **Mic jack setting** ................................... 176\n46. **AF+MF indicator²** ............................... 134\n47. **Shutter type** ......................................... 146\n48. **Recording level** ................................... 175\n49. **Continuous mode** ............................... 92\n50. **Exposure indicator** ............................. 65\n51. **Self-timer indicator** ............................ 141\n52. **Microphone** .......................................... 50\n53. **Remote release** ................................... 62\n54. **Flash (TTL) mode** ............................... 271\n55. **IS mode²** ............................................... 147\n\n> ¹ Shows "9999" if there is space for over 9999 frames.\n> \n> ² Not displayed when ON is selected for **SCREEN SET-UP > LARGE INDICATORS MODE(LCD) ...
#  CameraDocument(metadata={'page': 14, 'model': 'x-e4', 'subsection': ['Adjusting Display Brightness', 'Display Rotation', 'Choosing a Display Mode'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='\n## Adjusting Display Brightness\n\nThe brightness and hue of the viewfinder and LCD monitor can be adjusted using the items in the !SCREEN SET-UP menu. Choose **EVF BRIGHTNESS** or **EVF COLOR** to adjust viewfinder brightness or hue, **LCD BRIGHTNESS** or **LCD COLOR** to do the same for the LCD monitor.\n\n## Display Rotation\n\nWhen **ON** is selected for !SCREEN SET-UP > **AUTOROTATE DISPLAYS**, the indicators in the viewfinder and LCD monitor automatically rotate to match camera orientation.\n\n## Choosing a Display Mode\n\nUse !SCREEN SET-UP > **VIEW MODE SETTING** to choose from the following display modes. You can choose separate display modes for shooting and playback.\n\n### SHOOTING\n\n| Option                  | Description                                                                                                                                   |\n|-------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------|\n| !EYE SENSOR | Putting your eye to the viewfinder turns the viewfinder on and the LCD monitor off; taking your eye away turns the viewfinder off and LCD monitor on. |\n| !EVF ONLY   | Viewfinder on, LCD monitor off.                                                                                                        |\n| !LCD ONLY   | LCD monitor on, viewfinder off.                                                                                                        |\n| !EVF ONLY + SENSOR | Putting your eye to the viewfinder turns the viewfinder on; taking it away turns the viewfinder off. The LCD monitor remains off.                      |\n| !EYE SENSOR + LCD IMAGE DISP. | Putting your eye to the viewfinder during shooting turns the viewfinder on, but the LCD monitor is used for the display of images once you remove your eye from the viewfinder after shooting. The options selected for !SCREEN SET-UP > **IMAGE DISP.** apply to display in the LCD monitor. |\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 15, 'model': 'x-e4', 'subsection': ['Adjusting Display Brightness', 'Display Rotation', 'Choosing a Display Mode'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='# PLAYBACK\n\n| Option      | Description                                                                                                                                  |\n|-------------|----------------------------------------------------------------------------------------------------------------------------------------------|\n| !Eye Sensor Icon EYE SENSOR | Putting your eye to the viewfinder turns the viewfinder on and the LCD monitor off; taking your eye away turns the viewfinder off and LCD monitor on. |\n| !EVF Icon EVF ONLY     | Viewfinder on, LCD monitor off.                                                                                                                        |\n| !LCD Icon LCD ONLY     | LCD monitor on, viewfinder off.                                                                                                                        |\n\n## The Eye Sensor\n\nThe eye sensor may respond to objects other than your eye or to light shining directly on the sensor.\n\n!Eye Sensor', embedding_result=[]),
#  CameraDocument(metadata={'page': 16, 'model': 'x-e4', 'subsection': ['The DISP/BACK Button'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='# The DISP/BACK Button\n\nThe **DISP/BACK** button controls the display of indicators in the viewfinder and LCD monitor.\n\n!DISP/BACK Button\n\n> 💡 **Note:**  \n> Indicators for the EVF and LCD must be selected separately. To choose the EVF display, place your eye to the viewfinder while using the **DISP/BACK** button.\n\n## Viewfinder (EVF)\n\n- **Standard indicators**  \n  !Standard Indicators EVF\n\n- **Full screen (no indicators)**  \n  !Full Screen EVF\n\n## LCD Monitor\n\n- **Standard indicators**  \n  !Standard Indicators LCD\n\n- **No indicators**  \n  !No Indicators LCD\n\n- **Info display (still photography only)**  \n  !Info Display', embedding_result=[]),
#  CameraDocument(metadata={'page': 17, 'model': 'x-e4', 'subsection': ['Customizing the Standard Display'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='# Customizing the Standard Display\n\nTo choose the items shown in the standard indicator display:\n\n1. **Display standard indicators.**  \n   Use the **DISP/BACK** button to display standard indicators.\n\n2. **Select DISP. CUSTOM SETTING.**  \n   Select **SCREEN SET-UP > DISP. CUSTOM SETTING** in the setup menu.\n\n3. **Choose items.**  \n   Highlight items and press **MENU/OK** to select or deselect.\n\n   | Item                     | Default | Item                     | Default |\n   |--------------------------|---------|--------------------------|---------|\n   | FRAMING GUIDELINE        |         | CONTINUOUS MODE          | ✔       |\n   | ELECTRONIC LEVEL         |         | DUAL IS MODE             | ✔       |\n   | FOCUS FRAME              | ✔       | TOUCH SCREEN MODE        | ✔       |\n   | AF DISTANCE INDICATOR    |         | WHITE BALANCE            | ✔       |\n   | MF DISTANCE INDICATOR    | ✔       | FILM SIMULATION          | ✔       |\n   | HISTOGRAM                |         | DYNAMIC RANGE            | ✔       |\n   | LIVE VIEW HIGHLIGHT ALERT|         | BOOST MODE               | ✔       |\n   | SHOOTING MODE            | ✔       | FRAMES REMAINING         | ✔       |\n   | APERTURE/S-SPEED/ISO     | ✔       | IMAGE SIZE/QUALITY       | ✔       |\n   | INFORMATION BACKGROUND   | ✔       | MOVIE MODE & REC. TIME   | ✔       |\n   | Expo. Comp. (Digit)      |         | IMAGE TRANSFER ORDER     | ✔       |\n   | Expo. Comp. (Scale)      | ✔       | MIC LEVEL                | ✔       |\n   | FOCUS MODE               | ✔       | GUIDANCE MESSAGE         | ✔       |\n   | PHOTOMETRY               | ✔       | BATTERY LEVEL            | ✔       |\n   | SHUTTER TYPE             | ✔       | FRAMING OUTLINE          |         |\n   | FLASH                    | ✔       |                          |         |\n\n4. **Press DISP/BACK to save changes.**\n\n5. **Press DISP/BACK as needed to exit the menus and return to the shooting display.**', embedding_result=[]),
#  CameraDocument(metadata={'page': 18, 'model': 'x-e4', 'subsection': ['Customizing the Standard Display'], 'chapter': 'Before You Begin', 'section': 'Camera Displays'}, parsing_result='# Camera Displays\n\n## Virtual Horizon\n\nSelecting **ELECTRONIC LEVEL** displays a virtual horizon. The camera is level when the two lines overlap. Note that the virtual horizon may not be displayed if the camera lens is pointed up or down. For a 3D display (shown), press the function button to which **ELECTRONIC LEVEL** is assigned.\n\n!Virtual Horizon Display\n\n## Framing Outline\n\nEnable **FRAMING OUTLINE** to make the borders of the frame easier to see against dark backgrounds.\n\n## Histograms\n\nHistograms show the distribution of tones in the image. Brightness is shown by the horizontal axis, the number of pixels by the vertical axis.\n\n!Histogram Display\n\n- **Optimal exposure:** Pixels are distributed in an even curve throughout the tone range.\n- **Overexposed:** Pixels are clustered on the right side of the graph.\n- **Underexposed:** Pixels are clustered on the left side of the graph.\n\nTo view separate RGB histograms and a display showing areas of the frame that will be overexposed at current settings superimposed on the view through the lens, press the function button to which **HISTOGRAM** is assigned.\n\n1. Overexposed areas blink\n2. RGB histograms\n\n!RGB Histogram Display', embedding_result=[]),
#  CameraDocument(metadata={'page': 19, 'model': 'x-e4', 'subsection': ['The Menus'], 'chapter': 'Before You Begin', 'section': 'Using the Menus'}, parsing_result='# Using the Menus\n\nTo display the menus, press **MENU/OK**.\n\n!Menu Button\n\n## The Menus\n\nDifferent menus are displayed during still photography, movie recording, and playback.\n\n### Still Photography\n\n!Still Photography Menu\n\n- **IMAGE QUALITY SETTING**\n  - IMAGE SIZE\n  - IMAGE QUALITY\n  - RAW RECORDING\n  - FILM SIMULATION\n  - MONOCHROMATIC COLOR\n  - GRAIN EFFECT\n  - COLOR CHROME EFFECT\n  - COLOR CHROME FX BLUE\n\n### Movie Recording\n\n!Movie Recording Menu\n\n- **MOVIE SETTING**\n  - MOVIE MODE\n  - FILE FORMAT\n  - FULL HD HIGH SPEED REC\n  - FHD/4K MOVIE CROPPING\n  - F-Log RECORDING\n  - 4K MOVIE OUTPUT\n  - FULL HD MOVIE OUTPUT\n  - HDMI OUTPUT INFO DISPLAY\n\n### Playback\n\n!Playback Menu\n\n- **PLAY BACK MENU**\n  - RAW CONVERSION\n  - ERASE\n  - CROP\n  - RESIZE\n  - PROTECT\n  - IMAGE ROTATE\n  - RED EYE REMOVAL\n  - VOICE MEMO SETTING', embedding_result=[]),
#  CameraDocument(metadata={'page': 20, 'model': 'x-e4', 'subsection': ['Selecting a Menu Tab'], 'chapter': 'Before You Begin', 'section': 'Using the Menus'}, parsing_result='# Selecting a Menu Tab\n\nTo navigate the menus:\n\n1. Press **MENU/OK** to display the menus.\n\n   !Menu Display\n\n2. Press the focus stick (focus lever) left to highlight the tab for the current menu.\n\n   !Focus Stick Left\n\n3. Press the focus stick up or down to highlight the tab containing the desired item.\n\n4. Press the focus stick right to place the cursor in the menu.\n\n> 💡 **Note:**  \n> The front command dial can be used to highlight items when menus are displayed.', embedding_result=[]),
#  CameraDocument(metadata={'page': 21, 'model': 'x-e4', 'subsection': ['Shooting Touch Controls'], 'chapter': 'Before You Begin', 'section': 'Touch Screen Mode'}, parsing_result='\n## Touch Screen Mode\nThe LCD monitor also functions as a touch screen.\n\n### Shooting Touch Controls\nTo enable touch controls, select ON for  \n**BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH SCREEN SETTING**.\n\n!Touch Screen Settings\n\n### EVF\nThe LCD monitor can be used to select the focus area while pictures are being framed in the electronic viewfinder (EVF). Use  \n**BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > EVF TOUCH SCREEN AREA SETTINGS** to choose the area of the monitor employed for touch controls.\n\n!EVF Touch Controls\n\n> 💡 **Note:**\n> When **FACE DETECTION ON** is selected for **AF/MF SETTING > FACE/EYE DETECTION SETTING**, you can choose the face used for focus.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 22, 'model': 'x-e4', 'subsection': ['Shooting Touch Controls'], 'chapter': 'Before You Begin', 'section': 'Touch Screen Mode'}, parsing_result='\n# LCD Monitor\n\nThe operation performed can be selected by tapping the touch screen mode indicator in the display. Touch controls can be used for the following operations:\n\n| Mode          | Description                                                                                                                                                                                                 |\n|---------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| !Touch Shooting Icon **TOUCH SHOOTING** | Tap your subject in the display to focus and release the shutter. In burst mode, pictures will be taken while you keep your finger on the display.                                                                 |\n| !AF Icon **AF**               | - If **SINGLE AF** is selected for focus mode, the camera will focus when you tap your subject in the display. Focus locks at the current distance until you tap the **AF OFF** icon. <br> - If **CONTINUOUS AF** is selected for focus mode, the camera will initiate focus when you tap your subject in the display. The camera will continue to adjust focus for changes in the distance to the subject until you tap the **AF OFF** icon. <br> - When **MANUAL FOCUS** is selected for focus mode, you can tap the display to focus on the selected subject using autofocus. |\n| !AF OFF Icon **AF OFF**       |                                                                                                                                                                                                                             |\n| !Area Icon **AREA**           | Tap to select a point for focus or zoom. The focus frame will move to the selected point.                                                                                                                                   |\n| !Off Icon **OFF**             | Touch controls disabled.                                                                                                                                                                                                    |\n\n> !Note Icon **Note:**\n> - Different touch controls are used during focus zoom (📖 139).\n\n- To disable touch controls and hide the touch screen mode indicator, select **OFF** for !Button/Dial Setting Icon **BUTTON/DIAL SETTING** > **TOUCH SCREEN SETTING** > !Touch Screen Setting Icon **TOUCH SCREEN SETTING**.\n- Touch control settings can be adjusted using !AF/MF Setting Icon **AF/MF SETTING** > !Touch Screen Mode Icon **TOUCH SCREEN MODE**. For information on the touch controls available during movie recording, see “Movie Recording (📖 TOUCH SCREEN MODE; 📖 172)”.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 23, 'model': 'x-e4', 'subsection': ['Shooting Touch Controls'], 'chapter': 'Before You Begin', 'section': 'Touch Screen Mode'}, parsing_result='\n# MOVIE OPTIMIZED CONTROL\n\nSelecting **ON** for **MOVIE SETTING > MOVIE OPTIMIZED CONTROL** or tapping the movie-optimized mode button in the shooting display optimizes the command dials and touch controls for movie recording. This can be used to prevent camera sounds being recorded with movie footage.\n\n- **SHUTTER SPEED**\n- **APERTURE**\n- **EXPOSURE COMPENSATION**\n- **ISO**\n- **INTERNAL MIC LEVEL ADJUSTMENT/EXTERNAL MIC LEVEL ADJUSTMENT**\n- **WIND FILTER**\n- **HEADPHONES VOLUME**\n- **FILM SIMULATION**\n- **WHITE BALANCE**\n- **FOCUS MODE**\n\n!Movie-optimized mode button\n\n> 💡 **Note:**\n> - Enabling movie-optimized controls disables the shutter speed and exposure compensation dials and aperture ring.\n> - When movie-optimized control is enabled, the movie-optimized mode button can be used to change shooting settings or disable movie-optimized control.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 24, 'model': 'x-e4', 'subsection': ['Shooting Touch Controls'], 'chapter': 'Before You Begin', 'section': 'Touch Screen Mode'}, parsing_result='# Touch Function\n\nFunctions can be assigned to the following flick gestures in much the same way as function buttons (📖 256):\n\n- Flick up: **T-Fn1**\n- Flick left: **T-Fn2**\n- Flick right: **T-Fn3**\n- Flick down: **T-Fn4**\n\n!Touch Function Gestures\n\n> 💡 **Note:**\n> - In some cases, touch-function flick gestures display a menu; tap to select the desired option.\n> - Touch-function gestures are disabled by default. To enable touch-function gestures, select **ON** for **BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH FUNCTION**.', embedding_result=[]),
#  CameraDocument(metadata={'page': 25, 'model': 'x-e4', 'subsection': ['Playback Touch Controls'], 'chapter': 'Before You Begin', 'section': 'Touch Screen Mode'}, parsing_result='# Playback Touch Controls\n\nWhen **ON** is selected for **BUTTON/DIAL SETTING > TOUCH SCREEN SETTING > TOUCH SCREEN SETTING**, touch controls can be used for the following playback operations:\n\n- **Swipe:** Swipe a finger across the display to view other images.\n  \n  !Swipe Gesture\n\n- **Pinch-out:** Place two fingers on the display and spread them apart to zoom in.\n\n  !Pinch-out Gesture\n\n- **Pinch-in:** Place two fingers on the display and slide them together to zoom out.\n\n  !Pinch-in Gesture\n\n  > !Note Icon Pictures can be zoomed out until the entire image is visible but no further.\n\n- **Double-tap:** Tap the display twice to zoom in on the focus point.\n\n  !Double-tap Gesture\n\n- **Drag:** View other areas of the image during playback zoom.\n\n  !Drag Gesture', embedding_result=[]),
#  CameraDocument(metadata={'page': 28, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Attaching the Strap'}, parsing_result='# Attaching the Strap\n\nAttach the strap.\n\nAttach the strap to the two strap eyelets as shown below.\n\n!Attaching the Strap\n\n> 💡 **Note:**\n> - To avoid dropping the camera, be sure the strap is correctly secured.\n> - Do not attach the strap buckles to the strap eyelets. Failure to observe this precaution could deform or break the strap eyelets.', embedding_result=[]),
#  CameraDocument(metadata={'page': 29, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Attaching a Lens'}, parsing_result='\n## Attaching a Lens\n\nThe camera can be used with lenses for the FUJIFILM X-mount.\n\nRemove the body cap from the camera and the rear cap from the lens. Place the lens on mount, keeping the marks on the lens and camera aligned (①), and then rotate the lens until it clicks into place (②).\n\n!Attaching a Lens\n\n> 💡 **Note:**\n> - When attaching lenses, ensure that dust or other foreign matter does not enter the camera.\n> - Be careful not to touch the camera’s internal parts.\n> - Rotate the lens until it clicks securely into place.\n> - Do not press the lens release button while attaching the lens.\n\n### Removing Lenses\n\nTo remove the lens, turn the camera off, then press the lens release button (①) and rotate the lens as shown (②).\n\n!Removing a Lens\n\n> 💡 **Note:**\n> - To prevent dust accumulating on the lens or inside the camera, replace the lens caps and camera body cap when the lens is not attached.\n\n### Lenses and Other Optional Accessories\n\nThe camera can be used with lenses and accessories for the FUJIFILM X-mount.\n\n> 💡 **Precautions:**\n> - Check that the lenses are free of dust and other foreign matter.\n> - Do not change lenses in direct sunlight or under another bright light source. Light focused into the interior of the camera could cause it to malfunction.\n> - Attach the lens caps before exchanging lenses.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 30, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Inserting the Battery and a Memory Card'}, parsing_result='\n# Inserting the Battery and a Memory Card\n\nInsert the battery and memory card as described below.\n\n1. **Slide the battery-chamber cover latch**  \n   Slide the battery-chamber cover latch as shown and open the battery-chamber cover.\n\n   !Open Battery Chamber\n\n2. **Insert the battery**  \n   Using the battery to keep the battery latch pressed to one side, insert the battery contacts first in the direction shown by the arrow.\n\n   !Insert Battery\n\n3. **Insert the memory card**  \n   !Insert Memory Card\n\n   > 💡 **Note:**  \n   > The optional SD, SDHC, and SDXC memory cards the camera uses to store pictures are referred to as "memory cards".\n\n4. **Close the battery-chamber cover**  \n   Close the battery-chamber cover and slide the battery-chamber cover latch closed.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 31, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Inserting the Battery and a Memory Card'}, parsing_result='# Inserting the Battery and a Memory Card\n\n## Removing the Battery\n\nBefore removing the battery or memory card, **turn the camera off** and open the battery-chamber cover.\n\nTo remove the battery, press the battery latch to the side, and slide the battery out of the camera as shown.\n\n!Removing the Battery\n\n> ⚠️ **Note:**  \n> The battery may become hot when used in high-temperature environments. Observe caution when removing the battery.\n\n## Removing Memory Cards\n\nTo remove the memory card, press it in and release it slowly. The card can then be removed by hand.\n\n!Removing Memory Card\n\n- Press the center of the card when ejecting it.\n- When a memory card is removed, the card could be ejected too quickly. Use your finger to hold it and gently release the card.', embedding_result=[]),
#  CameraDocument(metadata={'page': 32, 'model': 'x-e4', 'subsection': ['Compatible Memory Cards'], 'chapter': 'First Steps', 'section': 'Inserting the Battery and a Memory Card'}, parsing_result='# Inserting the Battery and a Memory Card\n\n## Compatible Memory Cards\n\n- The camera can be used with SD, SDHC, and SDXC memory cards.\n- The camera supports UHS-I memory cards.\n- To record movies, use cards with a UHS speed class of 3 or better or a video speed class of V30 or better.\n- A list of supported memory cards is available on the Fujifilm website. For details, visit:  \n  https://fujifilm-x.com/support/compatibility/cameras/.\n\n> 💡 **Note:**\n> - Do not turn the camera off or remove the memory card while the memory card is being formatted or data are being recorded to or deleted from the card. Failure to observe this precaution could damage the card.\n> - Memory cards can be locked, making it impossible to format the card or to record or delete images. Before inserting a memory card, slide the write-protect switch to the unlocked position.\n> - Memory cards are small and can be swallowed; keep out of reach of children. If a child swallows a memory card, seek medical assistance immediately.\n> - miniSD or microSD adapters that are larger or smaller than memory cards may not eject normally; if the card does not eject, take the camera to an authorized service representative. Do not forcibly remove the card.\n> - Do not affix labels or other objects to memory cards. Peeling labels can cause camera malfunction.\n> - Movie recording may be interrupted with some types of memory card.\n> - Formatting a memory card in the camera creates a folder in which pictures are stored. Do not rename or delete this folder or use a computer or other device to edit, delete, or rename image files. Always use the camera to delete pictures; before editing or renaming files, copy them to a computer and edit or rename the copies, not the originals. Renaming the files on the camera can cause problems during playback.\n\n!Memory Card Lock', embedding_result=[]),
#  CameraDocument(metadata={'page': 33, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Charging the Battery'}, parsing_result='# Charging the Battery\n\nThe battery is not charged at shipment. Charge the battery before use.\n\n> 💡 **Note:**\n> - An NP-W126S rechargeable battery is supplied with the camera.\n> - Turn the camera off for charging.\n\n- The camera can be charged via USB. USB charging is available with computers with a manufacturer-approved operating system and USB interface.\n\n!Charging via USB\n\n*Leave the computer on during charging.*\n\n> 💡 **Note:**\n> - The battery will not charge while the camera is on.\n> - Connect the supplied USB cable.\n> - Connect the camera directly to the computer; do not use a USB hub or keyboard.\n> - Charging stops if the computer enters sleep mode. To resume charging, activate the computer and disconnect and reconnect the USB cable.\n> - Charging may not be supported depending on the model of computer, computer settings, and the computer’s current state.\n> - The battery takes about 5 hours to charge with a charging input of 5 V/500 mA.\n\n- To charge the battery from a household AC power outlet, use a BC-W126S battery charger (available separately).', embedding_result=[]),
#  CameraDocument(metadata={'page': 34, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Charging the Battery'}, parsing_result='# Charging the Battery\n\n## Charge Status\n\nThe indicator lamp shows battery charge status as follows:\n\n| Indicator lamp | Battery status       |\n|----------------|----------------------|\n| On             | Battery charging.    |\n| Off            | Charging complete.   |\n| Blinks         | Charging error.      |\n\n!Battery Indicator\n\n- Do not affix labels or other objects to the battery. Failure to observe this precaution could make it impossible to remove the battery from the camera.\n- Do not short the battery terminals. The battery could overheat.\n- Read the cautions in “The Battery and Power Supply”.\n- Use only genuine Fujifilm rechargeable batteries designated for use in this camera. Failure to observe this precaution could result in product malfunction.\n- Do not remove the labels from the battery or attempt to split or peel the outer casing.\n- The battery gradually loses its charge when not in use. Charge the battery one or two days before use.\n- If the battery fails to hold a charge, it has reached the end of its charging life and must be replaced.\n- Remove dirt from the battery terminals with a clean, dry cloth. Failure to observe this precaution could prevent the battery from charging.\n- Note that charging times increase at low or high temperatures.\n\n> 💡 **Note:**\n> - If the camera is turned on during charging, charging will end and the USB connection will instead be used to power the camera. The battery level will begin to gradually decline.\n> - The camera will display a “power supply” icon when powered via USB.', embedding_result=[]),
#  CameraDocument(metadata={'page': 35, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Turning the Camera On and Off'}, parsing_result='# Turning the Camera On and Off\n\nUse the **ON/OFF** switch to turn the camera on and off.\n\nSlide the switch to **ON** to turn the camera on, or to **OFF** to turn the camera off.\n\n!ON/OFF Switch\n\n> 💡 **Note:**\n> - Fingerprints and other marks on the lens or viewfinder can affect pictures or the view through the viewfinder. Keep the lens and viewfinder clean.\n\n- Pressing the **PLAY** button during shooting starts playback.\n- Press the shutter button halfway to return to shooting mode.\n- The camera will turn off automatically if no operations are performed for the length of time selected for **POWER MANAGEMENT > AUTO POWER OFF**. To reactivate the camera after it has turned off automatically, press the shutter button halfway or turn the **ON/OFF** switch to **OFF** and then back to **ON**.', embedding_result=[]),
#  CameraDocument(metadata={'page': 36, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Checking the Battery Level'}, parsing_result='# Checking the Battery Level\n\nAfter turning the camera on, check the battery level in the display.\n\nBattery level is shown as follows:\n\n!Battery Level Display\n\n| Indicator        | Description                                      |\n|------------------|--------------------------------------------------|\n| !Partially Discharged | Battery partially discharged.                    |\n| !80% Full             | Battery about 80% full.                         |\n| !60% Full             | Battery about 60% full.                         |\n| !40% Full             | Battery about 40% full.                         |\n| !20% Full             | Battery about 20% full.                         |\n| !Low Battery          | Low battery. Charge as soon as possible.        |\n| !Exhausted            | Battery exhausted. Turn camera off and recharge battery. |', embedding_result=[]),
#  CameraDocument(metadata={'page': 37, 'model': 'x-e4', 'subsection': [], 'chapter': 'First Steps', 'section': 'Basic Setup'}, parsing_result='\n## Basic Setup\n\nWhen you turn the camera on for the first time, you can choose a language and set the camera clock. At default settings, you can also pair the camera with a smartphone or tablet so that you can later synchronize the clocks or download pictures. Follow the steps below when turning the camera on for the first time.\n\n> 💡 **Note:**  \n> If you intend to pair the camera with a smartphone or tablet, install and launch the latest version of the FUJIFILM Camera Remote App on the smart device before proceeding. For more information, visit:  \n> http://app.fujifilm-dsc.com/en/camera_remote/\n\n1. **Turn the camera on.**  \n   A language-selection dialog will be displayed.\n\n   !Turn Camera On\n\n2. **Choose a language.**  \n   Highlight a language and press **MENU/OK**.\n\n   !Choose Language\n\n3. **Pair the camera with the smartphone or tablet.**  \n   Press **MENU/OK** to pair the camera with a smartphone or tablet running the FUJIFILM Camera Remote app.\n\n   !Pairing with Smartphone\n\n   > 💡 **Tip:**  \n   > To skip pairing, press **DISP/BACK**.\n', embedding_result=[]),
# ...
#  CameraDocument(metadata={'page': 327, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Warning Messages and Displays'}, parsing_result='\n# Warning Messages and Displays\n\n| Warning                                      | Description                                                                                                                                  |\n|----------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------|\n| CAN NOT CROP                                 | The picture is damaged or was not created with the camera.                                                                                   |\n| DPOF FILE ERROR                              | Print orders can contain no more than 999 pictures. Copy any additional pictures you wish to print to another memory card and create a second print order. |\n| CAN NOT SET DPOF                             | The picture cannot be printed using DPOF.                                                                                                    |\n| !Icon CAN NOT SET DPOF   | Movies cannot be printed using DPOF.                                                                                                         |\n| CAN NOT ROTATE                               | The selected picture cannot be rotated.                                                                                                      |\n| !Icon CAN NOT ROTATE     | Movies cannot be rotated.                                                                                                                    |\n| !Icon CANNOT EXECUTE     | Red-eye removal cannot be applied to movies.                                                                                                 |\n| !Icon CANNOT EXECUTE     | Red-eye removal cannot be applied to pictures created with other devices.                                                                    |\n| MISMATCH: 4K MODE AND EXTERNAL MONITOR CHANGE MOVIE MODE | The movie mode selected with the camera is not compatible with the device to which the camera is connected via HDMI. Try selecting a different movie mode. |\n| !Icon (yellow)           | Turn the camera off and wait for it to cool. Mottling may increase in pictures taken when this warning is displayed.                          |\n| !Icon (red)              | Turn the camera off and wait for it to cool. While this warning is displayed, movie recording may not be available, mottling may increase, and performance, including frame advance rate and display quality, may drop. |\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 328, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Memory Card Capacity'}, parsing_result='# Memory Card Capacity\n\nThe following table shows the recording time or number of pictures available at different image sizes. All figures are approximate; file size varies with the scene recorded, producing wide variations in the number of files that can be stored. The number of exposures or length remaining may not diminish at an even rate.\n\n!Memory Card Capacity Table\n\n| Capacity | 16 GB | 32 GB |\n|----------|-------|-------|\n| **FINE** | 1030  | 2060  |\n| **NORMAL** | 1540 | 3090  |\n| **RAW (UNCOMPRESSED)** | 270 | 550 |\n| **RAW (LOSSLESS COMPRESSED)** | 500 | 1010 |\n| **RAW (COMPRESSED)** | 690 | 1400 |\n| **4K 2160** | 20 minutes | 40 minutes |\n| **FHD 1080** | 20 minutes | 40 minutes |\n\n1. Use a UHS speed class 3 card or better.\n2. Assumes default bit rate.\n\n> 💡 **Note:**\n> If the memory card has a capacity of over 32 GB, movies will be recorded in single files, regardless of size. If the card has a capacity of 32 GB or less, movies over 4 GB in size will be recorded uninterrupted across multiple files.', embedding_result=[]),
#  CameraDocument(metadata={'page': 329, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='\n# Specifications\n\n## System\n\n- **Model:** FUJIFILM X-E4\n- **Product Number:** FF200002\n- **Effective pixels:** Approx. 26.1 million\n- **Image sensor:** 23.5 mm × 15.6 mm (APS-C), X-Trans CMOS 4 sensor with primary color filter\n- **Storage media:** Fujifilm-recommended SD/SDHC/SDXC memory cards\n- **Memory card slot:** SD memory card slot (UHS-I compliant)\n- **File system:** Compliant with Design Rule for Camera File System (DCF2.0), Exif 2.32, and Digital Print Order Format (DPOF)\n\n## File format\n\n- **Still pictures:** Exif 2.32 JPEG (compressed); RAW (original RAF format, uncompressed or compressed using a reversible or non-reversible algorithm; special purpose software required); RAW+JPEG available\n- **Movies:** MPEG-4 AVC/H.264 standard with stereo sound (MOV/MP4)\n- **Audio (voice memos):** Stereo sound (WAV)\n\n## Image size\n\n- **L 3:2** (6240 × 4160)\n- **L 16:9** (6240 × 3512)\n- **M 3:2** (4416 × 2944)\n- **M 16:9** (4416 × 2488)\n- **S 3:2** (3120 × 2080)\n- **S 16:9** (3120 × 1760)\n- **L 1:1** (4160 × 4160)\n- **M 1:1** (2944 × 2944)\n- **S 1:1** (2080 × 2080)\n- **RAW** (6240 × 4160)\n- **L panorama:** vertical (2160 × 9600)/horizontal (9600 × 1440)\n- **M panorama:** vertical (2160 × 6400)/horizontal (6400 × 1440)\n\n## Lens mount\n\n- **FUJIFILM X mount**\n\n## Sensitivity\n\n- **Still pictures:** Standard output sensitivity equivalent to ISO 160–12800 in increments of ⅓ EV; AUTO1; AUTO2; AUTO3; extended output sensitivity equivalent to ISO 80, 100, 125, 25600, or 51200\n- **Movies:** Standard output sensitivity equivalent to ISO 160–12800 in increments of ⅓ EV; AUTO; extended output sensitivity equivalent to ISO 25600\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 330, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='\n# System\n\n## Metering\n- 256-segment through-the-lens (TTL) metering\n- MULTI, SPOT, AVERAGE, CENTER WEIGHTED\n\n## Exposure Control\n- Programmed AE (with program shift)\n- Shutter-priority AE\n- Aperture-priority AE\n- Manual exposure\n\n## Exposure Compensation\n- **Still pictures:** –5 EV to +5 EV in increments of ⅓ EV\n- **Movies:** –2 EV to +2 EV in increments of ⅓ EV\n\n## Shutter Speed\n\n### Mechanical Shutter\n- **Mode P:** 4 s to 1/4000 s\n- **Mode A:** 30 s to 1/4000 s\n- **Modes S and M:** 15 min. to 1/4000 s\n- **Bulb:** Max. 60 min.\n\n### Electronic Shutter\n- **Mode P:** 4 s to 1/32000 s\n- **Mode A:** 30 s to 1/32000 s\n- **Modes S and M:** 15 min. to 1/32000 s\n- **Bulb:** Fixed at 1 s\n\n### Mechanical + Electronic\n- **Mode P:** 4 s to 1/32000 s\n- **Mode A:** 30 s to 1/32000 s\n- **Modes S and M:** 15 min. to 1/32000 s\n- **Bulb:** Max. 60 min.\n\n## Continuous\n\n| CONTINUOUS MODE         | Available frame advance rates (JPEG) |\n|-------------------------|--------------------------------------|\n| 30fps (1.25X CROP) *    | 30                                   |\n| 20fps (1.25X CROP) *    | 20                                   |\n| 10fps (1.25X CROP) *    | 10                                   |\n| 20fps *                 | 20                                   |\n| 10fps *                 | 10                                   |\n| 8.0fps                  | 8.0                                  |\n| 5.0fps                  | 5.0                                  |\n| 4.0fps                  | 4.0                                  |\n| 3.0fps                  | 3.0                                  |\n\n*Available with electronic shutter only.\n\n> 💡 **Note:**  \n> The frame rate and number of frames per burst varies with shooting conditions and type of memory card used.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 331, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='\n# Specifications\n\n## System\n\n### Focus\n- **Mode:** Single or continuous AF; manual focus with focus ring\n- **Autofocus system:** Intelligent hybrid AF (TTL contrast-detect/phase-detection AF) with AF-assist illuminator\n- **Focus-area selection:** SINGLE POINT, ZONE, WIDE/TRACKING, ALL\n\n### White Balance\n- Auto (WHITE PRIORITY, AUTO, AMBIENCE PRIORITY), Custom 1, Custom 2, Custom 3, color temperature selection, direct sunlight, shade, daylight fluorescent, warm white fluorescent, cool white fluorescent, incandescent, underwater\n\n### Self-timer\n- Off, 2 sec., 10 sec.\n\n### Flash Mode\n- **MODE:** TTL MODE (FLASH AUTO, STANDARD, SLOW SYNC.), MANUAL, MULTI, OFF\n- **SYNC. MODE:** 1ST CURTAIN, 2ND CURTAIN, AUTO FP (high-speed sync)\n- **RED EYE REMOVAL:** !Flash+Removal, !Flash, !Removal, OFF\n\n### Hot Shoe\n- Accessory shoe with TTL contacts; supports sync speeds as fast as 1/180 s\n\n### Sync Contact\n- X contact; supports sync speeds as fast as 1/180 s\n\n### Sync Terminal\n- —\n\n### Electronic Viewfinder (EVF)\n- 0.39-in., 2360k-dot OLED viewfinder; magnification 0.62× with 50 mm lens (35 mm format equivalent) at infinity and diopter set to −1 m⁻¹; diagonal angle of view approximately 31° (horizontal angle of view approximately 26°)\n  - **Diopter adjustment:** −4 to +2 m⁻¹\n  - **Eyepoint:** Approximately 17.5 mm\n\n### LCD Monitor\n- 3.0-in/7.6 cm, 1620k-dot color touch screen LCD monitor, tilting\n\n### Movies (with Stereo Sound)\n- **Movie size:** 4K 16:9, DCI 17:9, FHD 16:9, HD 17:9\n- **Frame rate:** 59.94P, 50P, 29.97P, 25P, 24P, 23.98P\n- **Bit rate:** 200Mbps, 100Mbps, 50Mbps\n- **Recording/output format:** SD card, 4:2:0, 8-bit/HDMI output, 4:2:2, 10-bit\n\n### High-speed Movies\n- **Movie size:** FULL HD 16:9\n- **Frame advance rate:** 240P, 200P, 120P, 100P\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 332, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='\n## Input/output terminals\n\n- **Microphone connector:** ø3.5 mm mini-stereo jack\n- **Headphone jack socket:** The USB connector can be converted to a headphone jack using the supplied headphone adapter\n- **Remote release connector:** ø3.5 mm 3-pole mini jack\n- **Digital input/output:** USB connector (Type-C) USB3.2 Gen1x1\n- **HDMI output:** HDMI Micro connector (type D)\n\n## Power supply/other\n\n- **Power supply:** NP-W126S rechargeable battery (supplied with camera)\n\n### Battery life\n\n- **Battery type:** NP-W126S\n- **Lens:** XF35mmF1.4 R\n- **External flash units:** Disabled\n- **Shooting mode:** Mode P\n\n| PERFORMANCE | Number of shots |\n|-------------|-----------------|\n| **LCD**     |                 |\n| BOOST       | Approx. 270     |\n| NORMAL      | Approx. 460     |\n| **EVF**     |                 |\n| BOOST       | Approx. 270     |\n| NORMAL      | Approx. 430     |\n\n### Total length of footage that can be recorded on a single charge\n\n| Mode               | Actual battery life of movie capture | Continuance battery life of movie capture |\n|--------------------|--------------------------------------|------------------------------------------|\n| **4K**<sup>1</sup> | Approx. 45 minutes                   | Approx. 60 minutes                       |\n| **FHD**<sup>2</sup>| Approx. 50 minutes                   | Approx. 75 minutes                       |\n| **High-speed movies**<sup>3</sup> | Approx. 80 minutes | -                                        |\n\n1. At a frame rate of 29.97 fps.\n2. At a frame rate of 59.94 fps.\n3. At a frame rate of 120 fps.\n\nCIPA standard. Measured using battery supplied with camera and SD memory card.\n\n> **Note:** Battery endurance varies with battery charge level and the figures given above are not guaranteed. Battery endurance will decline at low temperatures.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 333, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='\n# Specifications\n\n## Power Supply/Other\n\n- **Camera size (W × H × D):**  \n  121.3 mm × 72.9 mm × 32.7 mm / 4.78 in. × 2.87 in. × 1.29 in. (excluding projections)\n\n- **Camera weight:**  \n  Approx. 315 g / 11.1 oz., excluding battery, accessories, and memory card\n\n- **Shooting weight:**  \n  Approx. 364 g / 12.8 oz., including battery and memory card\n\n- **Operating conditions:**  \n  - Temperature: 0 °C to +40 °C / +32 °F to +104 °F  \n  - Humidity: 10% to 80% (no condensation)\n\n## Wireless Transmitter\n\n### Wireless LAN\n\n- **Standards:**  \n  IEEE 802.11b/g/n (standard wireless protocol)\n\n- **Operating frequency (center frequency):**  \n  2,412 MHz–2,462 MHz (11 channels)\n\n- **Access protocols:**  \n  Infrastructure\n\n### Bluetooth®\n\n- **Standards:**  \n  Bluetooth version 4.2 (Bluetooth Low Energy)\n\n- **Operating frequency (center frequency):**  \n  2,402 MHz–2,480 MHz\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 334, 'model': 'x-e4', 'subsection': [], 'chapter': 'Technical Notes', 'section': 'Specifications'}, parsing_result='# Specifications\n\n## NP-W126S Rechargeable Battery\n\n| Specification          | Details                                      |\n|------------------------|----------------------------------------------|\n| **Nominal voltage**    | 7.2 V                                        |\n| **Nominal capacity**   | 1260 mAh                                     |\n| **Operating temperature** | 0 °C to +40 °C / +32 °F to +104 °F        |\n| **Dimensions (W × H × D)** | 36.4 mm × 47.1 mm × 15.7 mm / 1.4 in. × 1.9 in. × 0.6 in. |\n| **Weight**             | Approx. 47 g / 1.7 oz.                       |\n\n> ⚠️ **Note:**\n> - Weight and dimensions vary with the country or region of sale.\n> - Specifications and performance are subject to change without notice. Fujifilm will not be held liable for any errors this manual may contain. The appearance of the product may differ from that described in this manual.', embedding_result=[])]

# %%
for document in memo_erase_documents:
    if not document.metadata['subsection']:
        print(document.metadata['page'])
# Out:
# 2
# 3
# 28
# 29
# 30
# 31
# 33
# 34
# 35
# 36
# 37
# 38
# 42
# 43
# 44
# 45
# 46
# 52
# 53
# 68
# 77
# 80
# 82
# 84
# 85
# 87
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 182
# 185
# 231
# 244
# 266
# 278
# 279
# 298
# 299
# 300
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334

# %%
for document in memo_erase_documents:
    if not document.metadata['subsection']:
        document.metadata['subsection'].append(document.metadata['section'])

# %%
camera_model = "x-e4"
json_dir = "./data/json"

output_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "processed_data")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for doc in memo_erase_documents:
    output_path = os.path.join(output_dir, f"{camera_model}_page{doc.metadata['page']}.json")
    doc.save_json(output_path)
# Out:
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page2.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page3.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page4.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page5.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page6.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page7.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page8.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page9.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page10.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page11.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page12.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page13.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page14.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page15.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page16.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page17.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page18.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page19.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page20.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page21.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page22.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page23.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page24.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page25.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page28.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page29.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page30.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page31.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page32.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page33.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page34.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page35.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page36.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page37.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page38.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page39.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page42.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page43.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page44.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page45.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page46.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page48.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page49.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page50.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page51.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page52.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page53.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page56.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page57.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page58.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page59.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page60.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page61.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page62.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page63.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page64.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page65.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page66.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page67.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page68.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page69.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page70.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page71.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page72.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page73.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page74.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page75.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page76.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page77.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page78.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page79.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page80.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page81.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page82.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page83.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page84.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page85.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page86.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page87.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page88.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page89.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page90.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page91.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page92.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page93.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page94.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page95.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page96.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page97.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page98.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page99.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page100.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page101.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page104.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page105.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page106.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page107.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page108.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page109.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page110.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page111.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page112.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page113.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page114.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page115.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page116.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page117.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page118.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page119.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page120.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page121.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page122.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page123.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page124.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page125.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page126.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page127.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page128.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page129.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page130.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page131.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page132.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page133.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page134.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page135.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page136.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page137.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page138.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page139.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page140.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page141.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page142.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page143.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page144.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page145.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page146.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page147.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page148.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page149.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page150.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page151.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page152.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page153.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page154.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page155.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page156.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page157.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page158.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page159.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page160.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page161.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page162.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page163.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page164.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page165.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page166.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page167.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page168.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page169.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page170.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page171.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page172.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page173.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page174.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page175.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page176.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page177.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page178.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page179.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page182.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page183.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page184.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page185.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page186.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page187.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page188.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page189.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page190.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page191.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page192.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page193.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page194.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page195.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page196.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page197.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page198.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page199.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page200.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page201.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page202.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page203.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page204.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page205.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page208.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page209.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page210.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page211.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page212.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page213.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page214.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page215.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page216.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page217.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page218.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page219.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page220.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page221.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page222.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page223.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page224.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page225.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page226.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page227.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page228.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page229.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page230.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page231.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page232.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page233.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page234.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page235.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page236.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page237.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page238.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page239.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page240.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page241.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page242.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page244.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page245.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page246.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page247.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page248.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page249.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page250.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page251.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page252.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page253.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page254.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page255.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page256.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page257.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page260.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page261.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page262.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page263.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page264.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page265.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page266.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page267.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page268.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page269.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page270.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page271.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page272.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page273.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page274.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page275.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page276.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page277.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page278.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page279.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page282.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page283.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page284.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page285.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page286.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page287.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page288.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page289.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page290.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page291.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page292.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page293.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page294.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page295.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page296.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page298.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page299.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page300.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page301.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page302.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page303.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page304.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page305.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page306.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page307.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page308.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page309.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page310.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page311.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page312.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page313.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page314.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page315.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page316.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page317.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page318.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page319.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page320.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page321.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page322.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page323.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page324.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page325.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page326.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page327.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page328.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page329.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page330.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page331.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page332.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page333.json complete
# ./data/json/x-e4/LlamaParseMultimodal/processed_data/x-e4_page334.json complete

# %% [markdown]
# # Image Extract

# %%
from glob import glob
import re
import os

import sys
sys.path.append('../') 
from CameraDocument import CameraDocument

camera_model = 'x-e4'
json_dir = "./data/json"
detail_json_dir = os.path.join(json_dir, camera_model, "LlamaParseMultimodal", "processed_data")
json_path = os.path.join(detail_json_dir, "*.json")

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)

documents = []
for i, path in enumerate(json_list):
    document = CameraDocument()
    document.load_json(path)
    documents.append(document)

documents[:5]
# Out:
# [CameraDocument(metadata={'page': 2, 'model': 'x-e4', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': 'Parts of the Camera'}, parsing_result='\n# Parts of the Camera\n\nThe parts of the camera are listed below.\n\n!Camera Diagram\n\n1. **Shutter button** .................................................. 44\n2. **Exposure compensation dial** .................. 4, 80\n3. **Q (quick menu) button** ............................. 247\n4. **Shutter speed dial** .................................... 4, 56, 59, 63, 65\n5. **Hot shoe** ..................................................... 267\n6. **Microphone** ............................................... 50, 175\n7. **Strap eyelet** ................................................. 28\n8. **Connector cover**\n9. **Lens signal contacts**\n10. **Lens release button** .................................. 29\n11. **AF-assist illuminator** ................................. 131\n    - Self-timer lamp ........................................... 141\n    - Tally light .................................................... 163\n12. **Front command dial** ................................ 6\n13. **ON/OFF switch** ......................................... 35\n14. **Fn button** .................................................. 253\n15. **Body cap** .................................................. 29\n16. **Microphone/remote release connector** (ø3.5 mm) ................. 3, 50, 154\n17. **USB connector (Type-C)** ....................... 33, 50, 287\n18. **HDMI Micro connector (Type D)** .......... 282\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 3, 'model': 'x-e4', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': 'Parts of the Camera'}, parsing_result='\n# Parts of the Camera\n\n!Camera Diagram\n\n## Key Components\n\n19. **Diopter adjustment control**  \n   - Page: 9\n\n20. **Electronic viewfinder (EVF)**  \n   - Pages: 10, 14, 16, 21\n\n21. **Eye sensor**  \n   - Page: 15\n\n22. **DRIVE/DELETE button**  \n   - Pages: 5, 46, 87\n\n23. **PLAY (playback) button**  \n   - Page: 45\n\n24. **AEL (exposure lock)/AFL (focus lock) button**  \n   - Pages: 86, 253\n\n25. **Indicator lamp**  \n   - Pages: 7, 163  \n   - **Tally light**  \n     - Page: 163\n\n26. **Focus stick (focus lever)**  \n   - Pages: 5, 74, 224\n\n27. **MENU/OK button**  \n   - Page: 19\n\n28. **DISP (display)/BACK button**  \n   - Pages: 16, 183\n\n29. **Cable channel cover for DC coupler**  \n   - Page: 298\n\n30. **Battery-chamber cover latch**  \n   - Page: 30\n\n31. **Battery-chamber cover**  \n   - Page: 30\n\n32. **Tripod mount**\n\n33. **Speaker**  \n   - Pages: 52, 214\n\n34. **LCD monitor**  \n   - Pages: 8, 12, 14  \n   - **Touch screen**  \n     - Pages: 21, 138, 230\n\n35. **Battery chamber**  \n   - Page: 30\n\n36. **Memory card slot**  \n   - Page: 30\n\n37. **Battery latch**  \n   - Page: 31\n\n38. **Serial number plate**  \n   - See below\n\n> 💡 **Note:**\n> - **16:** Use of an optional RR-100 remote release requires a third-party adapter to convert the female three-pin, ø2.5 mm connector to a male three-pin, ø3.5 mm connector.\n> - **38:** Do not remove the serial number plate, which provides the CMIT ID, serial number, and other important information.\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 4, 'model': 'x-e4', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': 'The Exposure Compensation Dial'}, parsing_result='\n# Before You Begin\n\n## The Shutter Speed Dial\nRotate the shutter speed dial to choose the shutter speed (📖 56).\n\n!Shutter Speed Dial\n\n## The Exposure Compensation Dial\nRotate the dial to choose an exposure compensation amount (📖 80).\n\n!Exposure Compensation Dial\n', embedding_result=[]),
#  CameraDocument(metadata={'page': 5, 'model': 'x-e4', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': 'The DRIVE/DELETE Button'}, parsing_result='# Parts of the Camera\n\n## The Focus Stick (Focus Lever)\n\nTilt or press the focus stick to select the focus area. The focus stick can also be used to navigate the menus.\n\n!Focus Stick\n\n> 💡 **Tip:**  \n> To choose the role played by the focus stick, press and hold the center of the stick or use **BUTTON/DIAL SETTING > FOCUS LEVER SETTING** (page 224).\n\n## The DRIVE/DELETE Button\n\nPressing the **DRIVE/DELETE** button displays the drive-mode menu, where you can choose from the following drive modes.\n\n!Drive/Delete Button\n\n| Mode                | Page |\n|---------------------|------|\n| Single frame        | 42   |\n| High-speed burst    | 92   |\n| Low-speed burst     | 92   |\n| ISO BKT             | 88   |\n| WHITE BALANCE BKT   | 88   |\n| Bracketing          | 89   |\n| HDR                 | 93   |\n| Adv. MODE           |      |\n| • Panorama          | 95   |\n| • Multiple Exposure | 98   |\n| Filter              | 100  |\n| Movie               | 48   |', embedding_result=[]),
#  CameraDocument(metadata={'page': 6, 'model': 'x-e4', 'chapter': 'Before You Begin', 'section': 'Parts of the Camera', 'subsection': 'The Command Dial'}, parsing_result='# The Command Dial\n\nThe front command dial is used for the operations below.\n\n!Command Dial\n\n## Shooting\n\n- Choose the desired combination of shutter speed and aperture (program shift).\n- Choose a shutter speed.\n- Adjust aperture.\n- Adjust exposure compensation.\n- Adjust sensitivity.\n\n> 💡 **Note:**\n> - During shooting, the role of the front command dial changes each time the center of the dial is pressed.\n> - For information on the roles performed by the dials during shooting, see “Front Command Dial Roles by Mode” (page 67).\n\n## Menus\n\nRotate the dial to select menu tabs or page through menus.\n\n## Q Menu\n\nRotate the dial to change settings in the quick menu and press the center of the dial to select.\n\n## Playback\n\n- View other pictures.\n- Zoom in or out during full- or multi-frame playback.\n\n> 💡 **Note:**\n> - Press the center of the front command dial to switch between the two roles.', embedding_result=[])]

# %%
import fitz

raw_data_dir = "./data/raw_data"
image_dir = "./data/image"
output_dir = os.path.join(image_dir, camera_model, "pdf_to_image")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

dpi = 600  # 원하는 DPI 값 (300, 600 등)
for document in documents:
    page_num = document.metadata['page']
    pdf_path = os.path.join(raw_data_dir, camera_model, f"{camera_model}_split", f"{camera_model}_page{page_num+24}.pdf")

    pdf_document = fitz.open(pdf_path)
    page = pdf_document.load_page(0)
    pix = page.get_pixmap(dpi=dpi)

    output_file = os.path.join(output_dir, f"{camera_model}_page{page_num}.png")
    pix.save(output_file)
    print(f"Saved: {output_file}")

    pdf_document.close()
# Out:
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page2.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page3.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page4.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page5.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page6.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page7.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page8.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page9.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page10.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page11.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page12.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page13.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page14.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page15.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page16.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page17.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page18.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page19.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page20.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page21.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page22.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page23.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page24.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page25.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page28.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page29.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page30.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page31.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page32.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page33.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page34.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page35.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page36.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page37.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page38.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page39.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page42.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page43.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page44.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page45.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page46.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page48.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page49.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page50.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page51.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page52.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page53.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page56.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page57.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page58.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page59.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page60.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page61.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page62.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page63.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page64.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page65.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page66.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page67.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page68.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page69.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page70.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page71.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page72.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page73.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page74.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page75.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page76.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page77.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page78.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page79.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page80.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page81.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page82.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page83.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page84.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page85.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page86.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page87.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page88.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page89.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page90.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page91.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page92.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page93.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page94.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page95.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page96.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page97.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page98.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page99.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page100.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page101.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page104.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page105.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page106.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page107.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page108.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page109.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page110.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page111.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page112.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page113.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page114.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page115.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page116.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page117.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page118.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page119.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page120.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page121.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page122.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page123.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page124.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page125.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page126.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page127.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page128.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page129.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page130.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page131.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page132.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page133.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page134.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page135.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page136.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page137.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page138.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page139.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page140.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page141.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page142.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page143.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page144.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page145.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page146.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page147.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page148.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page149.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page150.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page151.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page152.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page153.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page154.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page155.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page156.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page157.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page158.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page159.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page160.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page161.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page162.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page163.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page164.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page165.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page166.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page167.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page168.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page169.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page170.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page171.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page172.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page173.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page174.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page175.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page176.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page177.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page178.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page179.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page182.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page183.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page184.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page185.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page186.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page187.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page188.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page189.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page190.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page191.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page192.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page193.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page194.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page195.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page196.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page197.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page198.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page199.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page200.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page201.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page202.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page203.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page204.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page205.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page208.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page209.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page210.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page211.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page212.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page213.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page214.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page215.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page216.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page217.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page218.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page219.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page220.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page221.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page222.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page223.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page224.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page225.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page226.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page227.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page228.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page229.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page230.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page231.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page232.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page233.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page234.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page235.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page236.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page237.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page238.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page239.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page240.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page241.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page242.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page244.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page245.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page246.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page247.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page248.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page249.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page250.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page251.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page252.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page253.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page254.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page255.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page256.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page257.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page260.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page261.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page262.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page263.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page264.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page265.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page266.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page267.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page268.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page269.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page270.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page271.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page272.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page273.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page274.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page275.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page276.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page277.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page278.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page279.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page282.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page283.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page284.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page285.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page286.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page287.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page288.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page289.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page290.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page291.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page292.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page293.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page294.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page295.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page296.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page298.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page299.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page300.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page301.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page302.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page303.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page304.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page305.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page306.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page307.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page308.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page309.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page310.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page311.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page312.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page313.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page314.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page315.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page316.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page317.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page318.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page319.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page320.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page321.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page322.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page323.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page324.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page325.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page326.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page327.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page328.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page329.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page330.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page331.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page332.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page333.png
# Saved: ./data/image/x-e4/pdf_to_image/x-e4_page334.png

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path=".env", override=True)
# Out:
# True

# %%
from glob import glob
import re

def extract_number(file_path):
    match = re.search(r'(\d+)\.png$', file_path)
    return int(match.group(1)) if match else None

camera_model = "x-e4"
image_dir = "./data/image"
image_path = os.path.join(image_dir, camera_model, "pdf_to_image", "*.png")

images = glob(image_path)
images = sorted(images, key=extract_number)

# %%
import requests
import json

json_dir = f"./data/json/{camera_model}/upstage"
if not os.path.exists(json_dir):
    os.makedirs(json_dir)

api_key = os.getenv("UPSTAGE_API_KEY")
url = "https://api.upstage.ai/v1/document-ai/document-parse"
headers = {"Authorization": f"Bearer {api_key}"}

for image_path in images:
    filename = image_path
    files = {"document": open(filename, "rb")}
    data = {"output_formats":"['html','markdown']"}
    response_test = requests.post(url, headers=headers, files=files, data=data)

    json_path = os.path.join(json_dir, os.path.splitext(os.path.basename(image_path))[0] +".json")
    with open(json_path, "w", encoding="utf-8") as file:
        json.dump(response_test.json(), file, ensure_ascii=False, indent=4)

# %%
from glob import glob
import re
import os

def extract_number(file_path):
    match = re.search(r'(\d+)\.json$', file_path)
    return int(match.group(1)) if match else None

camera_model = "x-e4"
json_dir = "./data/json"
json_path = os.path.join(json_dir, camera_model, "upstage", "*.json")

json_list = glob(json_path)
json_list = sorted(json_list, key=extract_number)

# %%
import json
from PIL import Image

image_dir = "./data/image"
pdf_image_dir = os.path.join(image_dir, camera_model, "pdf_to_image")
output_dir = os.path.join(image_dir, camera_model, "extracted_images")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for json_path in json_list:
    with open(json_path, "r", encoding="utf-8") as file:
        json_data = json.load(file)

    filtered_elements = []
    for element in json_data['elements']:
        if element.get('category') == 'figure':
            filtered_elements.append(element.get('coordinates'))

    image_path = os.path.join(pdf_image_dir, os.path.splitext(os.path.basename(json_path))[0]+'.png')
    for idx, coordinate in enumerate(filtered_elements):
        try:
            with Image.open(image_path) as img:
                width, height = img.size

                # 바운딩 박스 좌표 계산
                x_min = int(min(coord['x'] * width for coord in coordinate))
                y_min = int(min(coord['y'] * height for coord in coordinate))
                x_max = int(max(coord['x'] * width for coord in coordinate))
                y_max = int(max(coord['y'] * height for coord in coordinate))

                # 바운딩 박스 크롭
                cropped_image = img.crop((x_min, y_min, x_max, y_max))

                # 결과 이미지 저장
                output_path = os.path.join(output_dir, os.path.splitext(os.path.basename(json_path))[0]+f"_image{idx+1}.png")
                cropped_image.save(output_path)
                print(f"Cropped image saved to: {output_path}")

        except FileNotFoundError:
            print(f"File not found: {image_path}")
# Out:
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page2_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page3_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page4_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page4_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page5_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page5_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page6_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page7_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page8_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page8_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page9_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page10_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page12_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page16_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page16_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page16_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page18_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page18_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page18_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page18_image4.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page19_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page20_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page21_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page21_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page21_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page23_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page24_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page24_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page25_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page25_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page25_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page28_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page29_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page29_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page30_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page31_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page31_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page33_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page34_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page35_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page37_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page37_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page42_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page42_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page43_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page44_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page45_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page46_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page48_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page49_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page50_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page52_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page52_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page53_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page57_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page57_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page58_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page59_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page60_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page60_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page61_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page62_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page63_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page65_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page66_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page67_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page74_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page76_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page76_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page76_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page77_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page77_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page78_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page79_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page79_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page79_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page80_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page81_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page85_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page86_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page87_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page90_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page91_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page91_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page91_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page92_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page93_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page95_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page95_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page97_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page98_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page98_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page99_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page99_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page99_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page100_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page101_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page108_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page112_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page112_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page112_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page114_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page118_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page120_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page121_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page123_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page124_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page126_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page127_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page127_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page128_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page129_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page132_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page139_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page139_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page140_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page143_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page143_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page149_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page155_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page163_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page173_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page173_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page179_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page182_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page183_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page183_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page184_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page184_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page184_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image4.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image5.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image6.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image7.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image8.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page185_image9.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page186_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page187_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page187_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page203_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page204_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page205_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page208_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page216_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page221_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page221_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page221_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page222_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page232_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page234_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page239_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page246_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page247_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page248_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page249_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page249_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page249_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page250_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page253_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page256_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page256_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page256_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page260_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page261_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page261_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page262_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page262_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page263_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page263_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page264_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page264_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page264_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page267_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page267_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page268_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page270_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page271_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page274_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page274_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page278_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page279_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page279_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page279_image3.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page282_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page285_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page285_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page286_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page287_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page290_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page291_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page291_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page292_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page292_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page294_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page295_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page296_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page303_image1.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page303_image2.png
# Cropped image saved to: ./data/image/x-e4/extracted_images/x-e4_page308_image1.png
